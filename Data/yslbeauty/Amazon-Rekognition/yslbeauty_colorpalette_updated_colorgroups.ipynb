# %% [markdown]
# <a href="https://colab.research.google.com/github/Emily-KD/PopularityPrediction/blob/main/Data/yslbeauty/Amazon-Rekognition/yslbeauty_colorpalette_updated_colorgroups.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install colorthief
# Out:
# Collecting colorthief
#   Downloading colorthief-0.2.1-py2.py3-none-any.whl.metadata (816 bytes)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from colorthief) (11.1.0)
# Downloading colorthief-0.2.1-py2.py3-none-any.whl (6.1 kB)
# Installing collected packages: colorthief
# Successfully installed colorthief-0.2.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from colorthief import ColorThief
import webcolors
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
import os

# %%
username = "yslbeauty"
rekog_images_dir = f"/content/drive/Shareddrives/DS340W Project/Dataset NEW*/{username}/{username}_images_2024_2025/"

# %%
local_images = os.listdir(rekog_images_dir) # Get all image names

# %%
# Get list of non-duplicate .jpg files
local_images = [
    f for f in os.listdir(rekog_images_dir)
    if f.endswith('.jpg') and ' (1)' not in f
]

local_images
# Out:
# ['post215_img2.jpg',
#  'post215_img1.jpg',
#  'post215_img3.jpg',
#  'post210_img1.jpg',
#  'post210_img2.jpg',
#  'post210_img3.jpg',
#  'post210_img4.jpg',
#  'post210_img5.jpg',
#  'post208_img3.jpg',
#  'post208_img1.jpg',
#  'post208_img2.jpg',
#  'post208_img5.jpg',
#  'post208_img4.jpg',
#  'post198_img1.jpg',
#  'post197_img2.jpg',
#  'post197_img1.jpg',
#  'post197_img6.jpg',
#  'post197_img5.jpg',
#  'post197_img3.jpg',
#  'post197_img4.jpg',
#  'post197_img7.jpg',
#  'post196_img1.jpg',
#  'post196_img2.jpg',
#  'post196_img3.jpg',
#  'post196_img4.jpg',
#  'post196_img5.jpg',
#  'post195_img3.jpg',
#  'post195_img2.jpg',
#  'post195_img4.jpg',
#  'post195_img1.jpg',
#  'post195_img5.jpg',
#  'post193_img1.jpg',
#  'post193_img3.jpg',
#  'post193_img2.jpg',
#  'post193_img4.jpg',
#  'post192_img1.jpg',
#  'post192_img2.jpg',
#  'post192_img3.jpg',
#  'post192_img4.jpg',
#  'post185_img1.jpg',
#  'post185_img2.jpg',
#  'post185_img4.jpg',
#  'post185_img3.jpg',
#  'post184_img1.jpg',
#  'post184_img2.jpg',
#  'post184_img3.jpg',
#  'post177_img1.jpg',
#  'post177_img2.jpg',
#  'post177_img3.jpg',
#  'post176_img1.jpg',
#  'post165_img1.jpg',
#  'post152_img1.jpg',
#  'post152_img2.jpg',
#  'post152_img4.jpg',
#  'post152_img3.jpg',
#  'post152_img5.jpg',
#  'post151_img1.jpg',
#  'post151_img2.jpg',
#  'post150_img3.jpg',
#  'post150_img1.jpg',
#  'post150_img4.jpg',
#  'post150_img2.jpg',
#  'post147_img2.jpg',
#  'post147_img1.jpg',
#  'post147_img3.jpg',
#  'post146_img1.jpg',
#  'post145_img1.jpg',
#  'post145_img2.jpg',
#  'post145_img3.jpg',
#  'post145_img4.jpg',
#  'post144_img1.jpg',
#  'post144_img2.jpg',
#  'post144_img3.jpg',
#  'post138_img1.jpg',
#  'post138_img2.jpg',
#  'post137_img2.jpg',
#  'post137_img1.jpg',
#  'post137_img4.jpg',
#  'post137_img5.jpg',
#  'post137_img3.jpg',
#  'post135_img1.jpg',
#  'post135_img2.jpg',
#  'post129_img1.jpg',
#  'post129_img2.jpg',
#  'post129_img3.jpg',
#  'post129_img4.jpg',
#  'post126_img1.jpg',
#  'post118_img1.jpg',
#  'post118_img2.jpg',
#  'post116_img2.jpg',
#  'post116_img1.jpg',
#  'post114_img1.jpg',
#  'post114_img2.jpg',
#  'post114_img3.jpg',
#  'post113_img1.jpg',
#  'post113_img2.jpg',
#  'post111_img2.jpg',
#  'post111_img3.jpg',
#  'post111_img1.jpg',
#  'post108_img2.jpg',
#  'post108_img3.jpg',
#  'post108_img1.jpg',
#  'post106_img1.jpg',
#  'post106_img2.jpg',
#  'post102_img1.jpg',
#  'post102_img2.jpg',
#  'post98_img3.jpg',
#  'post98_img1.jpg',
#  'post98_img2.jpg',
#  'post97_img1.jpg',
#  'post97_img2.jpg',
#  'post94_img1.jpg',
#  'post94_img2.jpg',
#  'post91_img4.jpg',
#  'post91_img3.jpg',
#  'post91_img2.jpg',
#  'post91_img1.jpg',
#  'post88_img1.jpg',
#  'post88_img2.jpg',
#  'post88_img3.jpg',
#  'post86_img1.jpg',
#  'post82_img1.jpg',
#  'post82_img2.jpg',
#  'post82_img4.jpg',
#  'post82_img6.jpg',
#  'post82_img7.jpg',
#  'post82_img5.jpg',
#  'post82_img3.jpg',
#  'post80_img3.jpg',
#  'post80_img1.jpg',
#  'post80_img2.jpg',
#  'post80_img4.jpg',
#  'post79_img1.jpg',
#  'post79_img2.jpg',
#  'post179_img1.jpg',
#  'post179_img5.jpg',
#  'post179_img2.jpg',
#  'post179_img4.jpg',
#  'post179_img3.jpg',
#  'post78_img3.jpg',
#  'post78_img2.jpg',
#  'post78_img1.jpg',
#  'post168_img1.jpg',
#  'post168_img2.jpg',
#  'post163_img2.jpg',
#  'post163_img1.jpg',
#  'post163_img3.jpg',
#  'post155_img1.jpg',
#  'post155_img2.jpg',
#  'post155_img3.jpg',
#  'post75_img1.jpg',
#  'post74_img1.jpg',
#  'post74_img3.jpg',
#  'post74_img2.jpg',
#  'post68_img3.jpg',
#  'post68_img1.jpg',
#  'post68_img2.jpg',
#  'post65_img1.jpg',
#  'post65_img2.jpg',
#  'post65_img3.jpg',
#  'post62_img2.jpg',
#  'post62_img4.jpg',
#  'post62_img3.jpg',
#  'post62_img1.jpg',
#  'post52_img1.jpg',
#  'post52_img3.jpg',
#  'post52_img4.jpg',
#  'post52_img2.jpg',
#  'post52_img7.jpg',
#  'post52_img5.jpg',
#  'post52_img8.jpg',
#  'post52_img6.jpg',
#  'post52_img9.jpg',
#  'post52_img10.jpg',
#  'post49_img1.jpg',
#  'post49_img4.jpg',
#  'post49_img3.jpg',
#  'post49_img2.jpg',
#  'post50_img1.jpg',
#  'post48_img2.jpg',
#  'post48_img1.jpg',
#  'post47_img1.jpg',
#  'post47_img2.jpg',
#  'post47_img3.jpg',
#  'post46_img3.jpg',
#  'post46_img1.jpg',
#  'post46_img2.jpg',
#  'post41_img1.jpg',
#  'post41_img3.jpg',
#  'post41_img2.jpg',
#  'post38_img1.jpg',
#  'post38_img3.jpg',
#  'post38_img4.jpg',
#  'post38_img2.jpg',
#  'post35_img1.jpg',
#  'post35_img2.jpg',
#  'post33_img2.jpg',
#  'post33_img3.jpg',
#  'post33_img1.jpg',
#  'post32_img2.jpg',
#  'post32_img1.jpg',
#  'post32_img3.jpg',
#  'post32_img4.jpg',
#  'post31_img2.jpg',
#  'post31_img3.jpg',
#  'post31_img1.jpg',
#  'post28_img3.jpg',
#  'post28_img4.jpg',
#  'post28_img2.jpg',
#  'post28_img1.jpg',
#  'post26_img1.jpg',
#  'post26_img2.jpg',
#  'post26_img3.jpg',
#  'post20_img1.jpg',
#  'post20_img2.jpg',
#  'post20_img3.jpg',
#  'post20_img4.jpg',
#  'post20_img6.jpg',
#  'post20_img7.jpg',
#  'post20_img5.jpg',
#  'post19_img1.jpg',
#  'post19_img2.jpg',
#  'post19_img3.jpg',
#  'post19_img4.jpg',
#  'post18_img1.jpg',
#  'post18_img2.jpg',
#  'post18_img3.jpg',
#  'post18_img4.jpg',
#  'post18_img5.jpg',
#  'post16_img1.jpg',
#  'post16_img3.jpg',
#  'post16_img2.jpg',
#  'post16_img4.jpg',
#  'post16_img5.jpg',
#  'post16_img6.jpg',
#  'post13_img1.jpg',
#  'post13_img2.jpg',
#  'post13_img3.jpg',
#  'post13_img5.jpg',
#  'post13_img6.jpg',
#  'post13_img4.jpg',
#  'post12_img1.jpg',
#  'post12_img3.jpg',
#  'post12_img2.jpg',
#  'post10_img1.jpg',
#  'post10_img3.jpg',
#  'post10_img2.jpg',
#  'post10_img4.jpg',
#  'post9_img1.jpg',
#  'post9_img5.jpg',
#  'post9_img2.jpg',
#  'post9_img4.jpg',
#  'post9_img7.jpg',
#  'post9_img6.jpg',
#  'post9_img9.jpg',
#  'post9_img8.jpg',
#  'post9_img3.jpg',
#  'post6_img1.jpg',
#  'post6_img2.jpg',
#  'post6_img3.jpg',
#  'post4_img4.jpg',
#  'post4_img1.jpg',
#  'post4_img3.jpg',
#  'post4_img2.jpg',
#  'post3_img2.jpg',
#  'post3_img1.jpg',
#  'post3_img3.jpg']

# %%
def is_css3_color(instance):
        if instance.lower() in webcolors.css3_names_to_hex:
            return True
        return is_css_color_code(instance)

# %%
def check_color(color_name):
    #Define colors
    PINK = ['pink', 'lightpink', 'hotpink', 'deeppink', 'palevioletred', 'mediumvioletred']
    PURPLE = ['lavender', 'thistle', 'plum', 'orchid', 'violet', 'fuchsia', 'magenta', 'mediumorchid', 'darkorchid', 'darkviolet', 'blueviolet', 'darkmagenta',  'purple',  'mediumpurple',  'mediumslateblue', 'slateblue', 'darkslateblue', 'rebeccapurple',  'indigo']
    RED = ['lightsalmon', 'salmon', 'darksalmon', 'lightcoral', 'indianred', 'crimson', 'red', 'firebrick', 'darkred']
    ORANGE = ['orange', 'darkorange', 'coral', 'tomato', 'orangered']
    YELLOW = ['gold', 'yellow', 'lightyellow', 'lemonchiffon', 'lightgoldenrodyellow', 'papayawhip', 'moccasin', 'peachpuff',  'palegoldenrod', 'khaki', 'darkkhaki']
    GREEN = ['greenyellow', 'chartreuse',  'lawngreen', 'lime',  'limegreen', 'palegreen', 'lightgreen', 'mediumspringgreen', 'springgreen', 'mediumseagreen', 'seagreen', 'forestgreen', 'green', 'darkgreen', 'yellowgreen', 'olivedrab', 'darkolivegreen', 'mediumaquamarine', 'darkseagreen', 'lightseagreen',  'darkcyan',  'teal']
    CYAN= ['aqua', 'cyan', "darkslategray",'lightcyan', 'paleturquoise', 'aquamarine', 'turquoise', 'mediumturquoise', 'darkturquoise']
    BLUE=  ['cadetblue', 'steelblue', 'lightsteelblue', 'lightblue', 'powderblue', 'lightskyblue',  'skyblue', 'cornflowerblue', 'deepskyblue', 'dodgerblue', 'royalblue', 'blue', 'mediumblue',  'darkblue',  'navy',  'MidnightBlue']
    BROWN =  ['cornsilk', 'blanchedalmond', 'bisque', 'navajowhite', 'wheat', 'burlywood', 'tan', 'rosybrown', 'sandybrown', 'goldenrod', 'darkgoldenrod',  'peru', 'chocolate', 'olive', 'saddlebrown',  'sienna',  'brown', 'maroon']
    WHITE = ['white', 'snow', 'honeydew', 'mintcream', 'azure', 'aliceblue',  'ghostwhite', 'whitesmoke', 'seashell',  'beige', 'oldlace',  'floralwhite',  'ivory', 'antiquewhite',  'linen', 'lavenderblush',  'mistyrose']
    GREY = [ 'gainsboro', 'lightgray', 'silver', 'darkgray', 'dimgray',  'gray',  'lightslategray', 'slategray', 'arkslategray', 'black']

    #Check cases
    if color_name in PINK:
        return 'pink'
    elif color_name in PURPLE:
        return 'purple'
    elif color_name in RED:
        return 'red'
    elif color_name in ORANGE:
        return 'orange'
    elif color_name in YELLOW:
        return 'yellow'
    elif color_name in GREEN:
        return 'green'
    elif color_name in CYAN:
        return 'cyan'
    elif color_name in BLUE:
        return 'blue'
    elif color_name in BROWN:
        return 'brown'
    elif color_name in WHITE:
        return 'white'
    elif color_name in GREY:
        return 'grey'
    else:
        return 'No color found'

# %%
# !pip install webcolors
# Out:
# Requirement already satisfied: webcolors in /usr/local/lib/python3.11/dist-packages (24.11.1)

# %%
# !pip show webcolors
# Out:
# Name: webcolors
# Version: 24.11.1
# Summary: A library for working with the color formats defined by HTML and CSS.
# Home-page:
# Author: James Bennett
# Author-email:
# License: BSD-3-Clause
# Location: /usr/local/lib/python3.11/dist-packages
# Requires:
# Required-by: music21

# %%
import webcolors
print(dir(webcolors))
# Out:
# ['CSS2', 'CSS21', 'CSS3', 'HTML4', 'HTML5SimpleColor', 'IntTuple', 'IntegerRGB', 'PercentRGB', 'PercentTuple', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '_conversion', '_definitions', '_html5', '_normalization', '_types', 'hex_to_name', 'hex_to_rgb', 'hex_to_rgb_percent', 'html5_parse_legacy_color', 'html5_parse_simple_color', 'html5_serialize_simple_color', 'name_to_hex', 'name_to_rgb', 'name_to_rgb_percent', 'names', 'normalize_hex', 'normalize_integer_triplet', 'normalize_percent_triplet', 'rgb_percent_to_hex', 'rgb_percent_to_name', 'rgb_percent_to_rgb', 'rgb_to_hex', 'rgb_to_name', 'rgb_to_rgb_percent']

# %%
print(webcolors.name_to_hex("red"))
# Out:
# #ff0000

# %%
image_names = []
color_names = []
total_images = len(local_images)
for idx, imageFile in enumerate(local_images, start=1):
    print(f"Processing image {idx}/{total_images}: {imageFile}")

    color_thief = ColorThief(os.path.join(rekog_images_dir, imageFile))
    dominant_color = color_thief.get_color(quality=1)
    rms_lst = []

    for color_name in webcolors.names():
        try:
            hex_val = webcolors.name_to_hex(color_name)
            cur_clr = webcolors.hex_to_rgb(hex_val)
            rmse = np.sqrt(mean_squared_error(dominant_color, cur_clr))
            rms_lst.append((color_name, rmse))
        except ValueError:
            continue

    # Get closest color by RMSE
    closest_color = min(rms_lst, key=lambda x: x[1])[0]
    grouped_color = check_color(closest_color)  # your categorization (e.g., pink, red, etc.)

    image_names.append(imageFile)
    color_names.append(grouped_color.lower())  # match lowercase pattern

# Create DataFrame with correct columns
output_colors = pd.DataFrame({
    'image_id': image_names,
    'dominantColor': color_names
})
# Out:
# Processing image 1/267: post215_img2.jpg
# Processing image 2/267: post215_img1.jpg
# Processing image 3/267: post215_img3.jpg
# Processing image 4/267: post210_img1.jpg
# Processing image 5/267: post210_img2.jpg
# Processing image 6/267: post210_img3.jpg
# Processing image 7/267: post210_img4.jpg
# Processing image 8/267: post210_img5.jpg
# Processing image 9/267: post208_img3.jpg
# Processing image 10/267: post208_img1.jpg
# Processing image 11/267: post208_img2.jpg
# Processing image 12/267: post208_img5.jpg
# Processing image 13/267: post208_img4.jpg
# Processing image 14/267: post198_img1.jpg
# Processing image 15/267: post197_img2.jpg
# Processing image 16/267: post197_img1.jpg
# Processing image 17/267: post197_img6.jpg
# Processing image 18/267: post197_img5.jpg
# Processing image 19/267: post197_img3.jpg
# Processing image 20/267: post197_img4.jpg
# Processing image 21/267: post197_img7.jpg
# Processing image 22/267: post196_img1.jpg
# Processing image 23/267: post196_img2.jpg
# Processing image 24/267: post196_img3.jpg
# Processing image 25/267: post196_img4.jpg
# Processing image 26/267: post196_img5.jpg
# Processing image 27/267: post195_img3.jpg
# Processing image 28/267: post195_img2.jpg
# Processing image 29/267: post195_img4.jpg
# Processing image 30/267: post195_img1.jpg
# Processing image 31/267: post195_img5.jpg
# Processing image 32/267: post193_img1.jpg
# Processing image 33/267: post193_img3.jpg
# Processing image 34/267: post193_img2.jpg
# Processing image 35/267: post193_img4.jpg
# Processing image 36/267: post192_img1.jpg
# Processing image 37/267: post192_img2.jpg
# Processing image 38/267: post192_img3.jpg
# Processing image 39/267: post192_img4.jpg
# Processing image 40/267: post185_img1.jpg
# Processing image 41/267: post185_img2.jpg
# Processing image 42/267: post185_img4.jpg
# Processing image 43/267: post185_img3.jpg
# Processing image 44/267: post184_img1.jpg
# Processing image 45/267: post184_img2.jpg
# Processing image 46/267: post184_img3.jpg
# Processing image 47/267: post177_img1.jpg
# Processing image 48/267: post177_img2.jpg
# Processing image 49/267: post177_img3.jpg
# Processing image 50/267: post176_img1.jpg
# Processing image 51/267: post165_img1.jpg
# Processing image 52/267: post152_img1.jpg
# Processing image 53/267: post152_img2.jpg
# Processing image 54/267: post152_img4.jpg
# Processing image 55/267: post152_img3.jpg
# Processing image 56/267: post152_img5.jpg
# Processing image 57/267: post151_img1.jpg
# Processing image 58/267: post151_img2.jpg
# Processing image 59/267: post150_img3.jpg
# Processing image 60/267: post150_img1.jpg
# Processing image 61/267: post150_img4.jpg
# Processing image 62/267: post150_img2.jpg
# Processing image 63/267: post147_img2.jpg
# Processing image 64/267: post147_img1.jpg
# Processing image 65/267: post147_img3.jpg
# Processing image 66/267: post146_img1.jpg
# Processing image 67/267: post145_img1.jpg
# Processing image 68/267: post145_img2.jpg
# Processing image 69/267: post145_img3.jpg
# Processing image 70/267: post145_img4.jpg
# Processing image 71/267: post144_img1.jpg
# Processing image 72/267: post144_img2.jpg
# Processing image 73/267: post144_img3.jpg
# Processing image 74/267: post138_img1.jpg
# Processing image 75/267: post138_img2.jpg
# Processing image 76/267: post137_img2.jpg
# Processing image 77/267: post137_img1.jpg
# Processing image 78/267: post137_img4.jpg
# Processing image 79/267: post137_img5.jpg
# Processing image 80/267: post137_img3.jpg
# Processing image 81/267: post135_img1.jpg
# Processing image 82/267: post135_img2.jpg
# Processing image 83/267: post129_img1.jpg
# Processing image 84/267: post129_img2.jpg
# Processing image 85/267: post129_img3.jpg
# Processing image 86/267: post129_img4.jpg
# Processing image 87/267: post126_img1.jpg
# Processing image 88/267: post118_img1.jpg
# Processing image 89/267: post118_img2.jpg
# Processing image 90/267: post116_img2.jpg
# Processing image 91/267: post116_img1.jpg
# Processing image 92/267: post114_img1.jpg
# Processing image 93/267: post114_img2.jpg
# Processing image 94/267: post114_img3.jpg
# Processing image 95/267: post113_img1.jpg
# Processing image 96/267: post113_img2.jpg
# Processing image 97/267: post111_img2.jpg
# Processing image 98/267: post111_img3.jpg
# Processing image 99/267: post111_img1.jpg
# Processing image 100/267: post108_img2.jpg
# Processing image 101/267: post108_img3.jpg
# Processing image 102/267: post108_img1.jpg
# Processing image 103/267: post106_img1.jpg
# Processing image 104/267: post106_img2.jpg
# Processing image 105/267: post102_img1.jpg
# Processing image 106/267: post102_img2.jpg
# Processing image 107/267: post98_img3.jpg
# Processing image 108/267: post98_img1.jpg
# Processing image 109/267: post98_img2.jpg
# Processing image 110/267: post97_img1.jpg
# Processing image 111/267: post97_img2.jpg
# Processing image 112/267: post94_img1.jpg
# Processing image 113/267: post94_img2.jpg
# Processing image 114/267: post91_img4.jpg
# Processing image 115/267: post91_img3.jpg
# Processing image 116/267: post91_img2.jpg
# Processing image 117/267: post91_img1.jpg
# Processing image 118/267: post88_img1.jpg
# Processing image 119/267: post88_img2.jpg
# Processing image 120/267: post88_img3.jpg
# Processing image 121/267: post86_img1.jpg
# Processing image 122/267: post82_img1.jpg
# Processing image 123/267: post82_img2.jpg
# Processing image 124/267: post82_img4.jpg
# Processing image 125/267: post82_img6.jpg
# Processing image 126/267: post82_img7.jpg
# Processing image 127/267: post82_img5.jpg
# Processing image 128/267: post82_img3.jpg
# Processing image 129/267: post80_img3.jpg
# Processing image 130/267: post80_img1.jpg
# Processing image 131/267: post80_img2.jpg
# Processing image 132/267: post80_img4.jpg
# Processing image 133/267: post79_img1.jpg
# Processing image 134/267: post79_img2.jpg
# Processing image 135/267: post179_img1.jpg
# Processing image 136/267: post179_img5.jpg
# Processing image 137/267: post179_img2.jpg
# Processing image 138/267: post179_img4.jpg
# Processing image 139/267: post179_img3.jpg
# Processing image 140/267: post78_img3.jpg
# Processing image 141/267: post78_img2.jpg
# Processing image 142/267: post78_img1.jpg
# Processing image 143/267: post168_img1.jpg
# Processing image 144/267: post168_img2.jpg
# Processing image 145/267: post163_img2.jpg
# Processing image 146/267: post163_img1.jpg
# Processing image 147/267: post163_img3.jpg
# Processing image 148/267: post155_img1.jpg
# Processing image 149/267: post155_img2.jpg
# Processing image 150/267: post155_img3.jpg
# Processing image 151/267: post75_img1.jpg
# Processing image 152/267: post74_img1.jpg
# Processing image 153/267: post74_img3.jpg
# Processing image 154/267: post74_img2.jpg
# Processing image 155/267: post68_img3.jpg
# Processing image 156/267: post68_img1.jpg
# Processing image 157/267: post68_img2.jpg
# Processing image 158/267: post65_img1.jpg
# Processing image 159/267: post65_img2.jpg
# Processing image 160/267: post65_img3.jpg
# Processing image 161/267: post62_img2.jpg
# Processing image 162/267: post62_img4.jpg
# Processing image 163/267: post62_img3.jpg
# Processing image 164/267: post62_img1.jpg
# Processing image 165/267: post52_img1.jpg
# Processing image 166/267: post52_img3.jpg
# Processing image 167/267: post52_img4.jpg
# Processing image 168/267: post52_img2.jpg
# Processing image 169/267: post52_img7.jpg
# Processing image 170/267: post52_img5.jpg
# Processing image 171/267: post52_img8.jpg
# Processing image 172/267: post52_img6.jpg
# Processing image 173/267: post52_img9.jpg
# Processing image 174/267: post52_img10.jpg
# Processing image 175/267: post49_img1.jpg
# Processing image 176/267: post49_img4.jpg
# Processing image 177/267: post49_img3.jpg
# Processing image 178/267: post49_img2.jpg
# Processing image 179/267: post50_img1.jpg
# Processing image 180/267: post48_img2.jpg
# Processing image 181/267: post48_img1.jpg
# Processing image 182/267: post47_img1.jpg
# Processing image 183/267: post47_img2.jpg
# Processing image 184/267: post47_img3.jpg
# Processing image 185/267: post46_img3.jpg
# Processing image 186/267: post46_img1.jpg
# Processing image 187/267: post46_img2.jpg
# Processing image 188/267: post41_img1.jpg
# Processing image 189/267: post41_img3.jpg
# Processing image 190/267: post41_img2.jpg
# Processing image 191/267: post38_img1.jpg
# Processing image 192/267: post38_img3.jpg
# Processing image 193/267: post38_img4.jpg
# Processing image 194/267: post38_img2.jpg
# Processing image 195/267: post35_img1.jpg
# Processing image 196/267: post35_img2.jpg
# Processing image 197/267: post33_img2.jpg
# Processing image 198/267: post33_img3.jpg
# Processing image 199/267: post33_img1.jpg
# Processing image 200/267: post32_img2.jpg
# Processing image 201/267: post32_img1.jpg
# Processing image 202/267: post32_img3.jpg
# Processing image 203/267: post32_img4.jpg
# Processing image 204/267: post31_img2.jpg
# Processing image 205/267: post31_img3.jpg
# Processing image 206/267: post31_img1.jpg
# Processing image 207/267: post28_img3.jpg
# Processing image 208/267: post28_img4.jpg
# Processing image 209/267: post28_img2.jpg
# Processing image 210/267: post28_img1.jpg
# Processing image 211/267: post26_img1.jpg
# Processing image 212/267: post26_img2.jpg
# Processing image 213/267: post26_img3.jpg
# Processing image 214/267: post20_img1.jpg
# Processing image 215/267: post20_img2.jpg
# Processing image 216/267: post20_img3.jpg
# Processing image 217/267: post20_img4.jpg
# Processing image 218/267: post20_img6.jpg
# Processing image 219/267: post20_img7.jpg
# Processing image 220/267: post20_img5.jpg
# Processing image 221/267: post19_img1.jpg
# Processing image 222/267: post19_img2.jpg
# Processing image 223/267: post19_img3.jpg
# Processing image 224/267: post19_img4.jpg
# Processing image 225/267: post18_img1.jpg
# Processing image 226/267: post18_img2.jpg
# Processing image 227/267: post18_img3.jpg
# Processing image 228/267: post18_img4.jpg
# Processing image 229/267: post18_img5.jpg
# Processing image 230/267: post16_img1.jpg
# Processing image 231/267: post16_img3.jpg
# Processing image 232/267: post16_img2.jpg
# Processing image 233/267: post16_img4.jpg
# Processing image 234/267: post16_img5.jpg
# Processing image 235/267: post16_img6.jpg
# Processing image 236/267: post13_img1.jpg
# Processing image 237/267: post13_img2.jpg
# Processing image 238/267: post13_img3.jpg
# Processing image 239/267: post13_img5.jpg
# Processing image 240/267: post13_img6.jpg
# Processing image 241/267: post13_img4.jpg
# Processing image 242/267: post12_img1.jpg
# Processing image 243/267: post12_img3.jpg
# Processing image 244/267: post12_img2.jpg
# Processing image 245/267: post10_img1.jpg
# Processing image 246/267: post10_img3.jpg
# Processing image 247/267: post10_img2.jpg
# Processing image 248/267: post10_img4.jpg
# Processing image 249/267: post9_img1.jpg
# Processing image 250/267: post9_img5.jpg
# Processing image 251/267: post9_img2.jpg
# Processing image 252/267: post9_img4.jpg
# Processing image 253/267: post9_img7.jpg
# Processing image 254/267: post9_img6.jpg
# Processing image 255/267: post9_img9.jpg
# Processing image 256/267: post9_img8.jpg
# Processing image 257/267: post9_img3.jpg
# Processing image 258/267: post6_img1.jpg
# Processing image 259/267: post6_img2.jpg
# Processing image 260/267: post6_img3.jpg
# Processing image 261/267: post4_img4.jpg
# Processing image 262/267: post4_img1.jpg
# Processing image 263/267: post4_img3.jpg
# Processing image 264/267: post4_img2.jpg
# Processing image 265/267: post3_img2.jpg
# Processing image 266/267: post3_img1.jpg
# Processing image 267/267: post3_img3.jpg

# %%
output_colors = output_colors.to_csv(f'/content/drive/Shareddrives/DS340W Project/Dataset NEW*/{username}/{username}_colors.csv', index=False)
