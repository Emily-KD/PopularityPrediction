# %% [markdown]
# <a href="https://colab.research.google.com/github/Emily-KD/PopularityPrediction/blob/main/Data/yslbeauty/Amazon-Rekognition/yslbeauty_AR_Labels_%26_Faces.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.37.37-py3-none-any.whl.metadata (6.7 kB)
# Collecting botocore<1.38.0,>=1.37.37 (from boto3)
#   Downloading botocore-1.37.37-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.12.0,>=0.11.0 (from boto3)
#   Downloading s3transfer-0.11.5-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore<1.38.0,>=1.37.37->boto3) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<1.38.0,>=1.37.37->boto3) (2.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.38.0,>=1.37.37->boto3) (1.17.0)
# Downloading boto3-1.37.37-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 3.6 MB/s eta 0:00:00
# Downloading botocore-1.37.37-py3-none-any.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 106.9 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.11.5-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 7.8 MB/s eta 0:00:00
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.37.37 botocore-1.37.37 jmespath-1.0.1 s3transfer-0.11.5

# %%
import csv
import boto3
import pickle
import os
import json
import pandas as pd

# %%
ls
# Out:
# drive/  sample_data/

# %%
########### Paths
username = "yslbeauty"
# Path to where your want to save the resulting labels
rekog_results_dir = f"/content/drive/Shareddrives/DS340W Project/Dataset NEW*/{username}/"

# Path to where your images are
rekog_images_dir = f"/content/drive/Shareddrives/DS340W Project/Dataset NEW*/{username}/{username}_images_2024_2025/"

# %%
# Read in your personal keys
personal_access_key = "AKIA6JKEXWET5465SAMQ"
secret_access_key = "Q3HEcBy+jO7ep4tL9It/7MEoFhlBxy9R2QpRjbWv"

# Initialize the boto client to access the Rekogniton api
client=boto3.client('rekognition','us-east-1', # or choose the best region for your work,
                                               # e.g. the location of your S3 bucket if using that method to store images
                    aws_access_key_id = personal_access_key,
                    aws_secret_access_key = secret_access_key)

# %%
# Make a list of all the images in the rekog_data_dir you created
local_images = os.listdir(rekog_images_dir)
#local_images = [str(p) for p in rekog_images_dir]

# %%
from PIL import Image
import io

def resize_if_needed(image_path, max_size=5242880):
    with open(image_path, 'rb') as f:
        img_bytes = f.read()

    if len(img_bytes) < max_size:
        return img_bytes

    # Resize the image using PIL
    with Image.open(image_path) as img:
        # Reduce resolution while maintaining aspect ratio
        img.thumbnail((1024, 1024))  # tweak if needed
        buf = io.BytesIO()
        img.save(buf, format='JPEG')
        buf.seek(0)
        return buf.read()

# %%
#### Beauty-focused label extraction
holder_labels = []

for imageFile in local_images:
    image_path = rekog_images_dir + imageFile
    try:
        image_bytes = resize_if_needed(image_path)
        response = client.detect_labels(Image={'Bytes': image_bytes})
    except Exception as e:
        print(f"❌ Skipping {imageFile}: {e}")
        continue

    print('Detected labels for ' + imageFile)

    labels = []
    temp_dict = {
        "image_id": imageFile,
        "has_makeup": False,
        "has_beauty_product": False,
        "has_logo_or_branding": False,
        "is_fashion_related": False,
        "is_beauty_scene": False,
        "has_text": False,
        "close_up": False,
        "indoors": False,
        "outdoors": False
    }

    for label in response.get('Labels', []):
        if label.get('Confidence', 0) >= 70:
            labels.append(label.get('Name'))

    # Category dictionaries
    makeup_labels = ['Makeup', 'Cosmetics', 'Lipstick', 'Eyeliner', 'Blush', 'Eyeshadow']
    product_labels = ['Cosmetics', 'Bottle', 'Container', 'Toiletry', 'Skincare', 'Cream']
    brand_labels = ['Label', 'Logo', 'Trademark', 'Packaging']
    fashion_labels = ['Clothing', 'Apparel', 'Dress', 'Fashion', 'Footwear', 'Shoes', 'Bag']
    scene_labels = ['Beauty Salon', 'Mirror', 'Vanity', 'Makeup Room']
    text_labels = ['Text', 'Advertisement', 'Poster', 'Font', 'Brochure', 'Paper']

    # Binary feature assignments
    if any(lbl in labels for lbl in makeup_labels):
        temp_dict["has_makeup"] = True
    if any(lbl in labels for lbl in product_labels):
        temp_dict["has_beauty_product"] = True
    if any(lbl in labels for lbl in brand_labels):
        temp_dict["has_logo_or_branding"] = True
    if any(lbl in labels for lbl in fashion_labels):
        temp_dict["is_fashion_related"] = True
    if any(lbl in labels for lbl in scene_labels):
        temp_dict["is_beauty_scene"] = True
    if any(lbl in labels for lbl in text_labels):
        temp_dict["has_text"] = True
    if 'Portrait' in labels:
        temp_dict["close_up"] = True
    if 'Indoors' in labels:
        temp_dict["indoors"] = True
    if 'Outdoors' in labels:
        temp_dict["outdoors"] = True

    holder_labels.append(temp_dict)
    print(labels)  # Optional log
# Out:
# Detected labels for post215_img2.jpg
# ['Clothing', 'Hosiery', 'Pantyhose', 'Adult', 'Female', 'Person', 'Woman']
# Detected labels for post215_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post215_img3.jpg
# ['Camera', 'Electronics', 'Palm Tree', 'Plant', 'Tree', 'Clothing', 'Glove', 'Person', 'Photography', 'Photoshoot']
# Detected labels for post210_img1.jpg
# ['Clothing', 'Coat', 'Jacket', 'Adult', 'Female', 'Person', 'Woman', 'Footwear', 'High Heel', 'Shoe', 'Face', 'Head', 'Hosiery', 'Accessories', 'Jewelry', 'Necklace']
# Detected labels for post210_img2.jpg
# ['Cosmetics', 'Lipstick', 'Device', 'Screwdriver', 'Tool', 'Makeup', 'Head', 'Person']
# Detected labels for post210_img3.jpg
# ['Clothing', 'Coat', 'Jacket', 'Costume', 'Person', 'Formal Wear', 'Face', 'Head', 'Fashion', 'Dress', 'Photography', 'Portrait', 'Footwear', 'Shoe']
# Detected labels for post210_img4.jpg
# ['Cosmetics', 'Lipstick', 'Makeup']
# Detected labels for post210_img5.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Smoke Pipe', 'Alcohol', 'Beverage', 'Skin', 'Tattoo', 'Drinking', 'Drinking Alcohol']
# Detected labels for post208_img3.jpg
# ['Person', 'Sitting', 'Adult', 'Female', 'Woman', 'Urban', 'Furniture']
# Detected labels for post208_img1.jpg
# ['Person', 'Sitting', 'Clothing', 'Glove', 'Adult', 'Female', 'Woman', 'Furniture']
# Detected labels for post208_img2.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Cosmetics', 'Lipstick', 'Head', 'Face', 'Makeup']
# Detected labels for post208_img5.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post208_img4.jpg
# ['Adult', 'Male', 'Man', 'Person', 'Female', 'Woman', 'Cosmetics', 'Makeup']
# Detected labels for post198_img1.jpg
# ['Advertisement', 'Architecture', 'Building', 'Spire', 'Tower', 'Poster', 'Art', 'Collage', 'Balloon', 'Person', 'City']
# Detected labels for post197_img2.jpg
# ['Blazer', 'Clothing', 'Coat', 'Jacket', 'Adult', 'Female', 'Person', 'Woman', 'Formal Wear', 'Suit', 'Head', 'Face', 'Photography', 'Portrait', 'Pants', 'Accessories', 'Belt', 'Happy', 'Blouse', 'Dress', 'People', 'Laughing']
# Detected labels for post197_img1.jpg
# ['Female', 'Girl', 'Person', 'Teen', 'Symbol', 'Sitting', 'Clothing', 'Sleeve', 'Text']
# Detected labels for post197_img6.jpg
# ['Test Tube']
# Detected labels for post197_img5.jpg
# ['Clothing', 'Coat', 'Blazer', 'Jacket', 'Adult', 'Female', 'Person', 'Woman', 'Overcoat', 'Formal Wear', 'Suit', 'Face', 'Head']
# Detected labels for post197_img3.jpg
# ['Head', 'Person', 'Face', 'Adult', 'Female', 'Woman', 'Clothing', 'Coat', 'Jacket', 'Performer', 'Solo Performance']
# Detected labels for post197_img4.jpg
# ['Blonde', 'Hair', 'Person', 'Adult', 'Female', 'Woman', 'People', 'Clothing', 'Formal Wear', 'Suit', 'Balloon', 'Pixie Cut', 'Head']
# Detected labels for post197_img7.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Hairdresser', 'Haircut']
# Detected labels for post196_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Hair', 'Head', 'Face', 'Red Hair']
# Detected labels for post196_img2.jpg
# ['Blazer', 'Clothing', 'Coat', 'Jacket', 'Formal Wear', 'Suit', 'Face', 'Head', 'Person', 'Photography', 'Portrait']
# Detected labels for post196_img3.jpg
# ['Clothing', 'Pants', 'Footwear', 'Shoe', 'Adult', 'Female', 'Person', 'Woman', 'High Heel', 'Coat', 'Hair', 'Jeans', 'Face', 'Head', 'Photography', 'Portrait']
# Detected labels for post196_img4.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Blazer', 'Clothing', 'Coat', 'Jacket', 'Pants', 'Happy', 'Smile', 'Business Card', 'Paper', 'Text', 'Hair', 'Adult', 'Male', 'Man', 'Formal Wear', 'Suit', 'Fashion']
# Detected labels for post196_img5.jpg
# ['Business Card', 'Paper', 'Text', 'Body Part', 'Finger', 'Hand', 'Person', 'Adult', 'Female', 'Woman']
# Detected labels for post195_img4 (1).jpg
# ['Clothing', 'Sleeve', 'Head', 'Person', 'Face', 'Cosmetics', 'Lipstick', 'Black Hair', 'Hair', 'Performer', 'Solo Performance', 'Blazer', 'Coat', 'Jacket', 'Pants']
# Detected labels for post195_img3.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Clothing', 'Coat', 'Hosiery']
# Detected labels for post195_img2.jpg
# ['Clothing', 'Coat', 'Jacket', 'Adult', 'Female', 'Person', 'Woman', 'Standing', 'Floor']
# Detected labels for post195_img4.jpg
# ['Clothing', 'Sleeve', 'Head', 'Person', 'Face', 'Cosmetics', 'Lipstick', 'Black Hair', 'Hair', 'Performer', 'Solo Performance', 'Blazer', 'Coat', 'Jacket', 'Pants']
# Detected labels for post195_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post195_img5.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Black Hair', 'Hair', 'Head', 'Face', 'Text', 'Business Card', 'Paper']
# Detected labels for post193_img1.jpg
# ['Blonde', 'Hair', 'Person', 'Cosmetics', 'Lipstick', 'Clothing', 'Coat', 'Jacket', 'Face', 'Head']
# Detected labels for post193_img3.jpg
# ['Clothing', 'Coat', 'Pants', 'Jacket', 'Blazer', 'Person', 'Blonde', 'Hair', 'Jeans']
# Detected labels for post193_img2.jpg
# ['Clothing', 'Coat', 'Jacket', 'Adult', 'Male', 'Man', 'Person', 'Pants', 'Standing', 'Symbol', 'Floor', 'Text', 'Blazer']
# Detected labels for post193_img4.jpg
# ['Blonde', 'Hair', 'Person', 'Bottle', 'Cosmetics', 'Perfume', 'Pixie Cut']
# Detected labels for post192_img1.jpg
# ['Blazer', 'Clothing', 'Coat', 'Jacket', 'Long Sleeve', 'Sleeve', 'Formal Wear', 'Suit', 'Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Photography', 'Portrait']
# Detected labels for post192_img2.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Cosmetics', 'Conversation', 'Lipstick', 'Head']
# Detected labels for post192_img3.jpg
# ['Clothing', 'Formal Wear', 'Suit', 'Blazer', 'Coat', 'Jacket', 'Face', 'Head', 'Person', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Fashion', 'Accessories', 'Tie', 'Hair']
# Detected labels for post192_img4.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Cosmetics', 'Festival', 'Hanukkah Menorah']
# Detected labels for post185_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post185_img2.jpg
# ['Flower', 'Petal', 'Plant', 'Anther', 'Geranium', 'Rose', 'Gladiolus']
# Detected labels for post185_img4.jpg
# ['Person', 'Head']
# Detected labels for post185_img3.jpg
# ['Smoke', 'Adult', 'Bride', 'Female', 'Person', 'Wedding', 'Woman']
# Detected labels for post184_img1.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Clothing', 'Dress', 'Black Hair', 'Hair', 'Formal Wear', 'Skin', 'Tattoo', 'Evening Dress', 'Fashion']
# Detected labels for post184_img2.jpg
# ['Publication', 'Adult', 'Female', 'Person', 'Woman', 'Blackboard', 'Magazine', 'Clothing', 'Footwear', 'High Heel', 'Shoe', 'Book']
# Detected labels for post184_img3.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Clothing', 'Long Sleeve', 'Sleeve', 'Hair', 'Red Hair']
# Detected labels for post177_img1.jpg
# ['Accessories', 'Earring', 'Jewelry', 'Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Body Part', 'Shoulder', 'Skin', 'Photography', 'Portrait']
# Detected labels for post177_img2.jpg
# ['Leisure Activities', 'Person', 'Sport', 'Swimming', 'Water', 'Water Sports', 'Nature', 'Outdoors', 'Sea', 'Adult', 'Female', 'Woman', 'Animal', 'Sea Life', 'Face', 'Head', 'Bird', 'Mammal']
# Detected labels for post177_img3.jpg
# ['Photo Frame', 'Adult', 'Female', 'Person', 'Woman', 'Face', 'Head']
# Detected labels for post176_img1.jpg
# ['Head', 'Person', 'Face', 'Cosmetics', 'Lipstick']
# Detected labels for post165_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post152_img1.jpg
# ['Person', 'Standing', 'Adult', 'Male', 'Man', 'Clothing', 'Coat']
# Detected labels for post152_img2.jpg
# ['Cosmetics', 'Adult', 'Female', 'Person', 'Woman', 'Makeup', 'Male', 'Man']
# Detected labels for post152_img4.jpg
# ['Clothing', 'Sleeve', 'Hair', 'Person', 'Bottle', 'Cosmetics', 'Perfume', 'Crew Cut', 'Adult', 'Male', 'Man']
# Detected labels for post152_img3.jpg
# ['Animal', 'Bee', 'Insect', 'Invertebrate', 'Wasp', 'Accessories', 'Wallet']
# Detected labels for post152_img5.jpg
# ['Face', 'Head', 'Person', 'Accessories', 'Wallet', 'Cosmetics', 'Makeup']
# Detected labels for post151_img1.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Body Part', 'Neck', 'Adult', 'Female', 'Woman', 'Hair']
# Detected labels for post151_img2.jpg
# ['Accessories', 'Box', 'Wallet']
# Detected labels for post150_img3.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post150_img1.jpg
# ['Sink', 'Sink Faucet', 'Pen', 'Art', 'Drawing']
# Detected labels for post150_img4.jpg
# ['Clothing', 'Formal Wear', 'Suit', 'Coat', 'Blazer', 'Jacket', 'Accessories', 'Tie', 'Tuxedo', 'Adult', 'Male', 'Man', 'Person', 'Shirt', 'Face', 'Head', 'People']
# Detected labels for post150_img2.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Clothing', 'Coat', 'Lighting', 'Photography', 'Electronics', 'Glove']
# Detected labels for post147_img2.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Fashion', 'Cosmetics', 'Lipstick', 'Clothing', 'Dress', 'Head', 'Face']
# Detected labels for post147_img1.jpg
# ['Symbol', 'Adult', 'Female', 'Person', 'Woman', 'Balloon', 'Text', 'Love Heart Symbol']
# Detected labels for post147_img3.jpg
# ['Female', 'Girl', 'Person', 'Teen', 'Text', 'Business Card', 'Paper']
# Detected labels for post146_img1.jpg
# ['Adult', 'Male', 'Man', 'Person', 'Formal Wear', 'Furniture', 'Table', 'Clothing', 'Suit', 'Face', 'Head']
# Detected labels for post145_img1.jpg
# ['Blonde', 'Hair', 'Person', 'Head', 'Cosmetics', 'Lipstick', 'Face', 'Body Part', 'Finger', 'Hand', 'Photography', 'Portrait']
# Detected labels for post145_img2.jpg
# ['Body Part', 'Mouth', 'Person', 'Baby', 'Berry', 'Food', 'Fruit', 'Plant', 'Produce', 'Eating', 'Raspberry']
# Detected labels for post145_img3.jpg
# ['Head', 'Person', 'Face', 'Adult', 'Female', 'Woman', 'Body Part', 'Neck', 'Accessories', 'Earring', 'Jewelry']
# Detected labels for post145_img4.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post144_img1.jpg
# ['Performer', 'Person', 'Solo Performance', 'Clothing', 'Shorts', 'Face', 'Head', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Fashion', 'Skin', 'Tattoo', 'Appliance', 'Ceiling Fan', 'Device', 'Electrical Device', 'Body Part', 'Finger', 'Hand', 'Dancing', 'Leisure Activities']
# Detected labels for post144_img2.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Adult', 'Female', 'Woman', 'Cosmetics', 'Lipstick', 'Accessories', 'Jewelry', 'Necklace', 'Clothing', 'Lingerie', 'Underwear']
# Detected labels for post144_img3.jpg
# ['Performer', 'Person', 'Solo Performance', 'Electrical Device', 'Microphone', 'Adult', 'Female', 'Woman', 'Leisure Activities', 'Music', 'Musical Instrument', 'Musician', 'Singing', 'Head', 'Face']
# Detected labels for post138_img1.jpg
# ['Cosmetics', 'Lipstick', 'Head', 'Person', 'Face', 'Smoke']
# Detected labels for post138_img2.jpg
# ['Cosmetics', 'Lipstick', 'Brown Hair', 'Hair', 'Person', 'Hairdresser', 'Haircut']
# Detected labels for post137_img2.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Photography', 'Head', 'Person', 'Face', 'Beverage', 'Adult', 'Female', 'Woman', 'Alcohol', 'Drinking', 'Drinking Alcohol']
# Detected labels for post137_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Head', 'Person', 'Face']
# Detected labels for post137_img4.jpg
# ['Clothing', 'Sleeve', 'Face', 'Head', 'Person', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Long Sleeve', 'Blouse', 'Formal Wear', 'Fashion', 'Happy', 'Smile']
# Detected labels for post137_img5.jpg
# ['Face', 'Head', 'Person', 'Smelling', 'Flower', 'Petal', 'Plant', 'Adult', 'Female', 'Woman']
# Detected labels for post137_img3.jpg
# ['Cosmetics', 'Bottle', 'Perfume', 'Nail Polish']
# Detected labels for post135_img1.jpg
# ['Head', 'Person', 'Face', 'Bottle', 'Cosmetics', 'Perfume', 'Accessories', 'Jewelry', 'Necklace', 'Photography', 'Portrait', 'Body Part', 'Finger', 'Hand', 'Neck', 'Adult', 'Female', 'Woman']
# Detected labels for post135_img2.jpg
# ['Head', 'Person', 'Face', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Flower', 'Plant']
# Detected labels for post129_img1.jpg
# ['Blade', 'Dagger', 'Knife', 'Weapon']
# Detected labels for post129_img2.jpg
# ['Blade', 'Dagger', 'Knife', 'Weapon', 'Home Damage']
# Detected labels for post129_img3.jpg
# ['Blade', 'Dagger', 'Knife', 'Weapon', 'Home Damage']
# Detected labels for post129_img4.jpg
# ['Blade', 'Dagger', 'Knife', 'Weapon', 'Home Damage']
# Detected labels for post126_img1.jpg
# ['Photography', 'Body Part', 'Finger', 'Hand', 'Person', 'Face', 'Head', 'Portrait', 'Bottle', 'Cosmetics', 'Perfume', 'Adult', 'Male', 'Man']
# Detected labels for post118_img1.jpg
# ['Black Hair', 'Hair', 'Person', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Photography', 'Portrait', 'Body Part', 'Neck', 'Clothing', 'Sleeve', 'Blade', 'Dagger', 'Knife', 'Weapon']
# Detected labels for post118_img2.jpg
# ['Black Hair', 'Hair', 'Person', 'Face', 'Head', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman']
# Detected labels for post116_img2.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume']
# Detected labels for post116_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post114_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Bottle', 'Cosmetics', 'Perfume', 'Skin', 'Tattoo']
# Detected labels for post114_img2.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Head', 'Person', 'Face']
# Detected labels for post114_img3.jpg
# ['Head', 'Person', 'Face', 'Adult', 'Bride', 'Female', 'Wedding', 'Woman', 'Accessories', 'Earring', 'Jewelry', 'Flower', 'Plant', 'Skin']
# Detected labels for post113_img1.jpg
# ['Clothing', 'Coat', 'Jacket', 'Adult', 'Male', 'Man', 'Person']
# Detected labels for post113_img2.jpg
# ['Head', 'Person', 'Face', 'Blonde', 'Hair', 'Body Part', 'Neck', 'Adult', 'Female', 'Woman', 'Pixie Cut', 'Clothing', 'Coat']
# Detected labels for post111_img2.jpg
# ['Photography', 'Face', 'Head', 'Person', 'Portrait', 'Body Part', 'Finger', 'Hand', 'Bottle', 'Cosmetics', 'Perfume', 'Sitting', 'Accessories', 'Jewelry', 'Necklace', 'Skin', 'Tattoo', 'Adult', 'Male', 'Man']
# Detected labels for post111_img3.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Clothing', 'Coat', 'Jacket', 'Blonde', 'Hair', 'Adult', 'Male', 'Man', 'Skin', 'Tattoo']
# Detected labels for post111_img1.jpg
# ['Cosmetics', 'Bottle', 'Person']
# Detected labels for post108_img2.jpg
# ['Body Part', 'Face', 'Head', 'Neck', 'Person', 'Photography', 'Portrait', 'Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post108_img3.jpg
# ['Body Part', 'Face', 'Head', 'Neck', 'Person', 'Adult', 'Male', 'Man', 'Shoulder']
# Detected labels for post108_img1.jpg
# ['Head', 'Person', 'Face', 'Skin', 'Adult', 'Male', 'Man', 'Body Part', 'Jaw']
# Detected labels for post106_img1.jpg
# ['Head', 'Person', 'Face', 'Photography', 'Portrait', 'Adult', 'Male', 'Man', 'Firearm', 'Weapon', 'Gun']
# Detected labels for post106_img2.jpg
# ['People', 'Person', 'Groupshot', 'Adult', 'Male', 'Man', 'Clothing', 'Coat', 'Head', 'Face', 'Indoors']
# Detected labels for post102_img1.jpg
# ['Clothing', 'Formal Wear', 'Suit', 'Body Part', 'Finger', 'Hand', 'Person', 'Face', 'Head', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Accessories', 'Jewelry', 'Ring', 'Bottle', 'Cosmetics', 'Perfume', 'Necklace', 'Sunglasses', 'Glasses', 'Black Hair', 'Hair', 'Coat', 'Jacket']
# Detected labels for post102_img2.jpg
# ['Clothing', 'Coat', 'Jacket', 'Blazer', 'Long Sleeve', 'Sleeve', 'Accessories', 'Sunglasses', 'Face', 'Head', 'Person', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Pants', 'Fashion', 'Formal Wear', 'Firearm', 'Gun', 'Handgun', 'Weapon', 'Suit']
# Detected labels for post98_img3.jpg
# ['Head', 'Person', 'Face', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Sad', 'Clothing', 'Coat']
# Detected labels for post98_img1.jpg
# ['Head', 'Person', 'Face', 'Adult', 'Female', 'Woman', 'Smoke', 'Photography', 'Portrait', 'Smoking']
# Detected labels for post98_img2.jpg
# ['Cosmetics', 'Lipstick', 'Head', 'Person', 'Face', 'Adult', 'Female', 'Woman']
# Detected labels for post97_img1 (1).jpg
# ['Cosmetics', 'Lipstick', 'Hair', 'Person', 'Makeup']
# Detected labels for post97_img1.jpg
# ['Cosmetics', 'Lipstick', 'Hair', 'Person', 'Makeup']
# Detected labels for post97_img2.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post94_img1.jpg
# ['Photography', 'Bottle', 'Cosmetics', 'Perfume', 'Face', 'Head', 'Person', 'Portrait']
# Detected labels for post94_img2.jpg
# ['Clothing', 'Sleeve', 'Bottle', 'Cosmetics', 'Perfume', 'Beverage', 'Alcohol', 'Drinking', 'Person', 'Drinking Alcohol', 'Boy', 'Male', 'Teen', 'Photography']
# Detected labels for post91_img4.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post91_img3.jpg
# ['Clothing', 'Coat', 'Jacket', 'Accessories', 'Sunglasses', 'Face', 'Head', 'Person', 'Photography', 'Portrait', 'Electronics', 'Phone', 'Adult', 'Male', 'Man', 'Mobile Phone', 'Bottle', 'Cosmetics', 'Perfume', 'Body Part', 'Finger', 'Hand', 'Hair']
# Detected labels for post91_img2.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Clothing', 'Coat', 'Jacket', 'Accessories', 'Sunglasses', 'Adult', 'Male', 'Man', 'Face', 'Head', 'Photography', 'Portrait', 'Jewelry', 'Ring']
# Detected labels for post91_img1.jpg
# ['Accessories', 'Bag', 'Handbag', 'Dressing Room', 'Indoors', 'Room', 'Window', 'Windowsill', 'Electronics', 'Speaker']
# Detected labels for post88_img1.jpg
# ['Face', 'Happy', 'Head', 'Person', 'Smile', 'Adult', 'Male', 'Man', 'Photography', 'Portrait', 'Hair', 'Gun', 'Weapon', 'Black Hair', 'Braid']
# Detected labels for post88_img2.jpg
# ['Person', 'Sitting', 'Clothing', 'Pants', 'Face', 'Head', 'Adult', 'Male', 'Man', 'Photography', 'Portrait', 'Happy', 'Smile', 'Hair', 'Accessories', 'Formal Wear', 'Tie']
# Detected labels for post88_img3.jpg
# ['Person', 'Sitting', 'Plant', 'Potted Plant', 'Clothing', 'Pants', 'Adult', 'Female', 'Woman', 'Accessories', 'Formal Wear', 'Tie', 'Electronics', 'Mobile Phone', 'Phone', 'Face', 'Head', 'Photography', 'Portrait', 'Furniture', 'Chair', 'Boot', 'Footwear', 'Shoe']
# Detected labels for post86_img1.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Body Part', 'Neck', 'Adult', 'Female', 'Woman', 'Black Hair', 'Hair', 'Skin']
# Detected labels for post82_img1.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Clothing', 'Sleeve', 'Dress', 'Formal Wear', 'Fashion']
# Detected labels for post82_img2.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Photobombing', 'Face', 'Head', 'Hair', 'Hairdresser']
# Detected labels for post82_img4.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Clothing', 'Dress', 'Formal Wear', 'Lady', 'Hair']
# Detected labels for post82_img6.jpg
# ['Head', 'Person', 'Face', 'Smoke', 'Body Part', 'Neck', 'Bottle', 'Cosmetics', 'Perfume', 'Lipstick']
# Detected labels for post82_img7.jpg
# ['Clothing', 'Sleeve', 'Face', 'Head', 'Person', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Standing', 'Hair', 'Dress', 'Black Hair']
# Detected labels for post82_img5.jpg
# ['Face', 'Head', 'Person', 'Adult', 'Female', 'Woman', 'Body Part', 'Neck']
# Detected labels for post82_img3.jpg
# ['Cosmetics', 'Adult', 'Female', 'Person', 'Woman', 'Makeup', 'Face', 'Head']
# Detected labels for post80_img3.jpg
# ['Cosmetics', 'Mailbox']
# Detected labels for post80_img1.jpg
# ['Text', 'Symbol', 'Number', 'Alphabet', 'Ampersand']
# Detected labels for post80_img2.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post80_img4.jpg
# ['Flower', 'Petal', 'Plant', 'Cosmetics', 'Lipstick', 'Symbol']
# Detected labels for post79_img1.jpg
# ['Accessories', 'Wallet', 'Envelope', 'Greeting Card', 'Mail']
# Detected labels for post79_img2.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post179_img1.jpg
# ['Business Card', 'Paper', 'Text']
# Detected labels for post179_img5.jpg
# ['Symbol', 'Balloon', 'Love Heart Symbol', 'Text']
# Detected labels for post179_img2.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Head', 'Face', 'Happy', 'Smile', 'Clothing', 'Coat', 'Cosmetics', 'Bottle', 'Perfume']
# Detected labels for post179_img4.jpg
# ['Indoors', 'Interior Design', 'Shop', 'Furniture', 'Table', 'Desk']
# Detected labels for post179_img3.jpg
# ['Advertisement', 'Architecture', 'Building', 'Sword', 'Weapon']
# Detected labels for post78_img3.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Electronics', 'Hardware', 'Blade', 'Dagger', 'Knife', 'Weapon']
# Detected labels for post78_img2.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Aftershave']
# Detected labels for post78_img1.jpg
# ['Accessories', 'Jewelry', 'Necklace', 'Earring']
# Detected labels for post168_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Accessories', 'Jewelry', 'Necklace', 'Hair', 'Skin', 'Tattoo', 'Cosmetics', 'Crew Cut', 'Machine', 'Screw']
# Detected labels for post168_img2.jpg
# ['Person', 'Photobombing', 'Adult', 'Female', 'Woman', 'Cosmetics', 'Accessories', 'Jewelry', 'Necklace', 'Bracelet', 'Makeup', 'Head', 'Face', 'Male', 'Man']
# Detected labels for post163_img2.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Pen', 'Cosmetics', 'Skin', 'Tattoo', 'Makeup']
# Detected labels for post163_img1.jpg
# ['Blonde', 'Hair', 'Person', 'Adult', 'Female', 'Woman', 'Skin', 'Tattoo']
# Detected labels for post163_img3.jpg
# ['Cosmetics', 'Lipstick', 'Makeup']
# Detected labels for post155_img1.jpg
# ['Person', 'Sitting', 'Adult', 'Male', 'Man', 'Furniture', 'Clothing', 'Formal Wear', 'Suit', 'Blazer', 'Coat', 'Jacket', 'Chair', 'Footwear', 'Shoe', 'Armchair']
# Detected labels for post155_img2.jpg
# ['Photography', 'Face', 'Head', 'Person', 'Portrait', 'Bottle', 'Cosmetics', 'Perfume', 'Clothing', 'Formal Wear', 'Suit', 'Coat', 'Adult', 'Male', 'Man', 'Body Part', 'Finger', 'Hand']
# Detected labels for post155_img3.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Computer Hardware', 'Electronics', 'Hardware', 'Monitor', 'Screen']
# Detected labels for post75_img1.jpg
# ['Accessories', 'Wallet', 'Head', 'Person', 'Face', 'Body Part', 'Neck', 'Finger', 'Hand', 'Bracelet', 'Jewelry', 'Cuff', 'Skin', 'Tattoo', 'Cosmetics']
# Detected labels for post74_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Cosmetics', 'Lipstick', 'Head', 'Face', 'Smoke Pipe']
# Detected labels for post74_img3.jpg
# ['Cosmetics', 'Lipstick', 'Blonde', 'Hair', 'Person', 'Head', 'Face']
# Detected labels for post74_img2.jpg
# ['Head', 'Person', 'Face', 'Cosmetics', 'Lipstick', 'Smoke', 'Smoking']
# Detected labels for post68_img3.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Photography', 'Portrait', 'Body Part', 'Finger', 'Hand', 'Hair']
# Detected labels for post68_img1.jpg
# ['Lighting', 'Lamp', 'Adult', 'Female', 'Person', 'Woman', 'Photography', 'Blade', 'Dagger', 'Knife', 'Weapon', 'Clothing', 'Footwear', 'Shoe', 'Dancing', 'Leisure Activities']
# Detected labels for post68_img2.jpg
# ['Dancing', 'Leisure Activities', 'Person', 'Adult', 'Female', 'Woman', 'Lighting', 'Photography', 'Performer', 'Solo Performance']
# Detected labels for post65_img1.jpg
# ['Person', 'Skin', 'Tattoo', 'Body Part', 'Finger', 'Hand', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Photography', 'Portrait']
# Detected labels for post65_img2.jpg
# ['Flower', 'Petal', 'Plant', 'Cosmetics']
# Detected labels for post65_img3.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post62_img2.jpg
# ['Advertisement', 'Poster']
# Detected labels for post62_img4.jpg
# ['Advertisement', 'Poster', 'Text', 'Bag']
# Detected labels for post62_img3.jpg
# ['Advertisement', 'Poster']
# Detected labels for post62_img1.jpg
# ['Advertisement', 'Poster', 'Gun', 'Weapon', 'Car', 'Transportation', 'Vehicle', 'Text']
# Detected labels for post52_img1.jpg
# ['Blonde', 'Hair', 'Person', 'Adult', 'Female', 'Woman', 'Blouse', 'Clothing', 'Vest']
# Detected labels for post52_img3.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Photography', 'Portrait', 'Black Hair', 'Hair', 'Clothing', 'Sleeve', 'Baby']
# Detected labels for post52_img4.jpg
# ['Curly Hair', 'Hair', 'Person', 'Clothing', 'Coat', 'Adult', 'Male', 'Man', 'Blonde', 'Body Part', 'Face', 'Head', 'Neck']
# Detected labels for post52_img2.jpg
# ['Clothing', 'Formal Wear', 'Suit', 'Black Hair', 'Hair', 'Person', 'Blazer', 'Coat', 'Jacket', 'Adult', 'Male', 'Man', 'Face', 'Head']
# Detected labels for post52_img7.jpg
# ['Black Hair', 'Hair', 'Person', 'Adult', 'Female', 'Woman']
# Detected labels for post52_img5.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Face', 'Head', 'Photography', 'Portrait', 'Cosmetics', 'Lipstick', 'Bottle', 'Perfume']
# Detected labels for post52_img8.jpg
# ['Blonde', 'Hair', 'Person', 'Adult', 'Female', 'Woman', 'Clothing', 'Coat', 'Jacket']
# Detected labels for post52_img6.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume']
# Detected labels for post52_img9.jpg
# ['Person', 'Photobombing', 'Adult', 'Female', 'Woman', 'Urban', 'Clothing', 'Vest', 'Club', 'Face', 'Head']
# Detected labels for post52_img10.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post49_img1.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Clothing', 'Coat', 'Jacket', 'Black Hair', 'Hair', 'Accessories', 'Wallet']
# Detected labels for post49_img4.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Head', 'Person', 'Face', 'Black Hair', 'Hair']
# Detected labels for post49_img3.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Head', 'Person', 'Face', 'Photography', 'Portrait', 'Black Hair', 'Hair', 'Clothing', 'Coat', 'Jacket']
# Detected labels for post49_img2.jpg
# ['Person', 'Skin', 'Head', 'Face']
# Detected labels for post50_img1.jpg
# ['Performer', 'Person', 'Solo Performance', 'Guitar', 'Musical Instrument', 'Guitarist', 'Leisure Activities', 'Music', 'Musician', 'Accessories', 'Jewelry', 'Necklace', 'Adult', 'Male', 'Man', 'Hair']
# Detected labels for post48_img2.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume']
# Detected labels for post48_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post47_img1.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Clothing', 'Coat', 'Body Part', 'Finger', 'Hand', 'Jacket']
# Detected labels for post47_img2 (1).jpg
# ['Cosmetics', 'Lipstick', 'Face', 'Head', 'Person', 'Tape']
# Detected labels for post47_img2.jpg
# ['Cosmetics', 'Lipstick', 'Face', 'Head', 'Person', 'Tape']
# Detected labels for post47_img3.jpg
# ['Head', 'Person', 'Face', 'Adult', 'Female', 'Woman', 'Spitting', 'Photography', 'Portrait']
# Detected labels for post46_img3.jpg
# ['Performer', 'Person', 'Solo Performance', 'Adult', 'Male', 'Man', 'Electronics', 'Camera', 'Accessories', 'Belt', 'Face', 'Head']
# Detected labels for post46_img1.jpg
# ['Animal', 'Adult', 'Female', 'Person', 'Woman', 'King Snake', 'Reptile', 'Snake']
# Detected labels for post46_img2 (1).jpg
# ['Lighting', 'Adult', 'Male', 'Man', 'Person', 'Camera', 'Electronics', 'Video Camera', 'Performer', 'Solo Performance', 'Face', 'Head', 'Concert', 'Crowd']
# Detected labels for post46_img2.jpg
# ['Lighting', 'Adult', 'Male', 'Man', 'Person', 'Camera', 'Electronics', 'Video Camera', 'Performer', 'Solo Performance', 'Face', 'Head', 'Concert', 'Crowd']
# Detected labels for post41_img1.jpg
# ['Braid', 'Hair', 'Person', 'Bottle', 'Cosmetics', 'Perfume', 'Face', 'Head']
# Detected labels for post41_img3.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post41_img2.jpg
# ['Black Hair', 'Hair', 'Person', 'Performer', 'Solo Performance', 'Adult', 'Male', 'Man', 'Face', 'Head', 'Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post38_img1.jpg
# ['Land', 'Nature', 'Outdoors', 'Sea', 'Water', 'Transportation', 'Vehicle', 'Yacht', 'Scenery', 'Lake', 'Lagoon', 'Coast', 'Shoreline', 'Summer', 'Beach', 'Person', 'Sky', 'Boat']
# Detected labels for post38_img3.jpg
# ['Citrus Fruit', 'Food', 'Fruit', 'Orange', 'Plant', 'Produce', 'Grapefruit']
# Detected labels for post38_img4.jpg
# ['Bottle', 'Pebble', 'Cosmetics', 'Perfume', 'Crystal']
# Detected labels for post38_img2.jpg
# ['Electronics', 'Radio']
# Detected labels for post35_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Clothing', 'Coat', 'Jacket', 'Face', 'Head', 'Photography', 'Portrait', 'Performer', 'Solo Performance', 'Happy', 'Smile', 'Swimwear', 'Sleeve']
# Detected labels for post35_img2.jpg
# ['Clothing', 'Coat', 'Jacket', 'Face', 'Head', 'Person', 'Photography', 'Portrait', 'Happy', 'Smile', 'Adult', 'Female', 'Woman']
# Detected labels for post33_img2.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Skin', 'Tattoo', 'Face', 'Head', 'Photography', 'Portrait', 'Adult', 'Male', 'Man', 'Back']
# Detected labels for post33_img3.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Clothing', 'Formal Wear', 'Suit', 'Body Part', 'Finger', 'Hand', 'Adult', 'Male', 'Man', 'Bottle', 'Cosmetics', 'Perfume', 'Neck', 'Coat']
# Detected labels for post33_img1.jpg
# ['Firearm', 'Weapon', 'Clothing', 'Coat', 'Jacket', 'Gun', 'Handgun', 'Furniture', 'Adult', 'Male', 'Man', 'Person', 'Sitting', 'Bottle', 'Cosmetics', 'Perfume', 'Footwear', 'Shoe', 'Chair', 'Face', 'Head', 'Photography', 'Portrait', 'Body Part', 'Finger', 'Hand', 'Formal Wear', 'Suit']
# Detected labels for post32_img2.jpg
# ['Face', 'Head', 'Person', 'Purple', 'Cosmetics', 'Lipstick', 'Makeup', 'Ping Pong', 'Ping Pong Paddle', 'Racket', 'Sport']
# Detected labels for post32_img1.jpg
# ['Face', 'Head', 'Person', 'Cosmetics', 'Face Makeup', 'Makeup']
# Detected labels for post32_img3.jpg
# ['Symbol', 'Text', 'Cosmetics']
# Detected labels for post32_img4.jpg
# ['Face', 'Head', 'Person', 'Cosmetics', 'Tape', 'Accessories', 'Wallet', 'Bag', 'Handbag', 'Makeup']
# Detected labels for post31_img2.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Body Part', 'Finger', 'Hand', 'Person']
# Detected labels for post31_img3 (1).jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Nail', 'Baby', 'Massage', 'Accessories', 'Jewelry', 'Ring']
# Detected labels for post31_img3.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Nail', 'Baby', 'Massage', 'Accessories', 'Jewelry', 'Ring']
# Detected labels for post31_img1 (1).jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Bottle', 'Cosmetics', 'Perfume', 'Head', 'Face', 'Accessories', 'Bracelet', 'Jewelry', 'Photography', 'Clothing', 'Swimwear', 'Skin', 'Tattoo']
# Detected labels for post31_img1.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Bottle', 'Cosmetics', 'Perfume', 'Head', 'Face', 'Accessories', 'Bracelet', 'Jewelry', 'Photography', 'Clothing', 'Swimwear', 'Skin', 'Tattoo']
# Detected labels for post28_img3.jpg
# ['Concert', 'Crowd', 'Person', 'Adult', 'Male', 'Man', 'Performer', 'Solo Performance', 'Lighting', 'Rock Concert', 'Guitar', 'Musical Instrument', 'Festival', 'Hanukkah Menorah']
# Detected labels for post28_img4.jpg
# ['Concert', 'Crowd', 'Person', 'Rock Concert', 'Lighting', 'Urban', 'Club', 'Adult', 'Male', 'Man', 'Face', 'Head']
# Detected labels for post28_img2.jpg
# ['Indoors']
# Detected labels for post28_img1.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Adult', 'Male', 'Man', 'Face', 'Head', 'Sweating', 'Accessories', 'Sunglasses', 'Shoulder', 'Jewelry', 'Necklace']
# Detected labels for post26_img1.jpg
# ['Gold']
# Detected labels for post26_img2.jpg
# ['Pattern', 'Alcohol', 'Beverage', 'Cocktail', 'Flower', 'Plant', 'Accessories', 'Fractal', 'Ornament', 'Light', 'Art', 'Graphics', 'Petal']
# Detected labels for post26_img3.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post20_img1.jpg
# ['Banner', 'Text', 'Indoors', 'Interior Design', 'Architecture', 'Building', 'Office Building', 'Advertisement']
# Detected labels for post20_img2.jpg
# ['Summer', 'Architecture', 'Building', 'Outdoors', 'Shelter', 'Palm Tree', 'Plant', 'Tree', 'Nature', 'Vegetation', 'Housing', 'City', 'Garden']
# Detected labels for post20_img3.jpg
# ['Advertisement', 'Person', 'Adult', 'Bride', 'Female', 'Wedding', 'Woman', 'Poster']
# Detected labels for post20_img4.jpg
# ['Logo', 'Symbol', 'Emblem']
# Detected labels for post20_img6.jpg
# ['Food', 'Sweets', 'Business Card', 'Paper', 'Text', 'Medication', 'Pill', 'Candy']
# Detected labels for post20_img7.jpg
# ['Symbol', 'Love Heart Symbol']
# Detected labels for post20_img5.jpg
# ['Indoors', 'Interior Design', 'Floor', 'Art', 'Modern Art', 'Appliance', 'Ceiling Fan', 'Device', 'Electrical Device']
# Detected labels for post19_img1.jpg
# ['Blonde', 'Hair', 'Person', 'Clothing', 'Pants', 'T-Shirt', 'Adult', 'Female', 'Woman', 'Sleeve', 'Text']
# Detected labels for post19_img2.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Symbol', 'Blonde', 'Hair', 'Head', 'Face']
# Detected labels for post19_img3.jpg
# ['Computer Hardware', 'Electronics', 'Hardware', 'Monitor', 'Screen', 'TV', 'Cosmetics', 'Lipstick', 'Adult', 'Female', 'Person', 'Woman', 'Face', 'Head']
# Detected labels for post19_img4 (1).jpg
# ['Clothing', 'Pants', 'Adult', 'Female', 'Person', 'Woman', 'Jeans', 'Symbol', 'Sleeve', 'Footwear', 'Shoe']
# Detected labels for post19_img4.jpg
# ['Clothing', 'Pants', 'Adult', 'Female', 'Person', 'Woman', 'Jeans', 'Symbol', 'Sleeve', 'Footwear', 'Shoe']
# Detected labels for post18_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Male', 'Man', 'Face', 'Head', 'Accessories', 'Glasses']
# Detected labels for post18_img2.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Black Hair', 'Hair', 'Symbol']
# Detected labels for post18_img3.jpg
# ['Black Hair', 'Hair', 'Person', 'Adult', 'Female', 'Woman', 'Bottle', 'Cosmetics', 'Perfume', 'Face', 'Head', 'Sword', 'Weapon', 'Eating', 'Food']
# Detected labels for post18_img4 (1).jpg
# ['Symbol', 'Bottle', 'Cosmetics', 'Perfume', 'Love Heart Symbol']
# Detected labels for post18_img4.jpg
# ['Symbol', 'Bottle', 'Cosmetics', 'Perfume', 'Love Heart Symbol']
# Detected labels for post18_img5.jpg
# ['Computer Hardware', 'Electronics', 'Hardware', 'Monitor', 'Screen', 'Adult', 'Female', 'Person', 'Woman', 'TV', 'Clothing', 'Dress', 'Art', 'Collage', 'Formal Wear', 'Face', 'Head', 'Back', 'Body Part', 'Photography', 'Portrait', 'Accessories', 'Jewelry', 'Necklace']
# Detected labels for post16_img1.jpg
# ['Purple', 'Crystal', 'Accessories', 'Ornament', 'Adult', 'Male', 'Man', 'Person', 'Gemstone', 'Jewelry', 'Ice']
# Detected labels for post16_img3.jpg
# ['Symbol', 'Medication', 'Pill', 'Love Heart Symbol']
# Detected labels for post16_img2.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Tape', 'Can', 'Tin']
# Detected labels for post16_img4.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume', 'Tape']
# Detected labels for post16_img5.jpg
# ['Box', 'Accessories', 'Wallet']
# Detected labels for post16_img6.jpg
# ['Aluminium', 'Christmas', 'Christmas Decorations', 'Christmas Tree', 'Christmas Tree Ornaments', 'Festival']
# Detected labels for post13_img1.jpg
# ['Clothing', 'Dress', 'Formal Wear', 'Evening Dress', 'Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Photography', 'Portrait', 'Fashion', 'Suit', 'Accessories', 'Belt', 'Happy', 'Smile']
# Detected labels for post13_img2.jpg
# ['Clothing', 'Formal Wear', 'Suit', 'Tuxedo', 'Face', 'Head', 'Person', 'Photography', 'Portrait', 'Accessories', 'Tie', 'Adult', 'Male', 'Man', 'Coat', 'Blazer', 'Jacket']
# Detected labels for post13_img3.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Face', 'Happy', 'Head', 'Smile', 'Photography', 'Portrait', 'Black Hair', 'Hair', 'Clothing', 'Dress', 'Formal Wear', 'Fashion', 'Long Sleeve', 'Sleeve', 'Coat', 'Suit']
# Detected labels for post13_img5.jpg
# ['Clothing', 'Dress', 'Adult', 'Female', 'Person', 'Woman', 'Formal Wear', 'Face', 'Head', 'Photography', 'Portrait', 'Evening Dress', 'Fashion', 'Accessories', 'Jewelry', 'Ring', 'Earring', 'Happy', 'Smile']
# Detected labels for post13_img6.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Black Hair', 'Hair', 'Sword', 'Weapon', 'Face', 'Head', 'Photography', 'Portrait', 'Clothing', 'Dress', 'Formal Wear']
# Detected labels for post13_img4.jpg
# ['Clothing', 'Coat', 'Jacket', 'Face', 'Head', 'Person', 'Photography', 'Portrait', 'Adult', 'Male', 'Man', 'Fashion']
# Detected labels for post12_img1.jpg
# ['Advertisement', 'Symbol', 'Architecture', 'Building', 'Love Heart Symbol']
# Detected labels for post12_img3.jpg
# ['Clothing', 'Coat', 'Jacket', 'Accessories', 'Sunglasses', 'Adult', 'Male', 'Man', 'Person', 'Face', 'Head', 'Photography', 'Portrait', 'Long Sleeve', 'Sleeve', 'People']
# Detected labels for post12_img2.jpg
# ['Purple', 'Face', 'Head', 'Person', 'Photography', 'Portrait', 'Lighting', 'Light', 'Accessories', 'Glasses', 'Adult', 'Male', 'Man', 'Electronics', 'Headphones', 'Bride', 'Female', 'Wedding', 'Woman', 'Sunglasses', 'Wristwatch']
# Detected labels for post10_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Club', 'Fashion', 'Formal Wear', 'Urban', 'Clothing', 'Dress', 'Coat', 'Face', 'Head', 'Suit', 'Accessories', 'Jewelry', 'Necklace', 'Body Part', 'Finger', 'Hand', 'Photography', 'Portrait']
# Detected labels for post10_img3.jpg
# ['Clothing', 'Dress', 'Evening Dress', 'Formal Wear', 'Accessories', 'Bag', 'Handbag', 'Face', 'Head', 'Person', 'Photography', 'Portrait', 'Wallet', 'Fashion', 'Suit', 'Gown']
# Detected labels for post10_img2.jpg
# ['Clothing', 'Dress', 'Formal Wear', 'Evening Dress', 'Fashion', 'Adult', 'Female', 'Person', 'Woman', 'Body Part', 'Finger', 'Hand', 'Accessories', 'Jewelry', 'Ring', 'Face', 'Head']
# Detected labels for post10_img4.jpg
# ['Black Hair', 'Hair', 'Person', 'Adult', 'Male', 'Man', 'Face', 'Head', 'Photography', 'Portrait', 'Female', 'Woman', 'Fashion']
# Detected labels for post9_img1.jpg
# ['Clothing', 'Coat', 'Jacket', 'Adult', 'Female', 'Person', 'Woman', 'Long Sleeve', 'Sleeve', 'Accessories', 'Jewelry', 'Ring', 'Photography', 'Face', 'Head', 'Portrait', 'Art', 'Painting']
# Detected labels for post9_img5.jpg
# ['Urban', 'Club', 'Night Club', 'People', 'Person', 'Adult', 'Female', 'Woman', 'Baby', 'Face', 'Head', 'Male', 'Man', 'Fun', 'Party', 'Crowd', 'Accessories', 'Glasses', 'Night Life']
# Detected labels for post9_img2.jpg
# ['Clothing', 'Dress', 'Evening Dress', 'Formal Wear', 'Adult', 'Female', 'Person', 'Woman', 'Body Part', 'Finger', 'Hand', 'Fashion', 'Face', 'Head']
# Detected labels for post9_img4.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Lighting', 'Light', 'Purple', 'Club', 'Accessories', 'Jewelry', 'Necklace', 'Face', 'Head', 'Photography', 'Portrait', 'Urban', 'Night Club', 'Fashion', 'Formal Wear']
# Detected labels for post9_img7.jpg
# ['Symbol', 'Balloon', 'Person', 'Love Heart Symbol', 'Egg', 'Food']
# Detected labels for post9_img6.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Photography', 'Face', 'Head', 'Portrait', 'Body Part', 'Finger', 'Hand']
# Detected labels for post9_img9.jpg
# ['Urban', 'Adult', 'Female', 'Person', 'Woman', 'Photobombing', 'Male', 'Man', 'Face', 'Head', 'Night Life']
# Detected labels for post9_img8.jpg
# ['People', 'Person', 'Clothing', 'Footwear', 'Shoe', 'Adult', 'Female', 'Woman', 'Male', 'Man', 'Groupshot', 'Accessories', 'Glasses', 'Face', 'Head', 'Furniture']
# Detected labels for post9_img3.jpg
# ['Symbol', 'Love Heart Symbol', 'Adult', 'Male', 'Man', 'Person']
# Detected labels for post6_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Bottle', 'Cosmetics', 'Perfume', 'Clothing', 'Hosiery', 'Footwear', 'High Heel', 'Shoe']
# Detected labels for post6_img2.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Flower', 'Plant']
# Detected labels for post6_img3.jpg
# ['Head', 'Person', 'Adult', 'Female', 'Woman', 'Face', 'Flower', 'Flower Arrangement', 'Flower Bouquet', 'Plant', 'Photography', 'Portrait', 'Body Part', 'Finger', 'Hand', 'Brown Hair', 'Hair']
# Detected labels for post4_img4.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Clothing', 'Hosiery', 'Pantyhose', 'Accessories', 'Jewelry', 'Ring']
# Detected labels for post4_img1.jpg
# ['Electronics', 'Screen', 'Computer Hardware', 'Hardware', 'Monitor', 'Adult', 'Female', 'Person', 'Woman', 'TV', 'Head', 'Face', 'Photography', 'Portrait']
# Detected labels for post4_img3.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Performer', 'Solo Performance']
# Detected labels for post4_img2.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Face', 'Head']
# Detected labels for post3_img2.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Nail', 'Baby', 'Massage', 'Accessories', 'Jewelry', 'Ring']
# Detected labels for post3_img1 (1).jpg
# ['Citrus Fruit', 'Food', 'Fruit', 'Orange', 'Plant', 'Produce', 'Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post3_img1.jpg
# ['Citrus Fruit', 'Food', 'Fruit', 'Orange', 'Plant', 'Produce', 'Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post3_img3 (1).jpg
# ['Flower', 'Flower Arrangement', 'Flower Bouquet', 'Plant', 'Citrus Fruit', 'Food', 'Fruit', 'Produce', 'Grapefruit', 'Adult', 'Bride', 'Female', 'Person', 'Wedding', 'Woman', 'Rose']
# Detected labels for post3_img3.jpg
# ['Flower', 'Flower Arrangement', 'Flower Bouquet', 'Plant', 'Citrus Fruit', 'Food', 'Fruit', 'Produce', 'Grapefruit', 'Adult', 'Bride', 'Female', 'Person', 'Wedding', 'Woman', 'Rose']

# %%
# Write out the results to a csv
with open(rekog_results_dir + f'labels_final_{username}.csv', 'w', newline = '') as csvfile:
    fieldnames = ['image_id', 'has_makeup', 'has_beauty_product', 'has_logo_or_branding',
 'is_fashion_related', 'is_beauty_scene', 'has_text', 'close_up', 'indoors', 'outdoors']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for entry in holder_labels:
        writer.writerow(entry)

# %%
face_labels = []

for imageFile in local_images:
    image_path = rekog_images_dir + imageFile
    try:
        image_bytes = resize_if_needed(image_path)
    except Exception as e:
        print(f"❌ Skipping {imageFile}: {e}")
        continue

    # Detect facial features
    face_response = client.detect_faces(Image={'Bytes': image_bytes}, Attributes=['ALL'])
    celeb_response = client.recognize_celebrities(Image={'Bytes': image_bytes})

    print('Detected faces and celebrities for ' + imageFile)

    temp_dict = {
        "image_id": imageFile,
        "face_count": 0,
        "has_smile": False,
        "has_female": False,
        "has_male": False,
        "dominant_emotion": None,
        "emotions": [],
        "has_happy_emotion": False,
        "has_confident_emotion": False,
        "has_celebrity": False,
        "celebrity_names": [],
        "has_unrecognized_face": False
    }

    # === CELEBRITY CHECK ===
    matched = celeb_response.get("CelebrityFaces", [])
    unmatched = celeb_response.get("UnrecognizedFaces", [])

    if matched:
        temp_dict["has_celebrity"] = True
        temp_dict["celebrity_names"] = [c["Name"] for c in matched]
    if unmatched:
        temp_dict["has_unrecognized_face"] = True

    # === FACIAL ATTRIBUTES ===
    faces = face_response.get('FaceDetails', [])
    temp_dict["face_count"] = len(faces)

    all_emotions = set()
    happy_detected = False
    confident_detected = False

    for face in faces:
        if face.get('Smile', {}).get('Value'):
            temp_dict["has_smile"] = True

        gender = face.get('Gender', {}).get('Value')
        if gender == 'Female':
            temp_dict["has_female"] = True
        elif gender == 'Male':
            temp_dict["has_male"] = True

        for emotion in face.get('Emotions', []):
            if emotion.get('Confidence', 0) >= 70:
                emotion_type = emotion.get('Type')
                all_emotions.add(emotion_type)

                if emotion_type == 'HAPPY':
                    happy_detected = True
                if emotion_type == 'CONFIDENT':
                    confident_detected = True

    temp_dict["emotions"] = list(all_emotions)
    temp_dict["has_happy_emotion"] = happy_detected
    temp_dict["has_confident_emotion"] = confident_detected
    if all_emotions:
        temp_dict["dominant_emotion"] = list(all_emotions)[0]

    face_labels.append(temp_dict)
# Out:
# Detected faces and celebrities for post215_img2.jpg
# Detected faces and celebrities for post215_img1.jpg
# Detected faces and celebrities for post215_img3.jpg
# Detected faces and celebrities for post210_img1.jpg
# Detected faces and celebrities for post210_img2.jpg
# Detected faces and celebrities for post210_img3.jpg
# Detected faces and celebrities for post210_img4.jpg
# Detected faces and celebrities for post210_img5.jpg
# Detected faces and celebrities for post208_img3.jpg
# Detected faces and celebrities for post208_img1.jpg
# Detected faces and celebrities for post208_img2.jpg
# Detected faces and celebrities for post208_img5.jpg
# Detected faces and celebrities for post208_img4.jpg
# Detected faces and celebrities for post198_img1.jpg
# Detected faces and celebrities for post197_img2.jpg
# Detected faces and celebrities for post197_img1.jpg
# Detected faces and celebrities for post197_img6.jpg
# Detected faces and celebrities for post197_img5.jpg
# Detected faces and celebrities for post197_img3.jpg
# Detected faces and celebrities for post197_img4.jpg
# Detected faces and celebrities for post197_img7.jpg
# Detected faces and celebrities for post196_img1.jpg
# Detected faces and celebrities for post196_img2.jpg
# Detected faces and celebrities for post196_img3.jpg
# Detected faces and celebrities for post196_img4.jpg
# Detected faces and celebrities for post196_img5.jpg
# Detected faces and celebrities for post195_img4 (1).jpg
# Detected faces and celebrities for post195_img3.jpg
# Detected faces and celebrities for post195_img2.jpg
# Detected faces and celebrities for post195_img4.jpg
# Detected faces and celebrities for post195_img1.jpg
# Detected faces and celebrities for post195_img5.jpg
# Detected faces and celebrities for post193_img1.jpg
# Detected faces and celebrities for post193_img3.jpg
# Detected faces and celebrities for post193_img2.jpg
# Detected faces and celebrities for post193_img4.jpg
# Detected faces and celebrities for post192_img1.jpg
# Detected faces and celebrities for post192_img2.jpg
# Detected faces and celebrities for post192_img3.jpg
# Detected faces and celebrities for post192_img4.jpg
# Detected faces and celebrities for post185_img1.jpg
# Detected faces and celebrities for post185_img2.jpg
# Detected faces and celebrities for post185_img4.jpg
# Detected faces and celebrities for post185_img3.jpg
# Detected faces and celebrities for post184_img1.jpg
# Detected faces and celebrities for post184_img2.jpg
# Detected faces and celebrities for post184_img3.jpg
# Detected faces and celebrities for post177_img1.jpg
# Detected faces and celebrities for post177_img2.jpg
# Detected faces and celebrities for post177_img3.jpg
# Detected faces and celebrities for post176_img1.jpg
# Detected faces and celebrities for post165_img1.jpg
# Detected faces and celebrities for post152_img1.jpg
# Detected faces and celebrities for post152_img2.jpg
# Detected faces and celebrities for post152_img4.jpg
# Detected faces and celebrities for post152_img3.jpg
# Detected faces and celebrities for post152_img5.jpg
# Detected faces and celebrities for post151_img1.jpg
# Detected faces and celebrities for post151_img2.jpg
# Detected faces and celebrities for post150_img3.jpg
# Detected faces and celebrities for post150_img1.jpg
# Detected faces and celebrities for post150_img4.jpg
# Detected faces and celebrities for post150_img2.jpg
# Detected faces and celebrities for post147_img2.jpg
# Detected faces and celebrities for post147_img1.jpg
# Detected faces and celebrities for post147_img3.jpg
# Detected faces and celebrities for post146_img1.jpg
# Detected faces and celebrities for post145_img1.jpg
# Detected faces and celebrities for post145_img2.jpg
# Detected faces and celebrities for post145_img3.jpg
# Detected faces and celebrities for post145_img4.jpg
# Detected faces and celebrities for post144_img1.jpg
# Detected faces and celebrities for post144_img2.jpg
# Detected faces and celebrities for post144_img3.jpg
# Detected faces and celebrities for post138_img1.jpg
# Detected faces and celebrities for post138_img2.jpg
# Detected faces and celebrities for post137_img2.jpg
# Detected faces and celebrities for post137_img1.jpg
# Detected faces and celebrities for post137_img4.jpg
# Detected faces and celebrities for post137_img5.jpg
# Detected faces and celebrities for post137_img3.jpg
# Detected faces and celebrities for post135_img1.jpg
# Detected faces and celebrities for post135_img2.jpg
# Detected faces and celebrities for post129_img1.jpg
# Detected faces and celebrities for post129_img2.jpg
# Detected faces and celebrities for post129_img3.jpg
# Detected faces and celebrities for post129_img4.jpg
# Detected faces and celebrities for post126_img1.jpg
# Detected faces and celebrities for post118_img1.jpg
# Detected faces and celebrities for post118_img2.jpg
# Detected faces and celebrities for post116_img2.jpg
# Detected faces and celebrities for post116_img1.jpg
# Detected faces and celebrities for post114_img1.jpg
# Detected faces and celebrities for post114_img2.jpg
# Detected faces and celebrities for post114_img3.jpg
# Detected faces and celebrities for post113_img1.jpg
# Detected faces and celebrities for post113_img2.jpg
# Detected faces and celebrities for post111_img2.jpg
# Detected faces and celebrities for post111_img3.jpg
# Detected faces and celebrities for post111_img1.jpg
# Detected faces and celebrities for post108_img2.jpg
# Detected faces and celebrities for post108_img3.jpg
# Detected faces and celebrities for post108_img1.jpg
# Detected faces and celebrities for post106_img1.jpg
# Detected faces and celebrities for post106_img2.jpg
# Detected faces and celebrities for post102_img1.jpg
# Detected faces and celebrities for post102_img2.jpg
# Detected faces and celebrities for post98_img3.jpg
# Detected faces and celebrities for post98_img1.jpg
# Detected faces and celebrities for post98_img2.jpg
# Detected faces and celebrities for post97_img1 (1).jpg
# Detected faces and celebrities for post97_img1.jpg
# Detected faces and celebrities for post97_img2.jpg
# Detected faces and celebrities for post94_img1.jpg
# Detected faces and celebrities for post94_img2.jpg
# Detected faces and celebrities for post91_img4.jpg
# Detected faces and celebrities for post91_img3.jpg
# Detected faces and celebrities for post91_img2.jpg
# Detected faces and celebrities for post91_img1.jpg
# Detected faces and celebrities for post88_img1.jpg
# Detected faces and celebrities for post88_img2.jpg
# Detected faces and celebrities for post88_img3.jpg
# Detected faces and celebrities for post86_img1.jpg
# Detected faces and celebrities for post82_img1.jpg
# Detected faces and celebrities for post82_img2.jpg
# Detected faces and celebrities for post82_img4.jpg
# Detected faces and celebrities for post82_img6.jpg
# Detected faces and celebrities for post82_img7.jpg
# Detected faces and celebrities for post82_img5.jpg
# Detected faces and celebrities for post82_img3.jpg
# Detected faces and celebrities for post80_img3.jpg
# Detected faces and celebrities for post80_img1.jpg
# Detected faces and celebrities for post80_img2.jpg
# Detected faces and celebrities for post80_img4.jpg
# Detected faces and celebrities for post79_img1.jpg
# Detected faces and celebrities for post79_img2.jpg
# Detected faces and celebrities for post179_img1.jpg
# Detected faces and celebrities for post179_img5.jpg
# Detected faces and celebrities for post179_img2.jpg
# Detected faces and celebrities for post179_img4.jpg
# Detected faces and celebrities for post179_img3.jpg
# Detected faces and celebrities for post78_img3.jpg
# Detected faces and celebrities for post78_img2.jpg
# Detected faces and celebrities for post78_img1.jpg
# Detected faces and celebrities for post168_img1.jpg
# Detected faces and celebrities for post168_img2.jpg
# Detected faces and celebrities for post163_img2.jpg
# Detected faces and celebrities for post163_img1.jpg
# Detected faces and celebrities for post163_img3.jpg
# Detected faces and celebrities for post155_img1.jpg
# Detected faces and celebrities for post155_img2.jpg
# Detected faces and celebrities for post155_img3.jpg
# Detected faces and celebrities for post75_img1.jpg
# Detected faces and celebrities for post74_img1.jpg
# Detected faces and celebrities for post74_img3.jpg
# Detected faces and celebrities for post74_img2.jpg
# Detected faces and celebrities for post68_img3.jpg
# Detected faces and celebrities for post68_img1.jpg
# Detected faces and celebrities for post68_img2.jpg
# Detected faces and celebrities for post65_img1.jpg
# Detected faces and celebrities for post65_img2.jpg
# Detected faces and celebrities for post65_img3.jpg
# Detected faces and celebrities for post62_img2.jpg
# Detected faces and celebrities for post62_img4.jpg
# Detected faces and celebrities for post62_img3.jpg
# Detected faces and celebrities for post62_img1.jpg
# Detected faces and celebrities for post52_img1.jpg
# Detected faces and celebrities for post52_img3.jpg
# Detected faces and celebrities for post52_img4.jpg
# Detected faces and celebrities for post52_img2.jpg
# Detected faces and celebrities for post52_img7.jpg
# Detected faces and celebrities for post52_img5.jpg
# Detected faces and celebrities for post52_img8.jpg
# Detected faces and celebrities for post52_img6.jpg
# Detected faces and celebrities for post52_img9.jpg
# Detected faces and celebrities for post52_img10.jpg
# Detected faces and celebrities for post49_img1.jpg
# Detected faces and celebrities for post49_img4.jpg
# Detected faces and celebrities for post49_img3.jpg
# Detected faces and celebrities for post49_img2.jpg
# Detected faces and celebrities for post50_img1.jpg
# Detected faces and celebrities for post48_img2.jpg
# Detected faces and celebrities for post48_img1.jpg
# Detected faces and celebrities for post47_img1.jpg
# Detected faces and celebrities for post47_img2 (1).jpg
# Detected faces and celebrities for post47_img2.jpg
# Detected faces and celebrities for post47_img3.jpg
# Detected faces and celebrities for post46_img3.jpg
# Detected faces and celebrities for post46_img1.jpg
# Detected faces and celebrities for post46_img2 (1).jpg
# Detected faces and celebrities for post46_img2.jpg
# Detected faces and celebrities for post41_img1.jpg
# Detected faces and celebrities for post41_img3.jpg
# Detected faces and celebrities for post41_img2.jpg
# Detected faces and celebrities for post38_img1.jpg
# Detected faces and celebrities for post38_img3.jpg
# Detected faces and celebrities for post38_img4.jpg
# Detected faces and celebrities for post38_img2.jpg
# Detected faces and celebrities for post35_img1.jpg
# Detected faces and celebrities for post35_img2.jpg
# Detected faces and celebrities for post33_img2.jpg
# Detected faces and celebrities for post33_img3.jpg
# Detected faces and celebrities for post33_img1.jpg
# Detected faces and celebrities for post32_img2.jpg
# Detected faces and celebrities for post32_img1.jpg
# Detected faces and celebrities for post32_img3.jpg
# Detected faces and celebrities for post32_img4.jpg
# Detected faces and celebrities for post31_img2.jpg
# Detected faces and celebrities for post31_img3 (1).jpg
# Detected faces and celebrities for post31_img3.jpg
# Detected faces and celebrities for post31_img1 (1).jpg
# Detected faces and celebrities for post31_img1.jpg
# Detected faces and celebrities for post28_img3.jpg
# Detected faces and celebrities for post28_img4.jpg
# Detected faces and celebrities for post28_img2.jpg
# Detected faces and celebrities for post28_img1.jpg
# Detected faces and celebrities for post26_img1.jpg
# Detected faces and celebrities for post26_img2.jpg
# Detected faces and celebrities for post26_img3.jpg
# Detected faces and celebrities for post20_img1.jpg
# Detected faces and celebrities for post20_img2.jpg
# Detected faces and celebrities for post20_img3.jpg
# Detected faces and celebrities for post20_img4.jpg
# Detected faces and celebrities for post20_img6.jpg
# Detected faces and celebrities for post20_img7.jpg
# Detected faces and celebrities for post20_img5.jpg
# Detected faces and celebrities for post19_img1.jpg
# Detected faces and celebrities for post19_img2.jpg
# Detected faces and celebrities for post19_img3.jpg
# Detected faces and celebrities for post19_img4 (1).jpg
# Detected faces and celebrities for post19_img4.jpg
# Detected faces and celebrities for post18_img1.jpg
# Detected faces and celebrities for post18_img2.jpg
# Detected faces and celebrities for post18_img3.jpg
# Detected faces and celebrities for post18_img4 (1).jpg
# Detected faces and celebrities for post18_img4.jpg
# Detected faces and celebrities for post18_img5.jpg
# Detected faces and celebrities for post16_img1.jpg
# Detected faces and celebrities for post16_img3.jpg
# Detected faces and celebrities for post16_img2.jpg
# Detected faces and celebrities for post16_img4.jpg
# Detected faces and celebrities for post16_img5.jpg
# Detected faces and celebrities for post16_img6.jpg
# Detected faces and celebrities for post13_img1.jpg
# Detected faces and celebrities for post13_img2.jpg
# Detected faces and celebrities for post13_img3.jpg
# Detected faces and celebrities for post13_img5.jpg
# Detected faces and celebrities for post13_img6.jpg
# Detected faces and celebrities for post13_img4.jpg
# Detected faces and celebrities for post12_img1.jpg
# Detected faces and celebrities for post12_img3.jpg
# Detected faces and celebrities for post12_img2.jpg
# Detected faces and celebrities for post10_img1.jpg
# Detected faces and celebrities for post10_img3.jpg
# Detected faces and celebrities for post10_img2.jpg
# Detected faces and celebrities for post10_img4.jpg
# Detected faces and celebrities for post9_img1.jpg
# Detected faces and celebrities for post9_img5.jpg
# Detected faces and celebrities for post9_img2.jpg
# Detected faces and celebrities for post9_img4.jpg
# Detected faces and celebrities for post9_img7.jpg
# Detected faces and celebrities for post9_img6.jpg
# Detected faces and celebrities for post9_img9.jpg
# Detected faces and celebrities for post9_img8.jpg
# Detected faces and celebrities for post9_img3.jpg
# Detected faces and celebrities for post6_img1.jpg
# Detected faces and celebrities for post6_img2.jpg
# Detected faces and celebrities for post6_img3.jpg
# Detected faces and celebrities for post4_img4.jpg
# Detected faces and celebrities for post4_img1.jpg
# Detected faces and celebrities for post4_img3.jpg
# Detected faces and celebrities for post4_img2.jpg
# Detected faces and celebrities for post3_img2.jpg
# Detected faces and celebrities for post3_img1 (1).jpg
# Detected faces and celebrities for post3_img1.jpg
# Detected faces and celebrities for post3_img3 (1).jpg
# Detected faces and celebrities for post3_img3.jpg

# %%
with open(rekog_results_dir + f'faces_final_{username}.csv', 'w', newline = '') as csvfile:
    fieldnames = [
        'image_id',
        'face_count',
        'has_smile',
        'has_female',
        'has_male',
        'dominant_emotion',
        'emotions',
        'has_happy_emotion',
        'has_confident_emotion',
        'has_celebrity',
        'celebrity_names',
        'has_unrecognized_face'
    ]

    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for entry in face_labels:
        writer.writerow(entry)
