# %% [markdown]
# <a href="https://colab.research.google.com/github/Emily-KD/PopularityPrediction/blob/main/Data/sephora/Amazon-Rekognition/sephora_AR_Labels_%26_Faces.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.37.37-py3-none-any.whl.metadata (6.7 kB)
# Collecting botocore<1.38.0,>=1.37.37 (from boto3)
#   Downloading botocore-1.37.37-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.12.0,>=0.11.0 (from boto3)
#   Downloading s3transfer-0.11.5-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore<1.38.0,>=1.37.37->boto3) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<1.38.0,>=1.37.37->boto3) (2.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.38.0,>=1.37.37->boto3) (1.17.0)
# Downloading boto3-1.37.37-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 4.6 MB/s eta 0:00:00
# Downloading botocore-1.37.37-py3-none-any.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 127.8 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.11.5-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 7.4 MB/s eta 0:00:00
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.37.37 botocore-1.37.37 jmespath-1.0.1 s3transfer-0.11.5

# %%
import csv
import boto3
import pickle
import os
import json
import pandas as pd

# %%
ls
# Out:
# drive/  sample_data/

# %%
########### Paths
username = "sephora"
# Path to where your want to save the resulting labels
rekog_results_dir = f"/content/drive/Shareddrives/DS340W Project/Dataset NEW*/{username}/"

# Path to where your images are
rekog_images_dir = f"/content/drive/Shareddrives/DS340W Project/Dataset NEW*/{username}/{username}_images_2024_2025/"

# %%
# Read in your personal keys
personal_access_key = "AKIA6JKEXWET5465SAMQ"
secret_access_key = "Q3HEcBy+jO7ep4tL9It/7MEoFhlBxy9R2QpRjbWv"

# Initialize the boto client to access the Rekogniton api
client=boto3.client('rekognition','us-east-1', # or choose the best region for your work,
                                               # e.g. the location of your S3 bucket if using that method to store images
                    aws_access_key_id = personal_access_key,
                    aws_secret_access_key = secret_access_key)

# %%
# Make a list of all the images in the rekog_data_dir you created
local_images = os.listdir(rekog_images_dir)
#local_images = [str(p) for p in rekog_images_dir]

# %%
from PIL import Image
import io

def resize_if_needed(image_path, max_size=5242880):
    with open(image_path, 'rb') as f:
        img_bytes = f.read()

    if len(img_bytes) < max_size:
        return img_bytes

    # Resize the image using PIL
    with Image.open(image_path) as img:
        # Reduce resolution while maintaining aspect ratio
        img.thumbnail((1024, 1024))  # tweak if needed
        buf = io.BytesIO()
        img.save(buf, format='JPEG')
        buf.seek(0)
        return buf.read()

# %%
#### Beauty-focused label extraction
holder_labels = []

for imageFile in local_images:
    image_path = rekog_images_dir + imageFile
    try:
        image_bytes = resize_if_needed(image_path)
        response = client.detect_labels(Image={'Bytes': image_bytes})
    except Exception as e:
        print(f"❌ Skipping {imageFile}: {e}")
        continue

    print('Detected labels for ' + imageFile)

    labels = []
    temp_dict = {
        "image_id": imageFile,
        "has_makeup": False,
        "has_beauty_product": False,
        "has_logo_or_branding": False,
        "is_fashion_related": False,
        "is_beauty_scene": False,
        "has_text": False,
        "close_up": False,
        "indoors": False,
        "outdoors": False
    }

    for label in response.get('Labels', []):
        if label.get('Confidence', 0) >= 70:
            labels.append(label.get('Name'))

    # Category dictionaries
    makeup_labels = ['Makeup', 'Cosmetics', 'Lipstick', 'Eyeliner', 'Blush', 'Eyeshadow']
    product_labels = ['Cosmetics', 'Bottle', 'Container', 'Toiletry', 'Skincare', 'Cream']
    brand_labels = ['Label', 'Logo', 'Trademark', 'Packaging']
    fashion_labels = ['Clothing', 'Apparel', 'Dress', 'Fashion', 'Footwear', 'Shoes', 'Bag']
    scene_labels = ['Beauty Salon', 'Mirror', 'Vanity', 'Makeup Room']
    text_labels = ['Text', 'Advertisement', 'Poster', 'Font', 'Brochure', 'Paper']

    # Binary feature assignments
    if any(lbl in labels for lbl in makeup_labels):
        temp_dict["has_makeup"] = True
    if any(lbl in labels for lbl in product_labels):
        temp_dict["has_beauty_product"] = True
    if any(lbl in labels for lbl in brand_labels):
        temp_dict["has_logo_or_branding"] = True
    if any(lbl in labels for lbl in fashion_labels):
        temp_dict["is_fashion_related"] = True
    if any(lbl in labels for lbl in scene_labels):
        temp_dict["is_beauty_scene"] = True
    if any(lbl in labels for lbl in text_labels):
        temp_dict["has_text"] = True
    if 'Portrait' in labels:
        temp_dict["close_up"] = True
    if 'Indoors' in labels:
        temp_dict["indoors"] = True
    if 'Outdoors' in labels:
        temp_dict["outdoors"] = True

    holder_labels.append(temp_dict)
    print(labels)  # Optional log
# Out:
# Detected labels for post1425_img1.jpg
# ['Cup', 'Cosmetics', 'Accessories', 'Bag', 'Handbag']
# Detected labels for post1422_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume', 'Mascara']
# Detected labels for post1420_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post1415_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1411_img1.jpg
# ['Hair', 'Person', 'Crew Cut']
# Detected labels for post1409_img1.jpg
# ['Clothing', 'Glove', 'Animal', 'Canine', 'Dog', 'Mammal', 'Pet', 'Grass', 'Plant', 'Toy', 'Outdoors', 'Nature']
# Detected labels for post1409_img2.jpg
# ['Furniture', 'Table', 'Desk', 'Computer', 'Electronics', 'Laptop', 'Pc', 'Plate', 'Bottle', 'Cosmetics', 'Perfume', 'Lamp', 'Tabletop']
# Detected labels for post1409_img3.jpg
# ['Home Decor', 'Toy', 'Jar', 'Indoors', 'Interior Design', 'Outdoors', 'Furniture']
# Detected labels for post1409_img4.jpg
# ['Light', 'Lighting', 'Desk', 'Furniture', 'Table', 'Laser', 'Cooktop', 'Indoors', 'Kitchen']
# Detected labels for post1407_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Perfume', 'Lipstick']
# Detected labels for post1403_img1.jpg
# ['Text', 'Person', 'Photography', 'Baby', 'Art', 'Collage', 'Face', 'Head', 'Portrait', 'Aircraft', 'Airplane', 'Transportation', 'Vehicle', 'People', 'Cap', 'Clothing', 'Hat', 'Cream', 'Dessert', 'Food', 'Ice Cream']
# Detected labels for post1401_img1.jpg
# ['Cosmetics', 'Cup', 'Box', 'Chopsticks', 'Food']
# Detected labels for post1400_img1.jpg
# ['Person', 'Skin', 'Cosmetics', 'Adult', 'Female', 'Woman', 'Makeup', 'Bottle', 'Perfume']
# Detected labels for post1400_img2.jpg
# ['Cosmetics', 'Lipstick', 'Cup', 'Bottle', 'Perfume']
# Detected labels for post1396_img1.jpg
# ['Head', 'Person', 'Face', 'Adult', 'Female', 'Woman', 'Trophy', 'Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1396_img2.jpg
# ['Head', 'Person', 'Face', 'Adult', 'Female', 'Woman', 'Trophy', 'Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1396_img3.jpg
# ['Head', 'Person', 'Face', 'Adult', 'Female', 'Woman', 'Trophy', 'Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1396_img4.jpg
# ['Head', 'Person', 'Adult', 'Female', 'Woman', 'Face', 'Trophy', 'Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1390_img1.jpg
# ['Cosmetics', 'Lipstick', 'Dynamite', 'Weapon', 'Nail Polish']
# Detected labels for post1385_img1.jpg
# ['Bottle', 'Cosmetics', 'Brush', 'Device', 'Tool', 'Perfume', 'Lotion', 'Lipstick']
# Detected labels for post1384_img1.jpg
# ['Cosmetics']
# Detected labels for post1382_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics']
# Detected labels for post1380_img1.jpg
# ['Cosmetics', 'Mascara']
# Detected labels for post1380_img2.jpg
# ['Marker', 'Dynamite', 'Weapon', 'Cosmetics', 'Lipstick', 'Can', 'Tin']
# Detected labels for post1373_img1.jpg
# ['Head', 'Person', 'Face', 'Adult', 'Female', 'Woman', 'Cosmetics']
# Detected labels for post1364_img1.jpg
# ['Cosmetics', 'Lipstick', 'Head', 'Person', 'Face', 'Tape']
# Detected labels for post1356_img1.jpg
# ['Cup', 'Bottle', 'Cosmetics', 'Perfume', 'Adult', 'Female', 'Person', 'Woman', 'Ice']
# Detected labels for post1349_img1.jpg
# ['Accessories', 'Bag', 'Handbag', 'Belt', 'First Aid', 'Clothing', 'Jeans', 'Pants', 'Wallet']
# Detected labels for post1346_img1.jpg
# ['Cosmetics', 'Face', 'Head', 'Person', 'Tape', 'Business Card', 'Paper', 'Text', 'Deodorant']
# Detected labels for post1339_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Bottle', 'Cosmetics', 'Perfume', 'Clothing', 'Footwear', 'Shoe', 'Face', 'Head']
# Detected labels for post1337_img1.jpg
# ['Brush', 'Device', 'Tool', 'Cutlery', 'Spoon', 'Cosmetics', 'Lipstick']
# Detected labels for post1336_img1.jpg
# ['Cosmetics', 'Lipstick', 'Cup', 'Body Part', 'Hand', 'Person']
# Detected labels for post1334_img1.jpg
# ['Electronics', 'Headphones', 'Computer', 'Pc', 'Laptop']
# Detected labels for post1333_img3.jpg
# ['Body Part', 'Mouth', 'Person', 'Cosmetics', 'Lipstick', 'Baby', 'Face', 'Head', 'Can', 'Tin']
# Detected labels for post1333_img4.jpg
# ['Bottle', 'Advertisement', 'Cosmetics', 'Lipstick', 'Perfume', 'Food', 'Fruit', 'Plant', 'Produce']
# Detected labels for post1331_img1.jpg
# ['Text', 'City']
# Detected labels for post1329_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume']
# Detected labels for post1326_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1333_img1.jpg
# ['Cosmetics', 'Nail Polish']
# Detected labels for post1333_img2.jpg
# ['Person', 'Skin', 'Cosmetics', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Lipstick', 'Makeup']
# Detected labels for post1317_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post1316_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1314_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Lotion', 'Dynamite', 'Weapon', 'Perfume', 'Head', 'Person', 'Business Card', 'Paper', 'Text', 'Face']
# Detected labels for post1314_img3.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Lotion', 'Lipstick']
# Detected labels for post1314_img2.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Lipstick', 'Perfume']
# Detected labels for post1312_img1.jpg
# ['Cosmetics', 'Lipstick', 'People', 'Person', 'Cream', 'Dessert', 'Food', 'Frozen Yogurt', 'Cake', 'Birthday Cake']
# Detected labels for post1305_img1.jpg
# ['Brush', 'Device', 'Tool']
# Detected labels for post1294_img1.jpg
# ['Cosmetics', 'Lipstick', 'Dynamite', 'Weapon']
# Detected labels for post1293_img1.jpg
# ['Clothing', 'Pajamas', 'Person', 'Face', 'Head', 'Adult', 'Bride', 'Female', 'Wedding', 'Woman', 'Fitness', 'Sport', 'Working Out', 'Yoga', 'Girl', 'Teen', 'White Board']
# Detected labels for post1290_img1.jpg
# ['Blonde', 'Hair', 'Person', 'Face', 'Head', 'Photography', 'Portrait', 'Bottle', 'Cosmetics', 'Perfume', 'Lipstick']
# Detected labels for post1284_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post1281_img1.jpg
# ['Clothing', 'Dress', 'Evening Dress', 'Formal Wear', 'Skirt', 'Glove', 'Adult', 'Female', 'Person', 'Woman', 'Architecture', 'Building', 'House', 'Housing', 'Staircase', 'Face', 'Head', 'Footwear', 'Shoe', 'Fashion']
# Detected labels for post1278_img1.jpg
# ['Food', 'Fruit', 'Plant', 'Produce', 'Bottle', 'Cosmetics', 'Perfume', 'Melon', 'Lotion']
# Detected labels for post1277_img1.jpg
# ['Advertisement', 'Poster', 'Female', 'Girl', 'Person', 'Teen', 'Photography', 'Text', 'People', 'Accessories', 'Wallet']
# Detected labels for post1275_img1.jpg
# ['Blade', 'Razor', 'Weapon', 'Toy', 'Brush', 'Device', 'Tool']
# Detected labels for post1272_img1.jpg
# ['Blade', 'Razor', 'Weapon', 'Cosmetics', 'Lipstick', 'Bottle']
# Detected labels for post1268_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post1266_img1.jpg
# ['Cosmetics', 'Lipstick', 'Brush', 'Device', 'Tool', 'Bottle', 'Perfume']
# Detected labels for post1261_img1.jpg
# ['Architecture', 'Building', 'Dining Room', 'Dining Table', 'Furniture', 'Indoors', 'Room', 'Table', 'Restaurant', 'Adult', 'Male', 'Man', 'Person', 'Bride', 'Female', 'Wedding', 'Woman', 'Face', 'Head', 'Accessories', 'Glasses', 'Cup', 'Saucer', 'Photography', 'Portrait', 'Beverage', 'Coffee', 'Coffee Cup', 'Bag', 'Handbag']
# Detected labels for post1259_img1.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Photography', 'Face', 'Head', 'Portrait', 'Adult', 'Female', 'Woman']
# Detected labels for post1256_img1.jpg
# ['Publication', 'Bottle']
# Detected labels for post1250_img1.jpg
# ['Purple', 'Mailbox', 'Box']
# Detected labels for post1241_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post1240_img1.jpg
# ['Head', 'Person', 'Face', 'Photography', 'Portrait', 'Bottle', 'Cosmetics', 'Perfume', 'Body Part', 'Finger', 'Hand', 'Lotion']
# Detected labels for post1237_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1229_img1.jpg
# ['Head', 'Person', 'Face', 'Cosmetics', 'Cup', 'Can', 'Tin', 'Makeup']
# Detected labels for post1207_img1.jpg
# ['Clothing', 'Footwear', 'Shoe', 'High Heel', 'Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1201_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Lipstick']
# Detected labels for post1196_img1.jpg
# ['Medication', 'Pill', 'Cosmetics', 'Bottle', 'Lotion']
# Detected labels for post1192_img1.jpg
# ['Food', 'Fruit', 'Plant', 'Produce', 'Melon', 'Watermelon', 'Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1187_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Flower', 'Petal', 'Plant', 'Rose']
# Detected labels for post1183_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1180_img1.jpg
# ['Cosmetics', 'Lipstick', 'Tape']
# Detected labels for post1177_img1.jpg
# ['Cosmetics', 'Smoke Pipe', 'Nail Polish']
# Detected labels for post1177_img2.jpg
# ['Cosmetics', 'Smoke Pipe']
# Detected labels for post1177_img3.jpg
# ['Head', 'Person', 'Face', 'Cosmetics', 'Brush', 'Device', 'Tool', 'Face Makeup', 'Makeup']
# Detected labels for post1177_img4.jpg
# ['Cabinet', 'Furniture', 'Medication', 'Pill', 'Tape', 'Medicine Chest', 'Cosmetics']
# Detected labels for post1174_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1170_img1.jpg
# ['Head', 'Person', 'Face', 'Adult', 'Female', 'Woman', 'Cosmetics', 'Brush', 'Device', 'Tool', 'Makeup', 'Lipstick', 'Tape', 'Face Makeup', 'Happy']
# Detected labels for post1170_img2.jpg
# ['Head', 'Person', 'Face', 'Cosmetics', 'Face Makeup', 'Makeup', 'Plate']
# Detected labels for post1169_img1.jpg
# ['Toothpaste', 'Bottle', 'Mortar Shell', 'Weapon']
# Detected labels for post1164_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post1154_img1.jpg
# ['Clothing', 'Hat', 'Cowboy Hat', 'Footwear', 'Shoe']
# Detected labels for post1149_img1.jpg
# ['Cosmetics', 'Bottle', 'Perfume', 'Clothing', 'Jeans', 'Pants', 'Face', 'Head', 'Person']
# Detected labels for post1140_img1.jpg
# ['Art', 'Collage', 'Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Home Decor', 'Accessories', 'Painting']
# Detected labels for post1138_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics']
# Detected labels for post1137_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1134_img1.jpg
# ['Chart', 'Pie Chart', 'Disk']
# Detected labels for post1131_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1130_img1.jpg
# ['Cosmetics', 'Lipstick', 'Head', 'Person', 'Face', 'Tape']
# Detected labels for post1125_img1.jpg
# ['Accessories', 'Bag', 'Handbag', 'Cosmetics', 'Lipstick', 'Bottle', 'Perfume', 'Tape']
# Detected labels for post1122_img1.jpg
# ['Photography', 'Face', 'Head', 'Person', 'Portrait', 'Advertisement', 'Cushion', 'Home Decor', 'Accessories', 'Bag', 'Handbag', 'Glasses', 'Electronics', 'Photographer', 'Poster', 'Clapperboard']
# Detected labels for post1121_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Perfume']
# Detected labels for post1107_img1.jpg
# ['Text', 'Electronics', 'Mobile Phone', 'Phone']
# Detected labels for post1107_img2.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Accessories', 'Bag', 'Handbag', 'Adult', 'Male', 'Man', 'Shop', 'Text', 'Indoors', 'Interior Design', 'Airport', 'Restaurant', 'Symbol']
# Detected labels for post1107_img3.jpg
# ['Face', 'Happy', 'Head', 'Person', 'Smile', 'Text', 'Adult', 'Female', 'Woman', 'Photography', 'QR Code', 'Car', 'Transportation', 'Vehicle', 'Accessories', 'Bag', 'Handbag', 'Document', 'Receipt']
# Detected labels for post1107_img4.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume']
# Detected labels for post1102_img1.jpg
# ['Cosmetics', 'Lipstick', 'Dynamite', 'Weapon']
# Detected labels for post1101_img1.jpg
# ['Indoors', 'Bathroom', 'Room', 'Shower', 'Shower Faucet', 'Beverage', 'Milk']
# Detected labels for post1085_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics']
# Detected labels for post1082_img1.jpg
# ['Furniture', 'Animal', 'Cat', 'Mammal', 'Pet', 'Photography', 'Face', 'Head', 'Person', 'Portrait', 'Home Decor', 'Kitten']
# Detected labels for post1082_img2.jpg
# ['Page', 'Text', 'White Board']
# Detected labels for post1081_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1081_img2.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1081_img3.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1081_img4.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Advertisement']
# Detected labels for post1078_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post1076_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Lotion']
# Detected labels for post1060_img1.jpg
# ['Device', 'Appliance', 'Electrical Device', 'Blow Dryer']
# Detected labels for post1058_img1.jpg
# ['Advertisement', 'Food', 'Fruit', 'Plant', 'Produce', 'Tape']
# Detected labels for post1051_img1.jpg
# ['Blonde', 'Hair', 'Person', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Photography', 'Portrait', 'Skin', 'Tattoo']
# Detected labels for post1051_img2.jpg
# ['Blonde', 'Hair', 'Person', 'Fashion', 'Adult', 'Female', 'Woman', 'Clothing', 'Dress', 'Formal Wear', 'Skin', 'Tattoo', 'Accessories']
# Detected labels for post1044_img1.jpg
# ['Food', 'Fruit', 'Plant', 'Produce', 'Cosmetics', 'Lipstick', 'Tape', 'Deodorant']
# Detected labels for post1044_img3.jpg
# ['Head', 'Person', 'Face', 'Happy', 'Smile', 'Accessories', 'Jewelry', 'Necklace', 'Clothing', 'Swimwear', 'People', 'Adult', 'Female', 'Woman', 'Cosmetics', 'Lipstick', 'Bottle', 'Perfume', 'Laughing']
# Detected labels for post1044_img2.jpg
# ['Head', 'Person', 'Face', 'Accessories', 'Jewelry', 'Necklace', 'Body Part', 'Neck']
# Detected labels for post1044_img4.jpg
# ['Flower', 'Petal', 'Plant', 'Animal', 'Sea Life']
# Detected labels for post1035_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Body Part', 'Finger', 'Hand', 'Cosmetics', 'Lipstick', 'Blonde', 'Hair', 'Clothing', 'Dress', 'Evening Dress', 'Formal Wear', 'Head', 'Face', 'Bottle', 'Perfume', 'Skin', 'Tattoo']
# Detected labels for post1034_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Lotion']
# Detected labels for post1031_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume']
# Detected labels for post1027_img1.jpg
# ['Cosmetics', 'Lipstick', 'Electronics', 'Mobile Phone', 'Phone', 'Bottle', 'Perfume', 'Animal', 'Cat', 'Mammal', 'Pet', 'Clapperboard']
# Detected labels for post1025_img1.jpg
# ['Hair', 'Person', 'Bun (Hairstyle)']
# Detected labels for post1025_img2.jpg
# ['Hair', 'Person', 'Adult', 'Bride', 'Female', 'Wedding', 'Woman', 'Bun (Hairstyle)']
# Detected labels for post1021_img1.jpg
# ['Cosmetics', 'Lipstick', 'Clothing', 'Footwear', 'Shoe']
# Detected labels for post1021_img2.jpg
# ['Cosmetics', 'Brush', 'Device', 'Tool', 'Lipstick']
# Detected labels for post1018_img1.jpg
# ['Person', 'Bag', 'City', 'Architecture', 'Building', 'House', 'Housing', 'Staircase', 'Accessories', 'Glasses', 'Postal Office']
# Detected labels for post1011_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1006_img1.jpg
# ['Bottle', 'Aftershave', 'Shaker', 'Cosmetics']
# Detected labels for post1000_img1.jpg
# ['Text', 'Advertisement', 'Business Card', 'Paper', 'Poster']
# Detected labels for post998_img1.jpg
# ['Pen', 'Face', 'Head', 'Person', 'Paper', 'Text']
# Detected labels for post995_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Baby', 'Person', 'Can', 'Tin']
# Detected labels for post983_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume', 'Furniture']
# Detected labels for post975_img1.jpg
# ['Key']
# Detected labels for post975_img2.jpg
# ['Key', 'Cosmetics', 'Lipstick', 'Cup']
# Detected labels for post975_img3.jpg
# ['Key', 'Dynamite', 'Weapon']
# Detected labels for post972_img1.jpg
# ['People', 'Person', 'Flower', 'Plant', 'Rose']
# Detected labels for post968_img1.jpg
# ['Head', 'Person', 'Face', 'Cosmetics', 'Electrical Device', 'Switch', 'Makeup', 'Lipstick', 'Hockey', 'Ice Hockey', 'Ice Hockey Puck', 'Rink', 'Skating', 'Sport']
# Detected labels for post955_img1.jpg
# ['Brown Hair', 'Hair', 'Person', 'Curly Hair', 'Smoke Pipe', 'Accessories', 'Jewelry', 'Necklace', 'Face', 'Head']
# Detected labels for post952_img1.jpg
# ['Cosmetics', 'Lipstick', 'Blade', 'Razor', 'Weapon']
# Detected labels for post938_img1.jpg
# ['Cosmetics', 'Tape', 'Bottle']
# Detected labels for post934_img1.jpg
# ['Grass', 'Plant', 'Lawn', 'Chair', 'Furniture']
# Detected labels for post924_img1.jpg
# ['Cosmetics', 'Lipstick', 'Appliance', 'Blow Dryer', 'Device', 'Electrical Device']
# Detected labels for post923_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post923_img2.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post919_img1.jpg
# ['Cup', 'Bread', 'Food', 'Beverage', 'Coffee', 'Coffee Cup', 'Cosmetics', 'Lipstick']
# Detected labels for post908_img1.jpg
# ['Food', 'Sweets', 'Cosmetics', 'Lipstick', 'Bread', 'Donut']
# Detected labels for post902_img1.jpg
# ['Bottle', 'Cosmetics', 'Sunscreen', 'Toothpaste', 'Can', 'Tin', 'Lotion']
# Detected labels for post902_img2.jpg
# ['Medication', 'Pill', 'Body Part', 'Hand', 'Nail', 'Person', 'Bottle', 'Cosmetics']
# Detected labels for post902_img3.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Tape']
# Detected labels for post902_img4.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Sunscreen', 'Medication', 'Pill']
# Detected labels for post899_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post895_img1.jpg
# ['Food', 'Fruit', 'Plant', 'Produce', 'Melon', 'Watermelon']
# Detected labels for post895_img2.jpg
# ['Food', 'Fruit', 'Plant', 'Produce', 'Melon', 'Watermelon', 'Tape', 'Pear', 'Can', 'Tin']
# Detected labels for post865_img1.jpg
# ['Adult', 'Bride', 'Female', 'Person', 'Wedding', 'Woman', 'Face', 'Head', 'Accessories', 'Jewelry', 'Necklace']
# Detected labels for post865_img2.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post864_img1.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Art', 'Collage', 'Accessories', 'Bag', 'Handbag', 'Adult', 'Female', 'Woman', 'Credit Card', 'Text', 'Face', 'Head']
# Detected labels for post855_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume', 'Face', 'Head', 'Person']
# Detected labels for post850_img1.jpg
# ['Child', 'Female', 'Girl', 'Person', 'Hair', 'Braid']
# Detected labels for post840_img1.jpg
# ['Cream', 'Dessert', 'Food', 'Ice Cream', 'Cup', 'Disposable Cup', 'Brush', 'Device', 'Tool', 'Toothbrush', 'Cosmetics', 'Accessories', 'Glasses']
# Detected labels for post839_img1.jpg
# ['Cosmetics', 'Cream', 'Dessert', 'Food', 'Frozen Yogurt', 'Nail Polish', 'Tape']
# Detected labels for post837_img1.jpg
# ['Text', 'City']
# Detected labels for post831_img1.jpg
# ['Berry', 'Food', 'Fruit', 'Plant', 'Produce', 'Blueberry', 'Blackberry']
# Detected labels for post823_img1.jpg
# ['Fun', 'Leisure Activities', 'Picnic', 'Picnic Basket', 'People', 'Person', 'Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post816_img1.jpg
# ['Cosmetics', 'Lipstick', 'Tape', 'Business Card', 'Paper', 'Text']
# Detected labels for post807_img1.jpg
# ['Jar', 'Bottle']
# Detected labels for post804_img1.jpg
# ['Food', 'Fruit', 'Plant', 'Produce', 'Accessories', 'Bag', 'Handbag', 'Apple', 'Peach', 'Ball', 'Sport', 'Tennis', 'Tennis Ball', 'Baby', 'Person', 'Pear']
# Detected labels for post788_img1.jpg
# ['Animal', 'Bird', 'Tape', 'Clothing', 'Footwear', 'Shoe', 'Accessories', 'Sunglasses', 'Bottle', 'Cosmetics', 'Perfume', 'Food', 'Sweets', 'Fruit', 'Plant', 'Produce', 'Cream', 'Dessert', 'Ice Cream', 'Candle']
# Detected labels for post782_img1.jpg
# ['Dimples', 'Face', 'Head', 'Person', 'Brown Hair', 'Hair', 'Bottle', 'Cosmetics', 'Perfume', 'Happy', 'Smile']
# Detected labels for post777_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Lipstick', 'Toothpaste']
# Detected labels for post776_img1.jpg
# ['Cosmetics', 'Bottle', 'Perfume', 'Nail Polish']
# Detected labels for post770_img1.jpg
# ['Triangle', 'Business Card', 'Paper', 'Text']
# Detected labels for post767_img1.jpg
# ['Basket', 'Accessories', 'Bag', 'Handbag', 'Person', 'Adult', 'Male', 'Man', 'Shopping Basket', 'Shop', 'Indoors']
# Detected labels for post767_img2.jpg
# ['Bottle', 'Tin']
# Detected labels for post767_img3.jpg
# ['Baseball Cap', 'Cap', 'Clothing', 'Hat', 'Appliance', 'Blow Dryer', 'Device', 'Electrical Device', 'Adult', 'Female', 'Person', 'Woman']
# Detected labels for post764_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post758_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post754_img1.jpg
# ['Herbal', 'Herbs', 'Plant', 'Bottle', 'Cosmetics', 'Perfume', 'Flower', 'Rose']
# Detected labels for post750_img1.jpg
# ['Gauge', 'Tachometer']
# Detected labels for post747_img1.jpg
# ['Food', 'Fruit', 'Plant', 'Produce', 'Bottle', 'Lotion', 'Cosmetics', 'Perfume', 'Melon']
# Detected labels for post744_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post743_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume']
# Detected labels for post741_img1.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Clothing', 'Coat', 'Jacket', 'Adult', 'Female', 'Woman', 'Brush', 'Device', 'Tool', 'Accessories', 'Jewelry', 'Ring', 'Blonde', 'Hair', 'Face', 'Head']
# Detected labels for post741_img2.jpg
# ['Body Part', 'Hand', 'Person', 'Game', 'First Aid']
# Detected labels for post735_img1.jpg
# ['Cosmetics', 'Lipstick', 'Dynamite', 'Weapon', 'Clothing', 'Footwear', 'Shoe', 'Blade', 'Dagger', 'Knife']
# Detected labels for post735_img2.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post719_img1.jpg
# ['Person', 'Skin', 'Adult', 'Female', 'Woman', 'Head', 'Face', 'Cosmetics']
# Detected labels for post711_img1.jpg
# ['Electrical Device', 'Switch', 'Jar', 'Cup', 'Disposable Cup', 'Bottle', 'Cosmetics', 'Perfume', 'Face', 'Head', 'Person', 'Adult', 'Female', 'Woman']
# Detected labels for post709_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post701_img1.jpg
# ['Body Part', 'Hand', 'Person', 'Wrist', 'Finger', 'Skin', 'Tattoo']
# Detected labels for post694_img1.jpg
# ['Cosmetics', 'Face', 'Head', 'Person', 'Lipstick', 'Tape']
# Detected labels for post692_img1.jpg
# ['Cosmetics', 'First Aid', 'Lipstick', 'Tape', 'QR Code', 'Accessories', 'Wallet', 'Furniture']
# Detected labels for post687_img1.jpg
# ['Head', 'Person', 'Face', 'Cosmetics', 'Makeup', 'Can', 'Tin', 'Computer Hardware', 'Electronics', 'Hardware', 'Mouse', 'Bottle', 'Lotion']
# Detected labels for post675_img1.jpg
# ['Cosmetics', 'Lipstick', 'Brush', 'Device', 'Tool', 'Head', 'Person', 'Face', 'Bottle', 'Perfume']
# Detected labels for post662_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume', 'Tape']
# Detected labels for post655_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Lipstick']
# Detected labels for post651_img1.jpg
# ['Food', 'Honey', 'Bottle', 'Cosmetics', 'Perfume', 'Honeycomb']
# Detected labels for post645_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post642_img1.jpg
# ['Photography', 'Face', 'Head', 'Person', 'Portrait', 'Clothing', 'Coat', 'Jacket', 'Accessories', 'Jewelry', 'Necklace', 'Cup', 'Disposable Cup']
# Detected labels for post640_img1.jpg
# ['Paint Container', 'Palette', 'Brush', 'Device', 'Tool', 'Cosmetics']
# Detected labels for post637_img1.jpg
# ['Accessories', 'Bag', 'Handbag', 'Purse', 'Arm', 'Body Part', 'Person']
# Detected labels for post627_img1.jpg
# ['Cosmetics', 'Bottle']
# Detected labels for post623_img1.jpg
# ['Animal', 'Canine', 'Dog', 'Mammal', 'Pet', 'Accessories', 'Bag', 'Handbag', 'Cosmetics', 'Lipstick', 'Bottle', 'Pen', 'Perfume']
# Detected labels for post616_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume']
# Detected labels for post615_img1.jpg
# ['Berry', 'Food', 'Fruit', 'Plant', 'Produce', 'Strawberry', 'Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post610_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Lipstick']
# Detected labels for post597_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Shaker', 'Cup']
# Detected labels for post591_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post586_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Aftershave', 'Mortar Shell', 'Weapon']
# Detected labels for post579_img1.jpg
# ['Cup', 'Beverage', 'Chocolate', 'Dessert', 'Food', 'Hot Chocolate', 'Saucer', 'Meal', 'Cutlery', 'Spoon', 'Art', 'Porcelain', 'Pottery', 'Cream', 'Ice Cream', 'Dish', 'Cosmetics', 'Lipstick']
# Detected labels for post563_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post562_img1.jpg
# ['Advertisement', 'Poster', 'Art', 'Graphics', 'Person', 'People', 'Face', 'Head']
# Detected labels for post552_img1.jpg
# ['Food', 'Sweets', 'Medication', 'Pill']
# Detected labels for post548_img1.jpg
# ['Head', 'Person', 'Text', 'Face']
# Detected labels for post544_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume']
# Detected labels for post542_img1.jpg
# ['Cosmetics', 'Lipstick', 'Tape', 'Brush', 'Device', 'Tool', 'Toothbrush']
# Detected labels for post540_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post537_img2.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Advertisement']
# Detected labels for post537_img1.jpg
# ['Text', 'Business Card', 'Paper', 'Document', 'Driving License', 'Id Cards', 'Face', 'Head', 'Person']
# Detected labels for post537_img3.jpg
# ['Cosmetics', 'Lipstick', 'Brush', 'Device', 'Tool', 'Toothbrush', 'Tape']
# Detected labels for post537_img4.jpg
# ['Bag', 'Tote Bag', 'Shopping Bag', 'Accessories', 'Handbag']
# Detected labels for post535_img1.jpg
# ['Accessories', 'Bag', 'Handbag', 'Furniture']
# Detected labels for post530_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume']
# Detected labels for post528_img1.jpg
# ['Jar', 'Cup', 'Pottery']
# Detected labels for post526_img1.jpg
# ['Bottle', 'Cosmetics', 'Lotion']
# Detected labels for post520_img1.jpg
# ['Face', 'Head', 'Person', 'Cosmetics', 'Tape', 'Makeup', 'Medication', 'Pill']
# Detected labels for post516_img1.jpg
# ['Food', 'Plant', 'Produce', 'Pumpkin', 'Vegetable', 'Fireplace', 'Indoors', 'Lunch', 'Meal', 'Bottle', 'Cosmetics', 'Perfume', 'Beverage', 'Coffee', 'Coffee Cup']
# Detected labels for post514_img1.jpg
# ['Bottle', 'Cosmetics', 'Head', 'Person', 'Face']
# Detected labels for post510_img1.jpg
# ['Cosmetics', 'Bottle', 'Perfume', 'Nail Polish']
# Detected labels for post504_img1.jpg
# ['Clothing', 'Footwear', 'Shoe', 'High Heel', 'Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post492_img1.jpg
# ['Cosmetics', 'Bottle', 'Perfume', 'Lipstick', 'Electronics']
# Detected labels for post479_img1.jpg
# ['Food', 'Sweets', 'Bottle', 'Cosmetics', 'Perfume', 'Macarons']
# Detected labels for post472_img1.jpg
# ['Bottle', 'Shaker', 'Cup', 'Disposable Cup', 'Cosmetics']
# Detected labels for post463_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post459_img1.jpg
# ['Cosmetics', 'Bottle', 'Perfume', 'Lipstick']
# Detected labels for post455_img1.jpg
# ['Cosmetics', 'Lipstick', 'Dynamite', 'Weapon', 'Bottle', 'Perfume']
# Detected labels for post444_img1.jpg
# ['Cosmetics', 'Accessories', 'Bag', 'Handbag', 'Pen', 'Bottle', 'Lipstick']
# Detected labels for post442_img1.jpg
# ['Cleaning', 'Person', 'Credit Card', 'Text', 'Scissors', 'Weapon']
# Detected labels for post435_img1.jpg
# ['Cosmetics', 'Bottle', 'Perfume', 'Lipstick', 'Nail Polish']
# Detected labels for post432_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post424_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Lipstick', 'Cutlery', 'Fork', 'Bread', 'Food', 'Plate']
# Detected labels for post422_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume', 'Business Card', 'Paper', 'Text', 'Face', 'Head', 'Person']
# Detected labels for post417_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume', 'Nail Polish']
# Detected labels for post414_img1.jpg
# ['Bottle', 'Beverage', 'Juice', 'Cosmetics', 'Perfume', 'Lipstick', 'Smoothie']
# Detected labels for post1231_img2.jpg
# ['Cosmetics', 'Lipstick', 'Advertisement', 'Bottle', 'Perfume', 'Poster']
# Detected labels for post1231_img3.jpg
# ['Head', 'Person', 'Face', 'Adult', 'Female', 'Woman', 'Bride', 'Wedding', 'Art', 'Collage']
# Detected labels for post1231_img1.jpg
# ['Accessories', 'Buckle', 'Furniture', 'First Aid', 'Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1231_img4.jpg
# ['Brush', 'Device', 'Tool', 'Head', 'Person']
# Detected labels for post411_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Lotion']
# Detected labels for post402_img1.jpg
# ['Cup', 'Beverage', 'Chocolate', 'Dessert', 'Food', 'Hot Chocolate', 'Cosmetics', 'Lipstick']
# Detected labels for post399_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'First Aid', 'Lipstick', 'Dynamite', 'Weapon']
# Detected labels for post399_img2.jpg
# ['Cosmetics', 'Bottle', 'Perfume', 'Face', 'Head', 'Person']
# Detected labels for post397_img1.jpg
# ['Flower', 'Flower Arrangement', 'Flower Bouquet', 'Plant', 'Cosmetics', 'Lipstick', 'Bottle', 'Perfume', 'Can', 'Tin', 'Test Tube']
# Detected labels for post388_img1.jpg
# ['File Binder', 'Business Card', 'Paper', 'Text', 'File Folder']
# Detected labels for post381_img1.jpg
# ['Cosmetics', 'Bottle', 'Perfume']
# Detected labels for post381_img2.jpg
# ['Cosmetics', 'Lipstick', 'Person', 'Bottle', 'Perfume']
# Detected labels for post381_img3.jpg
# ['Child', 'Female', 'Girl', 'Person', 'Figurine', 'Plant', 'Tree']
# Detected labels for post381_img4.jpg
# ['Cosmetics', 'Lipstick', 'Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Bottle', 'Perfume']
# Detected labels for post379_img1.jpg
# ['Food', 'Fruit', 'Plant', 'Produce', 'Book', 'Publication', 'Cosmetics', 'Lipstick', 'Peach', 'Tape']
# Detected labels for post379_img2.jpg
# ['Head', 'Person', 'Face', 'Happy', 'Smile', 'Dimples', 'Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post379_img3.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Tape']
# Detected labels for post379_img4.jpg
# ['Body Part', 'Face', 'Head', 'Neck', 'Person', 'Adult', 'Female', 'Woman']
# Detected labels for post378_img3.jpg
# ['Cosmetics', 'Lipstick', 'Advertisement', 'Poster', 'Firearm', 'Weapon', 'Text', 'Credit Card']
# Detected labels for post378_img2.jpg
# ['Advertisement', 'Poster']
# Detected labels for post378_img5.jpg
# ['Cosmetics', 'Lipstick', 'Mailbox']
# Detected labels for post378_img4.jpg
# ['Cosmetics', 'Lipstick', 'Advertisement', 'Bottle', 'Lotion']
# Detected labels for post378_img1.jpg
# ['Advertisement', 'Poster', 'Book', 'Publication', 'Art', 'Graphics', 'Text']
# Detected labels for post378_img6.jpg
# ['Text', 'Female', 'Girl', 'Person', 'Teen', 'Head', 'Face']
# Detected labels for post376_img1.jpg
# ['Cream', 'Dessert', 'Food', 'Ice Cream', 'Cosmetics', 'Lipstick', 'Soft Serve Ice Cream', 'Frozen Yogurt']
# Detected labels for post375_img1.jpg
# ['Bag', 'Accessories', 'Handbag', 'Tote Bag', 'Transportation', 'Vehicle']
# Detected labels for post375_img2.jpg
# ['Bag', 'Cup', 'Disposable Cup', 'Shopping Bag', 'Beverage']
# Detected labels for post375_img3.jpg
# ['Person', 'Skin', 'Body Part', 'Hand']
# Detected labels for post375_img4.jpg
# ['Basket', 'Bag', 'Tote Bag', 'Shopping Basket']
# Detected labels for post360_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Head', 'Face', 'Jar', 'Food', 'Fruit', 'Plant', 'Produce']
# Detected labels for post360_img2.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Food', 'Head', 'Person', 'Face', 'Tape']
# Detected labels for post349_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post345_img1.jpg
# ['Plant', 'Potted Plant', 'Tree', 'Flower', 'Flower Arrangement', 'Cream', 'Dessert', 'Food', 'Icing', 'Animal', 'Canine', 'Dog', 'Mammal', 'Pet', 'Cup', 'Lunch', 'Meal', 'Ice Cream', 'Beverage', 'Coffee', 'Coffee Cup', 'Furniture', 'Table']
# Detected labels for post341_img1.jpg
# ['Clothing', 'Coat', 'Jacket', 'Blazer', 'Pants', 'Face', 'Head', 'Person', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Accessories', 'Bag', 'Handbag', 'Advertisement', 'Poster', 'City', 'Road', 'Street', 'Urban', 'Male', 'Man', 'People', 'Jeans', 'Clapperboard', 'Plant', 'Tree']
# Detected labels for post336_img1.jpg
# ['Clothing', 'Glove', 'Plate', 'Beverage', 'Milk', 'Food', 'Food Presentation']
# Detected labels for post334_img1.jpg
# ['Advertisement', 'Cosmetics', 'Lipstick', 'People', 'Person', 'Poster']
# Detected labels for post332_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume']
# Detected labels for post327_img1.jpg
# ['Bag', 'Advertisement', 'Poster', 'Accessories', 'Handbag', 'Adult', 'Bride', 'Female', 'Person', 'Wedding', 'Woman', 'Text']
# Detected labels for post321_img1.jpg
# ['Text', 'Accessories', 'Formal Wear', 'Tie', 'Business Card', 'Paper']
# Detected labels for post321_img2.jpg
# ['Bottle', 'Lotion', 'Cosmetics']
# Detected labels for post321_img3.jpg
# ['Bottle', 'Dynamite', 'Weapon', 'Advertisement', 'Cosmetics']
# Detected labels for post321_img4.jpg
# ['Bottle', 'Cosmetics', 'Sunscreen', 'Lotion']
# Detected labels for post321_img5.jpg
# ['Bottle', 'Cosmetics', 'Lipstick']
# Detected labels for post321_img6.jpg
# ['Bottle', 'Cosmetics', 'Sunscreen', 'Lotion', 'Dynamite', 'Weapon']
# Detected labels for post321_img7.jpg
# ['Bottle', 'Cosmetics', 'Sunscreen']
# Detected labels for post321_img8.jpg
# ['Bottle', 'Cosmetics', 'Sunscreen']
# Detected labels for post321_img9.jpg
# ['Bottle', 'Cosmetics', 'Sunscreen']
# Detected labels for post319_img1.jpg
# ['Handle', 'Accessories', 'Cross', 'Symbol', 'Jewelry', 'Locket', 'Pendant']
# Detected labels for post318_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume']
# Detected labels for post301_img1.jpg
# ['Bottle', 'Lotion', 'Food']
# Detected labels for post1015_img3.jpg
# ['Bottle', 'Cosmetics', 'Sunscreen', 'Perfume']
# Detected labels for post1015_img1.jpg
# ['Bottle', 'Cosmetics', 'Sunscreen', 'Lotion', 'Lipstick', 'Perfume']
# Detected labels for post1015_img2.jpg
# ['Berry', 'Blueberry', 'Food', 'Fruit', 'Plant', 'Produce', 'Bottle', 'Cosmetics', 'Perfume', 'Lotion']
# Detected labels for post273_img1.jpg
# ['Treasure', 'Accessories', 'Jewelry', 'Necklace', 'Cosmetics', 'Lipstick', 'Tape', 'Dynamite', 'Weapon']
# Detected labels for post269_img1.jpg
# ['Cosmetics', 'Lipstick', 'Egg', 'Food', 'Box', 'Medication', 'Pill', 'Tape', 'Brush', 'Device', 'Tool', 'Makeup']
# Detected labels for post252_img1.jpg
# ['Advertisement', 'Poster', 'Plate', 'Food', 'Meal']
# Detected labels for post249_img1.jpg
# ['Cosmetics', 'Lipstick', 'Dynamite', 'Weapon', 'Bottle']
# Detected labels for post237_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post232_img1.jpg
# ['Accessories', 'Bag', 'Handbag', 'Purse', 'Art', 'Collage', 'Clapperboard', 'Adult', 'Female', 'Person', 'Woman']
# Detected labels for post225_img2.jpg
# ['Head', 'Person', 'Face', 'Adult', 'Female', 'Woman', 'Art', 'Collage', 'Photography', 'Portrait']
# Detected labels for post225_img1.jpg
# ['Cosmetics', 'Lipstick', 'Food', 'Fruit', 'Plant', 'Produce', 'Nail Polish']
# Detected labels for post225_img3.jpg
# ['Cosmetics', 'Makeup', 'Device', 'Screwdriver', 'Tool', 'Adult', 'Bride', 'Female', 'Person', 'Wedding', 'Woman']
# Detected labels for post224_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics']
# Detected labels for post224_img2.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Perfume', 'Can', 'Tin']
# Detected labels for post224_img3.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Perfume', 'Lipstick']
# Detected labels for post221_img1.jpg
# ['Cosmetics', 'Mailbox', 'Lipstick']
# Detected labels for post221_img3.jpg
# ['Head', 'Person', 'Face', 'Photography', 'Portrait', 'Bottle', 'Shaker']
# Detected labels for post221_img4.jpg
# ['Clothing', 'Footwear', 'Shoe', 'High Heel', 'Pedestrian', 'Person', 'Adult', 'Female', 'Woman', 'Bag', 'Accessories', 'Handbag']
# Detected labels for post221_img2.jpg
# ['Bag', 'Business Card', 'Paper', 'Text', 'Opening Present', 'Person']
# Detected labels for post220_img1.jpg
# ['Chart', 'Line Chart']
# Detected labels for post212_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Head', 'Face', 'Cosmetics', 'Lipstick', 'Bottle', 'Perfume', 'Photography', 'Portrait']
# Detected labels for post209_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post207_img1.jpg
# ['Accessories', 'Bag', 'Handbag', 'Purse']
# Detected labels for post203_img1.jpg
# ['Burger', 'Food', 'Sweets', 'Bread', 'Donut']
# Detected labels for post202_img1.jpg
# ['Cosmetics']
# Detected labels for post197_img1.jpg
# ['Bottle', 'Lotion', 'Face', 'Head', 'Person', 'Tape', 'Cosmetics']
# Detected labels for post197_img2.jpg
# ['Bottle', 'Lotion', 'Tape', 'Cosmetics']
# Detected labels for post190_img2.jpg
# ['Food', 'Sweets', 'Accessories', 'Diamond', 'Gemstone', 'Jewelry', 'Tape', 'Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post190_img1.jpg
# ['Food', 'Sweets', 'Tape', 'Cosmetics', 'People', 'Person', 'Bottle', 'Perfume']
# Detected labels for post161_img1.jpg
# ['Clothing', 'Footwear', 'Shoe', 'High Heel', 'Fashion', 'Premiere', 'Red Carpet']
# Detected labels for post159_img1.jpg
# ['Text', 'Menu', 'Person']
# Detected labels for post154_img1.jpg
# ['Helmet', 'Accessories', 'Sunglasses', 'Child', 'Female', 'Girl', 'Person', 'Clothing', 'Hardhat', 'Toothpaste', 'Cosmetics', 'Lipstick', 'Face', 'Head', 'Bag', 'Handbag']
# Detected labels for post154_img2.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Lipstick', 'Sunscreen', 'Beach', 'Coast', 'Nature', 'Outdoors', 'Sea', 'Shoreline', 'Water']
# Detected labels for post154_img3.jpg
# ['Dynamite', 'Weapon', 'Bottle', 'Cosmetics', 'Perfume', 'Baby', 'Person', 'Outdoors']
# Detected labels for post150_img1.jpg
# ['Indoors', 'Shop', 'Market', 'Grocery Store', 'Supermarket', 'Person']
# Detected labels for post150_img2.jpg
# ['Person', 'Symbol', 'Text', 'Number']
# Detected labels for post141_img1.jpg
# ['Food', 'Sweets', 'Art', 'Porcelain', 'Pottery', 'Plate']
# Detected labels for post141_img2.jpg
# ['People', 'Person', 'Food', 'Fruit', 'Plant', 'Produce', 'Cosmetics', 'Lipstick', 'Cherry', 'Cream', 'Dessert', 'Tape', 'Cake', 'Cupcake', 'Flower', 'Ice Cream']
# Detected labels for post141_img3.jpg
# ['Burger', 'Food', 'Flower', 'Plant', 'Rose', 'Cup', 'Meal', 'Cake', 'Dessert', 'Wedding', 'Wedding Cake', 'Saucer', 'Dahlia', 'Dish']
# Detected labels for post141_img4.jpg
# ['Accessories', 'Cream', 'Dessert', 'Food', 'Icing', 'Jewelry', 'People', 'Person', 'Cake', 'Cupcake', 'Pearl']
# Detected labels for post134_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Food', 'Fruit', 'Plant', 'Produce', 'Flower', 'Petal', 'Pear']
# Detected labels for post116_img1.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Paper', 'Document', 'Receipt', 'Text', 'Blade', 'Dagger', 'Knife', 'Weapon', 'Art']
# Detected labels for post103_img1.jpg
# ['Face', 'Happy', 'Head', 'Person', 'Smile', 'Photography', 'Portrait', 'Child', 'Female', 'Girl']
# Detected labels for post103_img2.jpg
# ['Head', 'Person', 'Face', 'Photography', 'Portrait']
# Detected labels for post103_img3.jpg
# ['People', 'Person', 'Face', 'Head', 'Photography', 'Portrait', 'Baby', 'Clothing', 'Pants', 'Happy']
# Detected labels for post103_img4.jpg
# ['Photography', 'Face', 'Head', 'Person', 'Portrait', 'Clothing', 'Hat', 'Happy', 'Smile', 'Adult', 'Female', 'Woman', 'Dress']
# Detected labels for post100_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post94_img1.jpg
# ['Person', 'Skin', 'Tattoo', 'Adult', 'Female', 'Woman', 'Head', 'Face', 'Accessories', 'Jewelry', 'Necklace', 'Clothing', 'Scarf', 'Cosmetics', 'Lipstick']
# Detected labels for post76_img1.jpg
# ['Accessories', 'Bag', 'Handbag', 'Sunglasses', 'Purse', 'Cosmetics', 'Bottle', 'Perfume', 'Head', 'Person', 'Face']
# Detected labels for post76_img2.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post61_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post45_img1.jpg
# ['Bag', 'Advertisement', 'Accessories', 'Handbag', 'Poster', 'Clothing', 'Footwear', 'Shoe']
# Detected labels for post45_img3.jpg
# ['Cosmetics', 'Lipstick', 'Text']
# Detected labels for post45_img2.jpg
# ['Electronics', 'Mobile Phone', 'Phone', 'Text']
# Detected labels for post45_img6.jpg
# ['Electronics', 'Phone', 'Smoke Pipe', 'Mobile Phone', 'Baby', 'Person', 'Text', 'Advertisement']
# Detected labels for post45_img5.jpg
# ['Bulldozer', 'Machine', 'Computer', 'Electronics', 'Pc']
# Detected labels for post45_img4.jpg
# ['QR Code', 'Text']
# Detected labels for post34_img1.jpg
# ['Accessories', 'Bag', 'Handbag', 'Basket', 'First Aid', 'Cabinet', 'Furniture', 'Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post29_img2.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume', 'Device', 'Screwdriver', 'Tool']
# Detected labels for post29_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Accessories', 'Bag', 'Handbag', 'Figurine', 'Clothing', 'Hosiery', 'Sock', 'Cosmetics', 'Lipstick', 'Toy', 'Doll']
# Detected labels for post28_img1.jpg
# ['Cosmetics', 'Lipstick', 'Can', 'Tin']
# Detected labels for post23_img1.jpg
# ['Indoors', 'Interior Design', 'Adult', 'Female', 'Person', 'Woman', 'Bag', 'Shop']
# Detected labels for post19_img1.jpg
# ['Accessories', 'Bag', 'Handbag', 'Clothing', 'Footwear', 'Shoe', 'Cup', 'Disposable Cup', 'High Heel', 'Person', 'Body Part', 'Finger', 'Hand']
# Detected labels for post16_img1.jpg
# ['Indoors', 'Shop', 'Person', 'Doll', 'Toy', 'Face', 'Head', 'Clothing', 'Footwear', 'Shoe']
# Detected labels for post15_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Accessories', 'Sunglasses', 'Clothing', 'Glove', 'Long Sleeve', 'Sleeve', 'Photography', 'Head', 'Alcohol', 'Beverage', 'Face']
# Detected labels for post12_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Body Part', 'Finger', 'Hand', 'Head', 'Face', 'Accessories', 'Jewelry', 'Necklace', 'Clothing', 'Long Sleeve', 'Sleeve', 'Happy', 'Smile', 'Formal Wear', 'Suit', 'Bottle']
# Detected labels for post7_img1.jpg
# ['Egg', 'Food']
# Detected labels for post1_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Perfume', 'Face', 'Head', 'Person']

# %%
# Write out the results to a csv
with open(rekog_results_dir + f'labels_final_{username}.csv', 'w', newline = '') as csvfile:
    fieldnames = ['image_id', 'has_makeup', 'has_beauty_product', 'has_logo_or_branding',
 'is_fashion_related', 'is_beauty_scene', 'has_text', 'close_up', 'indoors', 'outdoors']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for entry in holder_labels:
        writer.writerow(entry)

# %%
face_labels = []

for imageFile in local_images:
    image_path = rekog_images_dir + imageFile
    try:
        image_bytes = resize_if_needed(image_path)
    except Exception as e:
        print(f"❌ Skipping {imageFile}: {e}")
        continue

    # Detect facial features
    face_response = client.detect_faces(Image={'Bytes': image_bytes}, Attributes=['ALL'])
    celeb_response = client.recognize_celebrities(Image={'Bytes': image_bytes})

    print('Detected faces and celebrities for ' + imageFile)

    temp_dict = {
        "image_id": imageFile,
        "face_count": 0,
        "has_smile": False,
        "has_female": False,
        "has_male": False,
        "dominant_emotion": None,
        "emotions": [],
        "has_happy_emotion": False,
        "has_confident_emotion": False,
        "has_celebrity": False,
        "celebrity_names": [],
        "has_unrecognized_face": False
    }

    # === CELEBRITY CHECK ===
    matched = celeb_response.get("CelebrityFaces", [])
    unmatched = celeb_response.get("UnrecognizedFaces", [])

    if matched:
        temp_dict["has_celebrity"] = True
        temp_dict["celebrity_names"] = [c["Name"] for c in matched]
    if unmatched:
        temp_dict["has_unrecognized_face"] = True

    # === FACIAL ATTRIBUTES ===
    faces = face_response.get('FaceDetails', [])
    temp_dict["face_count"] = len(faces)

    all_emotions = set()
    happy_detected = False
    confident_detected = False

    for face in faces:
        if face.get('Smile', {}).get('Value'):
            temp_dict["has_smile"] = True

        gender = face.get('Gender', {}).get('Value')
        if gender == 'Female':
            temp_dict["has_female"] = True
        elif gender == 'Male':
            temp_dict["has_male"] = True

        for emotion in face.get('Emotions', []):
            if emotion.get('Confidence', 0) >= 70:
                emotion_type = emotion.get('Type')
                all_emotions.add(emotion_type)

                if emotion_type == 'HAPPY':
                    happy_detected = True
                if emotion_type == 'CONFIDENT':
                    confident_detected = True

    temp_dict["emotions"] = list(all_emotions)
    temp_dict["has_happy_emotion"] = happy_detected
    temp_dict["has_confident_emotion"] = confident_detected
    if all_emotions:
        temp_dict["dominant_emotion"] = list(all_emotions)[0]

    face_labels.append(temp_dict)
# Out:
# Detected faces and celebrities for post1425_img1.jpg
# Detected faces and celebrities for post1422_img1.jpg
# Detected faces and celebrities for post1420_img1.jpg
# Detected faces and celebrities for post1415_img1.jpg
# Detected faces and celebrities for post1411_img1.jpg
# Detected faces and celebrities for post1409_img1.jpg
# Detected faces and celebrities for post1409_img2.jpg
# Detected faces and celebrities for post1409_img3.jpg
# Detected faces and celebrities for post1409_img4.jpg
# Detected faces and celebrities for post1407_img1.jpg
# Detected faces and celebrities for post1403_img1.jpg
# Detected faces and celebrities for post1401_img1.jpg
# Detected faces and celebrities for post1400_img1.jpg
# Detected faces and celebrities for post1400_img2.jpg
# Detected faces and celebrities for post1396_img1.jpg
# Detected faces and celebrities for post1396_img2.jpg
# Detected faces and celebrities for post1396_img3.jpg
# Detected faces and celebrities for post1396_img4.jpg
# Detected faces and celebrities for post1390_img1.jpg
# Detected faces and celebrities for post1385_img1.jpg
# Detected faces and celebrities for post1384_img1.jpg
# Detected faces and celebrities for post1382_img1.jpg
# Detected faces and celebrities for post1380_img1.jpg
# Detected faces and celebrities for post1380_img2.jpg
# Detected faces and celebrities for post1373_img1.jpg
# Detected faces and celebrities for post1364_img1.jpg
# Detected faces and celebrities for post1356_img1.jpg
# Detected faces and celebrities for post1349_img1.jpg
# Detected faces and celebrities for post1346_img1.jpg
# Detected faces and celebrities for post1339_img1.jpg
# Detected faces and celebrities for post1337_img1.jpg
# Detected faces and celebrities for post1336_img1.jpg
# Detected faces and celebrities for post1334_img1.jpg
# Detected faces and celebrities for post1333_img3.jpg
# Detected faces and celebrities for post1333_img4.jpg
# Detected faces and celebrities for post1331_img1.jpg
# Detected faces and celebrities for post1329_img1.jpg
# Detected faces and celebrities for post1326_img1.jpg
# Detected faces and celebrities for post1333_img1.jpg
# Detected faces and celebrities for post1333_img2.jpg
# Detected faces and celebrities for post1317_img1.jpg
# Detected faces and celebrities for post1316_img1.jpg
# Detected faces and celebrities for post1314_img1.jpg
# Detected faces and celebrities for post1314_img3.jpg
# Detected faces and celebrities for post1314_img2.jpg
# Detected faces and celebrities for post1312_img1.jpg
# Detected faces and celebrities for post1305_img1.jpg
# Detected faces and celebrities for post1294_img1.jpg
# Detected faces and celebrities for post1293_img1.jpg
# Detected faces and celebrities for post1290_img1.jpg
# Detected faces and celebrities for post1284_img1.jpg
# Detected faces and celebrities for post1281_img1.jpg
# Detected faces and celebrities for post1278_img1.jpg
# Detected faces and celebrities for post1277_img1.jpg
# Detected faces and celebrities for post1275_img1.jpg
# Detected faces and celebrities for post1272_img1.jpg
# Detected faces and celebrities for post1268_img1.jpg
# Detected faces and celebrities for post1266_img1.jpg
# Detected faces and celebrities for post1261_img1.jpg
# Detected faces and celebrities for post1259_img1.jpg
# Detected faces and celebrities for post1256_img1.jpg
# Detected faces and celebrities for post1250_img1.jpg
# Detected faces and celebrities for post1241_img1.jpg
# Detected faces and celebrities for post1240_img1.jpg
# Detected faces and celebrities for post1237_img1.jpg
# Detected faces and celebrities for post1229_img1.jpg
# Detected faces and celebrities for post1207_img1.jpg
# Detected faces and celebrities for post1201_img1.jpg
# Detected faces and celebrities for post1196_img1.jpg
# Detected faces and celebrities for post1192_img1.jpg
# Detected faces and celebrities for post1187_img1.jpg
# Detected faces and celebrities for post1183_img1.jpg
# Detected faces and celebrities for post1180_img1.jpg
# Detected faces and celebrities for post1177_img1.jpg
# Detected faces and celebrities for post1177_img2.jpg
# Detected faces and celebrities for post1177_img3.jpg
# Detected faces and celebrities for post1177_img4.jpg
# Detected faces and celebrities for post1174_img1.jpg
# Detected faces and celebrities for post1170_img1.jpg
# Detected faces and celebrities for post1170_img2.jpg
# Detected faces and celebrities for post1169_img1.jpg
# Detected faces and celebrities for post1164_img1.jpg
# Detected faces and celebrities for post1154_img1.jpg
# Detected faces and celebrities for post1149_img1.jpg
# Detected faces and celebrities for post1140_img1.jpg
# Detected faces and celebrities for post1138_img1.jpg
# Detected faces and celebrities for post1137_img1.jpg
# Detected faces and celebrities for post1134_img1.jpg
# Detected faces and celebrities for post1131_img1.jpg
# Detected faces and celebrities for post1130_img1.jpg
# Detected faces and celebrities for post1125_img1.jpg
# Detected faces and celebrities for post1122_img1.jpg
# Detected faces and celebrities for post1121_img1.jpg
# Detected faces and celebrities for post1107_img1.jpg
# Detected faces and celebrities for post1107_img2.jpg
# Detected faces and celebrities for post1107_img3.jpg
# Detected faces and celebrities for post1107_img4.jpg
# Detected faces and celebrities for post1102_img1.jpg
# Detected faces and celebrities for post1101_img1.jpg
# Detected faces and celebrities for post1085_img1.jpg
# Detected faces and celebrities for post1082_img1.jpg
# Detected faces and celebrities for post1082_img2.jpg
# Detected faces and celebrities for post1081_img1.jpg
# Detected faces and celebrities for post1081_img2.jpg
# Detected faces and celebrities for post1081_img3.jpg
# Detected faces and celebrities for post1081_img4.jpg
# Detected faces and celebrities for post1078_img1.jpg
# Detected faces and celebrities for post1076_img1.jpg
# Detected faces and celebrities for post1060_img1.jpg
# Detected faces and celebrities for post1058_img1.jpg
# Detected faces and celebrities for post1051_img1.jpg
# Detected faces and celebrities for post1051_img2.jpg
# Detected faces and celebrities for post1044_img1.jpg
# Detected faces and celebrities for post1044_img3.jpg
# Detected faces and celebrities for post1044_img2.jpg
# Detected faces and celebrities for post1044_img4.jpg
# Detected faces and celebrities for post1035_img1.jpg
# Detected faces and celebrities for post1034_img1.jpg
# Detected faces and celebrities for post1031_img1.jpg
# Detected faces and celebrities for post1027_img1.jpg
# Detected faces and celebrities for post1025_img1.jpg
# Detected faces and celebrities for post1025_img2.jpg
# Detected faces and celebrities for post1021_img1.jpg
# Detected faces and celebrities for post1021_img2.jpg
# Detected faces and celebrities for post1018_img1.jpg
# Detected faces and celebrities for post1011_img1.jpg
# Detected faces and celebrities for post1006_img1.jpg
# Detected faces and celebrities for post1000_img1.jpg
# Detected faces and celebrities for post998_img1.jpg
# Detected faces and celebrities for post995_img1.jpg
# Detected faces and celebrities for post983_img1.jpg
# Detected faces and celebrities for post975_img1.jpg
# Detected faces and celebrities for post975_img2.jpg
# Detected faces and celebrities for post975_img3.jpg
# Detected faces and celebrities for post972_img1.jpg
# Detected faces and celebrities for post968_img1.jpg
# Detected faces and celebrities for post955_img1.jpg
# Detected faces and celebrities for post952_img1.jpg
# Detected faces and celebrities for post938_img1.jpg
# Detected faces and celebrities for post934_img1.jpg
# Detected faces and celebrities for post924_img1.jpg
# Detected faces and celebrities for post923_img1.jpg
# Detected faces and celebrities for post923_img2.jpg
# Detected faces and celebrities for post919_img1.jpg
# Detected faces and celebrities for post908_img1.jpg
# Detected faces and celebrities for post902_img1.jpg
# Detected faces and celebrities for post902_img2.jpg
# Detected faces and celebrities for post902_img3.jpg
# Detected faces and celebrities for post902_img4.jpg
# Detected faces and celebrities for post899_img1.jpg
# Detected faces and celebrities for post895_img1.jpg
# Detected faces and celebrities for post895_img2.jpg
# Detected faces and celebrities for post865_img1.jpg
# Detected faces and celebrities for post865_img2.jpg
# Detected faces and celebrities for post864_img1.jpg
# Detected faces and celebrities for post855_img1.jpg
# Detected faces and celebrities for post850_img1.jpg
# Detected faces and celebrities for post840_img1.jpg
# Detected faces and celebrities for post839_img1.jpg
# Detected faces and celebrities for post837_img1.jpg
# Detected faces and celebrities for post831_img1.jpg
# Detected faces and celebrities for post823_img1.jpg
# Detected faces and celebrities for post816_img1.jpg
# Detected faces and celebrities for post807_img1.jpg
# Detected faces and celebrities for post804_img1.jpg
# Detected faces and celebrities for post788_img1.jpg
# Detected faces and celebrities for post782_img1.jpg
# Detected faces and celebrities for post777_img1.jpg
# Detected faces and celebrities for post776_img1.jpg
# Detected faces and celebrities for post770_img1.jpg
# Detected faces and celebrities for post767_img1.jpg
# Detected faces and celebrities for post767_img2.jpg
# Detected faces and celebrities for post767_img3.jpg
# Detected faces and celebrities for post764_img1.jpg
# Detected faces and celebrities for post758_img1.jpg
# Detected faces and celebrities for post754_img1.jpg
# Detected faces and celebrities for post750_img1.jpg
# Detected faces and celebrities for post747_img1.jpg
# Detected faces and celebrities for post744_img1.jpg
# Detected faces and celebrities for post743_img1.jpg
# Detected faces and celebrities for post741_img1.jpg
# Detected faces and celebrities for post741_img2.jpg
# Detected faces and celebrities for post735_img1.jpg
# Detected faces and celebrities for post735_img2.jpg
# Detected faces and celebrities for post719_img1.jpg
# Detected faces and celebrities for post711_img1.jpg
# Detected faces and celebrities for post709_img1.jpg
# Detected faces and celebrities for post701_img1.jpg
# Detected faces and celebrities for post694_img1.jpg
# Detected faces and celebrities for post692_img1.jpg
# Detected faces and celebrities for post687_img1.jpg
# Detected faces and celebrities for post675_img1.jpg
# Detected faces and celebrities for post662_img1.jpg
# Detected faces and celebrities for post655_img1.jpg
# Detected faces and celebrities for post651_img1.jpg
# Detected faces and celebrities for post645_img1.jpg
# Detected faces and celebrities for post642_img1.jpg
# Detected faces and celebrities for post640_img1.jpg
# Detected faces and celebrities for post637_img1.jpg
# Detected faces and celebrities for post627_img1.jpg
# Detected faces and celebrities for post623_img1.jpg
# Detected faces and celebrities for post616_img1.jpg
# Detected faces and celebrities for post615_img1.jpg
# Detected faces and celebrities for post610_img1.jpg
# Detected faces and celebrities for post597_img1.jpg
# Detected faces and celebrities for post591_img1.jpg
# Detected faces and celebrities for post586_img1.jpg
# Detected faces and celebrities for post579_img1.jpg
# Detected faces and celebrities for post563_img1.jpg
# Detected faces and celebrities for post562_img1.jpg
# Detected faces and celebrities for post552_img1.jpg
# Detected faces and celebrities for post548_img1.jpg
# Detected faces and celebrities for post544_img1.jpg
# Detected faces and celebrities for post542_img1.jpg
# Detected faces and celebrities for post540_img1.jpg
# Detected faces and celebrities for post537_img2.jpg
# Detected faces and celebrities for post537_img1.jpg
# Detected faces and celebrities for post537_img3.jpg
# Detected faces and celebrities for post537_img4.jpg
# Detected faces and celebrities for post535_img1.jpg
# Detected faces and celebrities for post530_img1.jpg
# Detected faces and celebrities for post528_img1.jpg
# Detected faces and celebrities for post526_img1.jpg
# Detected faces and celebrities for post520_img1.jpg
# Detected faces and celebrities for post516_img1.jpg
# Detected faces and celebrities for post514_img1.jpg
# Detected faces and celebrities for post510_img1.jpg
# Detected faces and celebrities for post504_img1.jpg
# Detected faces and celebrities for post492_img1.jpg
# Detected faces and celebrities for post479_img1.jpg
# Detected faces and celebrities for post472_img1.jpg
# Detected faces and celebrities for post463_img1.jpg
# Detected faces and celebrities for post459_img1.jpg
# Detected faces and celebrities for post455_img1.jpg
# Detected faces and celebrities for post444_img1.jpg
# Detected faces and celebrities for post442_img1.jpg
# Detected faces and celebrities for post435_img1.jpg
# Detected faces and celebrities for post432_img1.jpg
# Detected faces and celebrities for post424_img1.jpg
# Detected faces and celebrities for post422_img1.jpg
# Detected faces and celebrities for post417_img1.jpg
# Detected faces and celebrities for post414_img1.jpg
# Detected faces and celebrities for post1231_img2.jpg
# Detected faces and celebrities for post1231_img3.jpg
# Detected faces and celebrities for post1231_img1.jpg
# Detected faces and celebrities for post1231_img4.jpg
# Detected faces and celebrities for post411_img1.jpg
# Detected faces and celebrities for post402_img1.jpg
# Detected faces and celebrities for post399_img1.jpg
# Detected faces and celebrities for post399_img2.jpg
# Detected faces and celebrities for post397_img1.jpg
# Detected faces and celebrities for post388_img1.jpg
# Detected faces and celebrities for post381_img1.jpg
# Detected faces and celebrities for post381_img2.jpg
# Detected faces and celebrities for post381_img3.jpg
# Detected faces and celebrities for post381_img4.jpg
# Detected faces and celebrities for post379_img1.jpg
# Detected faces and celebrities for post379_img2.jpg
# Detected faces and celebrities for post379_img3.jpg
# Detected faces and celebrities for post379_img4.jpg
# Detected faces and celebrities for post378_img3.jpg
# Detected faces and celebrities for post378_img2.jpg
# Detected faces and celebrities for post378_img5.jpg
# Detected faces and celebrities for post378_img4.jpg
# Detected faces and celebrities for post378_img1.jpg
# Detected faces and celebrities for post378_img6.jpg
# Detected faces and celebrities for post376_img1.jpg
# Detected faces and celebrities for post375_img1.jpg
# Detected faces and celebrities for post375_img2.jpg
# Detected faces and celebrities for post375_img3.jpg
# Detected faces and celebrities for post375_img4.jpg
# Detected faces and celebrities for post360_img1.jpg
# Detected faces and celebrities for post360_img2.jpg
# Detected faces and celebrities for post349_img1.jpg
# Detected faces and celebrities for post345_img1.jpg
# Detected faces and celebrities for post341_img1.jpg
# Detected faces and celebrities for post336_img1.jpg
# Detected faces and celebrities for post334_img1.jpg
# Detected faces and celebrities for post332_img1.jpg
# Detected faces and celebrities for post327_img1.jpg
# Detected faces and celebrities for post321_img1.jpg
# Detected faces and celebrities for post321_img2.jpg
# Detected faces and celebrities for post321_img3.jpg
# Detected faces and celebrities for post321_img4.jpg
# Detected faces and celebrities for post321_img5.jpg
# Detected faces and celebrities for post321_img6.jpg
# Detected faces and celebrities for post321_img7.jpg
# Detected faces and celebrities for post321_img8.jpg
# Detected faces and celebrities for post321_img9.jpg
# Detected faces and celebrities for post319_img1.jpg
# Detected faces and celebrities for post318_img1.jpg
# Detected faces and celebrities for post301_img1.jpg
# Detected faces and celebrities for post1015_img3.jpg
# Detected faces and celebrities for post1015_img1.jpg
# Detected faces and celebrities for post1015_img2.jpg
# Detected faces and celebrities for post273_img1.jpg
# Detected faces and celebrities for post269_img1.jpg
# Detected faces and celebrities for post252_img1.jpg
# Detected faces and celebrities for post249_img1.jpg
# Detected faces and celebrities for post237_img1.jpg
# Detected faces and celebrities for post232_img1.jpg
# Detected faces and celebrities for post225_img2.jpg
# Detected faces and celebrities for post225_img1.jpg
# Detected faces and celebrities for post225_img3.jpg
# Detected faces and celebrities for post224_img1.jpg
# Detected faces and celebrities for post224_img2.jpg
# Detected faces and celebrities for post224_img3.jpg
# Detected faces and celebrities for post221_img1.jpg
# Detected faces and celebrities for post221_img3.jpg
# Detected faces and celebrities for post221_img4.jpg
# Detected faces and celebrities for post221_img2.jpg
# Detected faces and celebrities for post220_img1.jpg
# Detected faces and celebrities for post212_img1.jpg
# Detected faces and celebrities for post209_img1.jpg
# Detected faces and celebrities for post207_img1.jpg
# Detected faces and celebrities for post203_img1.jpg
# Detected faces and celebrities for post202_img1.jpg
# Detected faces and celebrities for post197_img1.jpg
# Detected faces and celebrities for post197_img2.jpg
# Detected faces and celebrities for post190_img2.jpg
# Detected faces and celebrities for post190_img1.jpg
# Detected faces and celebrities for post161_img1.jpg
# Detected faces and celebrities for post159_img1.jpg
# Detected faces and celebrities for post154_img1.jpg
# Detected faces and celebrities for post154_img2.jpg
# Detected faces and celebrities for post154_img3.jpg
# Detected faces and celebrities for post150_img1.jpg
# Detected faces and celebrities for post150_img2.jpg
# Detected faces and celebrities for post141_img1.jpg
# Detected faces and celebrities for post141_img2.jpg
# Detected faces and celebrities for post141_img3.jpg
# Detected faces and celebrities for post141_img4.jpg
# Detected faces and celebrities for post134_img1.jpg
# Detected faces and celebrities for post116_img1.jpg
# Detected faces and celebrities for post103_img1.jpg
# Detected faces and celebrities for post103_img2.jpg
# Detected faces and celebrities for post103_img3.jpg
# Detected faces and celebrities for post103_img4.jpg
# Detected faces and celebrities for post100_img1.jpg
# Detected faces and celebrities for post94_img1.jpg
# Detected faces and celebrities for post76_img1.jpg
# Detected faces and celebrities for post76_img2.jpg
# Detected faces and celebrities for post61_img1.jpg
# Detected faces and celebrities for post45_img1.jpg
# Detected faces and celebrities for post45_img3.jpg
# Detected faces and celebrities for post45_img2.jpg
# Detected faces and celebrities for post45_img6.jpg
# Detected faces and celebrities for post45_img5.jpg
# Detected faces and celebrities for post45_img4.jpg
# Detected faces and celebrities for post34_img1.jpg
# Detected faces and celebrities for post29_img2.jpg
# Detected faces and celebrities for post29_img1.jpg
# Detected faces and celebrities for post28_img1.jpg
# Detected faces and celebrities for post23_img1.jpg
# Detected faces and celebrities for post19_img1.jpg
# Detected faces and celebrities for post16_img1.jpg
# Detected faces and celebrities for post15_img1.jpg
# Detected faces and celebrities for post12_img1.jpg
# Detected faces and celebrities for post7_img1.jpg
# Detected faces and celebrities for post1_img1.jpg

# %%
with open(rekog_results_dir + f'faces_final_{username}.csv', 'w', newline = '') as csvfile:
    fieldnames = [
        'image_id',
        'face_count',
        'has_smile',
        'has_female',
        'has_male',
        'dominant_emotion',
        'emotions',
        'has_happy_emotion',
        'has_confident_emotion',
        'has_celebrity',
        'celebrity_names',
        'has_unrecognized_face'
    ]

    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for entry in face_labels:
        writer.writerow(entry)
