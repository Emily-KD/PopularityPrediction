# %% [markdown]
# <a href="https://colab.research.google.com/github/Emily-KD/PopularityPrediction/blob/main/Data/sephora/Amazon-Rekognition/sephora_colorpalette_updated_colorgroups.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install colorthief
# Out:
# Collecting colorthief
#   Downloading colorthief-0.2.1-py2.py3-none-any.whl.metadata (816 bytes)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from colorthief) (11.1.0)
# Downloading colorthief-0.2.1-py2.py3-none-any.whl (6.1 kB)
# Installing collected packages: colorthief
# Successfully installed colorthief-0.2.1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from colorthief import ColorThief
import webcolors
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
import os

# %%
username = "sephora"
rekog_images_dir = f"/content/drive/Shareddrives/DS340W Project/Dataset NEW*/{username}/{username}_images_2024_2025/"

# %%
local_images = os.listdir(rekog_images_dir) # Get all image names

# %%
# Get list of non-duplicate .jpg files
local_images = [
    f for f in os.listdir(rekog_images_dir)
    if f.endswith('.jpg') and ' (1)' not in f
]

local_images
# Out:
# ['post1425_img1.jpg',
#  'post1422_img1.jpg',
#  'post1420_img1.jpg',
#  'post1415_img1.jpg',
#  'post1411_img1.jpg',
#  'post1409_img1.jpg',
#  'post1409_img2.jpg',
#  'post1409_img3.jpg',
#  'post1409_img4.jpg',
#  'post1407_img1.jpg',
#  'post1403_img1.jpg',
#  'post1401_img1.jpg',
#  'post1400_img1.jpg',
#  'post1400_img2.jpg',
#  'post1396_img1.jpg',
#  'post1396_img2.jpg',
#  'post1396_img3.jpg',
#  'post1396_img4.jpg',
#  'post1390_img1.jpg',
#  'post1385_img1.jpg',
#  'post1384_img1.jpg',
#  'post1382_img1.jpg',
#  'post1380_img1.jpg',
#  'post1380_img2.jpg',
#  'post1373_img1.jpg',
#  'post1364_img1.jpg',
#  'post1356_img1.jpg',
#  'post1349_img1.jpg',
#  'post1346_img1.jpg',
#  'post1339_img1.jpg',
#  'post1337_img1.jpg',
#  'post1336_img1.jpg',
#  'post1334_img1.jpg',
#  'post1333_img3.jpg',
#  'post1333_img4.jpg',
#  'post1331_img1.jpg',
#  'post1329_img1.jpg',
#  'post1326_img1.jpg',
#  'post1333_img1.jpg',
#  'post1333_img2.jpg',
#  'post1317_img1.jpg',
#  'post1316_img1.jpg',
#  'post1314_img1.jpg',
#  'post1314_img3.jpg',
#  'post1314_img2.jpg',
#  'post1312_img1.jpg',
#  'post1305_img1.jpg',
#  'post1294_img1.jpg',
#  'post1293_img1.jpg',
#  'post1290_img1.jpg',
#  'post1284_img1.jpg',
#  'post1281_img1.jpg',
#  'post1278_img1.jpg',
#  'post1277_img1.jpg',
#  'post1275_img1.jpg',
#  'post1272_img1.jpg',
#  'post1268_img1.jpg',
#  'post1266_img1.jpg',
#  'post1261_img1.jpg',
#  'post1259_img1.jpg',
#  'post1256_img1.jpg',
#  'post1250_img1.jpg',
#  'post1241_img1.jpg',
#  'post1240_img1.jpg',
#  'post1237_img1.jpg',
#  'post1229_img1.jpg',
#  'post1207_img1.jpg',
#  'post1201_img1.jpg',
#  'post1196_img1.jpg',
#  'post1192_img1.jpg',
#  'post1187_img1.jpg',
#  'post1183_img1.jpg',
#  'post1180_img1.jpg',
#  'post1177_img1.jpg',
#  'post1177_img2.jpg',
#  'post1177_img3.jpg',
#  'post1177_img4.jpg',
#  'post1174_img1.jpg',
#  'post1170_img1.jpg',
#  'post1170_img2.jpg',
#  'post1169_img1.jpg',
#  'post1164_img1.jpg',
#  'post1154_img1.jpg',
#  'post1149_img1.jpg',
#  'post1140_img1.jpg',
#  'post1138_img1.jpg',
#  'post1137_img1.jpg',
#  'post1134_img1.jpg',
#  'post1131_img1.jpg',
#  'post1130_img1.jpg',
#  'post1125_img1.jpg',
#  'post1122_img1.jpg',
#  'post1121_img1.jpg',
#  'post1107_img1.jpg',
#  'post1107_img2.jpg',
#  'post1107_img3.jpg',
#  'post1107_img4.jpg',
#  'post1102_img1.jpg',
#  'post1101_img1.jpg',
#  'post1085_img1.jpg',
#  'post1082_img1.jpg',
#  'post1082_img2.jpg',
#  'post1081_img1.jpg',
#  'post1081_img2.jpg',
#  'post1081_img3.jpg',
#  'post1081_img4.jpg',
#  'post1078_img1.jpg',
#  'post1076_img1.jpg',
#  'post1060_img1.jpg',
#  'post1058_img1.jpg',
#  'post1051_img1.jpg',
#  'post1051_img2.jpg',
#  'post1044_img1.jpg',
#  'post1044_img3.jpg',
#  'post1044_img2.jpg',
#  'post1044_img4.jpg',
#  'post1035_img1.jpg',
#  'post1034_img1.jpg',
#  'post1031_img1.jpg',
#  'post1027_img1.jpg',
#  'post1025_img1.jpg',
#  'post1025_img2.jpg',
#  'post1021_img1.jpg',
#  'post1021_img2.jpg',
#  'post1018_img1.jpg',
#  'post1011_img1.jpg',
#  'post1006_img1.jpg',
#  'post1000_img1.jpg',
#  'post998_img1.jpg',
#  'post995_img1.jpg',
#  'post983_img1.jpg',
#  'post975_img1.jpg',
#  'post975_img2.jpg',
#  'post975_img3.jpg',
#  'post972_img1.jpg',
#  'post968_img1.jpg',
#  'post955_img1.jpg',
#  'post952_img1.jpg',
#  'post938_img1.jpg',
#  'post934_img1.jpg',
#  'post924_img1.jpg',
#  'post923_img1.jpg',
#  'post923_img2.jpg',
#  'post919_img1.jpg',
#  'post908_img1.jpg',
#  'post902_img1.jpg',
#  'post902_img2.jpg',
#  'post902_img3.jpg',
#  'post902_img4.jpg',
#  'post899_img1.jpg',
#  'post895_img1.jpg',
#  'post895_img2.jpg',
#  'post865_img1.jpg',
#  'post865_img2.jpg',
#  'post864_img1.jpg',
#  'post855_img1.jpg',
#  'post850_img1.jpg',
#  'post840_img1.jpg',
#  'post839_img1.jpg',
#  'post837_img1.jpg',
#  'post831_img1.jpg',
#  'post823_img1.jpg',
#  'post816_img1.jpg',
#  'post807_img1.jpg',
#  'post804_img1.jpg',
#  'post788_img1.jpg',
#  'post782_img1.jpg',
#  'post777_img1.jpg',
#  'post776_img1.jpg',
#  'post770_img1.jpg',
#  'post767_img1.jpg',
#  'post767_img2.jpg',
#  'post767_img3.jpg',
#  'post764_img1.jpg',
#  'post758_img1.jpg',
#  'post754_img1.jpg',
#  'post750_img1.jpg',
#  'post747_img1.jpg',
#  'post744_img1.jpg',
#  'post743_img1.jpg',
#  'post741_img1.jpg',
#  'post741_img2.jpg',
#  'post735_img1.jpg',
#  'post735_img2.jpg',
#  'post719_img1.jpg',
#  'post711_img1.jpg',
#  'post709_img1.jpg',
#  'post701_img1.jpg',
#  'post694_img1.jpg',
#  'post692_img1.jpg',
#  'post687_img1.jpg',
#  'post675_img1.jpg',
#  'post662_img1.jpg',
#  'post655_img1.jpg',
#  'post651_img1.jpg',
#  'post645_img1.jpg',
#  'post642_img1.jpg',
#  'post640_img1.jpg',
#  'post637_img1.jpg',
#  'post627_img1.jpg',
#  'post623_img1.jpg',
#  'post616_img1.jpg',
#  'post615_img1.jpg',
#  'post610_img1.jpg',
#  'post597_img1.jpg',
#  'post591_img1.jpg',
#  'post586_img1.jpg',
#  'post579_img1.jpg',
#  'post563_img1.jpg',
#  'post562_img1.jpg',
#  'post552_img1.jpg',
#  'post548_img1.jpg',
#  'post544_img1.jpg',
#  'post542_img1.jpg',
#  'post540_img1.jpg',
#  'post537_img2.jpg',
#  'post537_img1.jpg',
#  'post537_img3.jpg',
#  'post537_img4.jpg',
#  'post535_img1.jpg',
#  'post530_img1.jpg',
#  'post528_img1.jpg',
#  'post526_img1.jpg',
#  'post520_img1.jpg',
#  'post516_img1.jpg',
#  'post514_img1.jpg',
#  'post510_img1.jpg',
#  'post504_img1.jpg',
#  'post492_img1.jpg',
#  'post479_img1.jpg',
#  'post472_img1.jpg',
#  'post463_img1.jpg',
#  'post459_img1.jpg',
#  'post455_img1.jpg',
#  'post444_img1.jpg',
#  'post442_img1.jpg',
#  'post435_img1.jpg',
#  'post432_img1.jpg',
#  'post424_img1.jpg',
#  'post422_img1.jpg',
#  'post417_img1.jpg',
#  'post414_img1.jpg',
#  'post1231_img2.jpg',
#  'post1231_img3.jpg',
#  'post1231_img1.jpg',
#  'post1231_img4.jpg',
#  'post411_img1.jpg',
#  'post402_img1.jpg',
#  'post399_img1.jpg',
#  'post399_img2.jpg',
#  'post397_img1.jpg',
#  'post388_img1.jpg',
#  'post381_img1.jpg',
#  'post381_img2.jpg',
#  'post381_img3.jpg',
#  'post381_img4.jpg',
#  'post379_img1.jpg',
#  'post379_img2.jpg',
#  'post379_img3.jpg',
#  'post379_img4.jpg',
#  'post378_img3.jpg',
#  'post378_img2.jpg',
#  'post378_img5.jpg',
#  'post378_img4.jpg',
#  'post378_img1.jpg',
#  'post378_img6.jpg',
#  'post376_img1.jpg',
#  'post375_img1.jpg',
#  'post375_img2.jpg',
#  'post375_img3.jpg',
#  'post375_img4.jpg',
#  'post360_img1.jpg',
#  'post360_img2.jpg',
#  'post349_img1.jpg',
#  'post345_img1.jpg',
#  'post341_img1.jpg',
#  'post336_img1.jpg',
#  'post334_img1.jpg',
#  'post332_img1.jpg',
#  'post327_img1.jpg',
#  'post321_img1.jpg',
#  'post321_img2.jpg',
#  'post321_img3.jpg',
#  'post321_img4.jpg',
#  'post321_img5.jpg',
#  'post321_img6.jpg',
#  'post321_img7.jpg',
#  'post321_img8.jpg',
#  'post321_img9.jpg',
#  'post319_img1.jpg',
#  'post318_img1.jpg',
#  'post301_img1.jpg',
#  'post1015_img3.jpg',
#  'post1015_img1.jpg',
#  'post1015_img2.jpg',
#  'post273_img1.jpg',
#  'post269_img1.jpg',
#  'post252_img1.jpg',
#  'post249_img1.jpg',
#  'post237_img1.jpg',
#  'post232_img1.jpg',
#  'post225_img2.jpg',
#  'post225_img1.jpg',
#  'post225_img3.jpg',
#  'post224_img1.jpg',
#  'post224_img2.jpg',
#  'post224_img3.jpg',
#  'post221_img1.jpg',
#  'post221_img3.jpg',
#  'post221_img4.jpg',
#  'post221_img2.jpg',
#  'post220_img1.jpg',
#  'post212_img1.jpg',
#  'post209_img1.jpg',
#  'post207_img1.jpg',
#  'post203_img1.jpg',
#  'post202_img1.jpg',
#  'post197_img1.jpg',
#  'post197_img2.jpg',
#  'post190_img2.jpg',
#  'post190_img1.jpg',
#  'post161_img1.jpg',
#  'post159_img1.jpg',
#  'post154_img1.jpg',
#  'post154_img2.jpg',
#  'post154_img3.jpg',
#  'post150_img1.jpg',
#  'post150_img2.jpg',
#  'post141_img1.jpg',
#  'post141_img2.jpg',
#  'post141_img3.jpg',
#  'post141_img4.jpg',
#  'post134_img1.jpg',
#  'post116_img1.jpg',
#  'post103_img1.jpg',
#  'post103_img2.jpg',
#  'post103_img3.jpg',
#  'post103_img4.jpg',
#  'post100_img1.jpg',
#  'post94_img1.jpg',
#  'post76_img1.jpg',
#  'post76_img2.jpg',
#  'post61_img1.jpg',
#  'post45_img1.jpg',
#  'post45_img3.jpg',
#  'post45_img2.jpg',
#  'post45_img6.jpg',
#  'post45_img5.jpg',
#  'post45_img4.jpg',
#  'post34_img1.jpg',
#  'post29_img2.jpg',
#  'post29_img1.jpg',
#  'post28_img1.jpg',
#  'post23_img1.jpg',
#  'post19_img1.jpg',
#  'post16_img1.jpg',
#  'post15_img1.jpg',
#  'post12_img1.jpg',
#  'post7_img1.jpg',
#  'post1_img1.jpg']

# %%
def is_css3_color(instance):
        if instance.lower() in webcolors.css3_names_to_hex:
            return True
        return is_css_color_code(instance)

# %%
def check_color(color_name):
    #Define colors
    PINK = ['pink', 'lightpink', 'hotpink', 'deeppink', 'palevioletred', 'mediumvioletred']
    PURPLE = ['lavender', 'thistle', 'plum', 'orchid', 'violet', 'fuchsia', 'magenta', 'mediumorchid', 'darkorchid', 'darkviolet', 'blueviolet', 'darkmagenta',  'purple',  'mediumpurple',  'mediumslateblue', 'slateblue', 'darkslateblue', 'rebeccapurple',  'indigo']
    RED = ['lightsalmon', 'salmon', 'darksalmon', 'lightcoral', 'indianred', 'crimson', 'red', 'firebrick', 'darkred']
    ORANGE = ['orange', 'darkorange', 'coral', 'tomato', 'orangered']
    YELLOW = ['gold', 'yellow', 'lightyellow', 'lemonchiffon', 'lightgoldenrodyellow', 'papayawhip', 'moccasin', 'peachpuff',  'palegoldenrod', 'khaki', 'darkkhaki']
    GREEN = ['greenyellow', 'chartreuse',  'lawngreen', 'lime',  'limegreen', 'palegreen', 'lightgreen', 'mediumspringgreen', 'springgreen', 'mediumseagreen', 'seagreen', 'forestgreen', 'green', 'darkgreen', 'yellowgreen', 'olivedrab', 'darkolivegreen', 'mediumaquamarine', 'darkseagreen', 'lightseagreen',  'darkcyan',  'teal']
    CYAN= ['aqua', 'cyan', "darkslategray",'lightcyan', 'paleturquoise', 'aquamarine', 'turquoise', 'mediumturquoise', 'darkturquoise']
    BLUE=  ['cadetblue', 'steelblue', 'lightsteelblue', 'lightblue', 'powderblue', 'lightskyblue',  'skyblue', 'cornflowerblue', 'deepskyblue', 'dodgerblue', 'royalblue', 'blue', 'mediumblue',  'darkblue',  'navy',  'MidnightBlue']
    BROWN =  ['cornsilk', 'blanchedalmond', 'bisque', 'navajowhite', 'wheat', 'burlywood', 'tan', 'rosybrown', 'sandybrown', 'goldenrod', 'darkgoldenrod',  'peru', 'chocolate', 'olive', 'saddlebrown',  'sienna',  'brown', 'maroon']
    WHITE = ['white', 'snow', 'honeydew', 'mintcream', 'azure', 'aliceblue',  'ghostwhite', 'whitesmoke', 'seashell',  'beige', 'oldlace',  'floralwhite',  'ivory', 'antiquewhite',  'linen', 'lavenderblush',  'mistyrose']
    GREY = [ 'gainsboro', 'lightgray', 'silver', 'darkgray', 'dimgray',  'gray',  'lightslategray', 'slategray', 'arkslategray', 'black']

    #Check cases
    if color_name in PINK:
        return 'pink'
    elif color_name in PURPLE:
        return 'purple'
    elif color_name in RED:
        return 'red'
    elif color_name in ORANGE:
        return 'orange'
    elif color_name in YELLOW:
        return 'yellow'
    elif color_name in GREEN:
        return 'green'
    elif color_name in CYAN:
        return 'cyan'
    elif color_name in BLUE:
        return 'blue'
    elif color_name in BROWN:
        return 'brown'
    elif color_name in WHITE:
        return 'white'
    elif color_name in GREY:
        return 'grey'
    else:
        return 'No color found'

# %%
# !pip install webcolors
# Out:
# Requirement already satisfied: webcolors in /usr/local/lib/python3.11/dist-packages (24.11.1)

# %%
# !pip show webcolors
# Out:
# Name: webcolors
# Version: 24.11.1
# Summary: A library for working with the color formats defined by HTML and CSS.
# Home-page:
# Author: James Bennett
# Author-email:
# License: BSD-3-Clause
# Location: /usr/local/lib/python3.11/dist-packages
# Requires:
# Required-by: music21

# %%
import webcolors
print(dir(webcolors))
# Out:
# ['CSS2', 'CSS21', 'CSS3', 'HTML4', 'HTML5SimpleColor', 'IntTuple', 'IntegerRGB', 'PercentRGB', 'PercentTuple', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '_conversion', '_definitions', '_html5', '_normalization', '_types', 'hex_to_name', 'hex_to_rgb', 'hex_to_rgb_percent', 'html5_parse_legacy_color', 'html5_parse_simple_color', 'html5_serialize_simple_color', 'name_to_hex', 'name_to_rgb', 'name_to_rgb_percent', 'names', 'normalize_hex', 'normalize_integer_triplet', 'normalize_percent_triplet', 'rgb_percent_to_hex', 'rgb_percent_to_name', 'rgb_percent_to_rgb', 'rgb_to_hex', 'rgb_to_name', 'rgb_to_rgb_percent']

# %%
print(webcolors.name_to_hex("red"))
# Out:
# #ff0000

# %%
image_names = []
color_names = []
total_images = len(local_images)
for idx, imageFile in enumerate(local_images, start=1):
    print(f"Processing image {idx}/{total_images}: {imageFile}")

    color_thief = ColorThief(os.path.join(rekog_images_dir, imageFile))
    dominant_color = color_thief.get_color(quality=1)
    rms_lst = []

    for color_name in webcolors.names():
        try:
            hex_val = webcolors.name_to_hex(color_name)
            cur_clr = webcolors.hex_to_rgb(hex_val)
            rmse = np.sqrt(mean_squared_error(dominant_color, cur_clr))
            rms_lst.append((color_name, rmse))
        except ValueError:
            continue

    # Get closest color by RMSE
    closest_color = min(rms_lst, key=lambda x: x[1])[0]
    grouped_color = check_color(closest_color)  # your categorization (e.g., pink, red, etc.)

    image_names.append(imageFile)
    color_names.append(grouped_color.lower())  # match lowercase pattern

# Create DataFrame with correct columns
output_colors = pd.DataFrame({
    'image_id': image_names,
    'dominantColor': color_names
})
# Out:
# Processing image 1/360: post1425_img1.jpg
# Processing image 2/360: post1422_img1.jpg
# Processing image 3/360: post1420_img1.jpg
# Processing image 4/360: post1415_img1.jpg
# Processing image 5/360: post1411_img1.jpg
# Processing image 6/360: post1409_img1.jpg
# Processing image 7/360: post1409_img2.jpg
# Processing image 8/360: post1409_img3.jpg
# Processing image 9/360: post1409_img4.jpg
# Processing image 10/360: post1407_img1.jpg
# Processing image 11/360: post1403_img1.jpg
# Processing image 12/360: post1401_img1.jpg
# Processing image 13/360: post1400_img1.jpg
# Processing image 14/360: post1400_img2.jpg
# Processing image 15/360: post1396_img1.jpg
# Processing image 16/360: post1396_img2.jpg
# Processing image 17/360: post1396_img3.jpg
# Processing image 18/360: post1396_img4.jpg
# Processing image 19/360: post1390_img1.jpg
# Processing image 20/360: post1385_img1.jpg
# Processing image 21/360: post1384_img1.jpg
# Processing image 22/360: post1382_img1.jpg
# Processing image 23/360: post1380_img1.jpg
# Processing image 24/360: post1380_img2.jpg
# Processing image 25/360: post1373_img1.jpg
# Processing image 26/360: post1364_img1.jpg
# Processing image 27/360: post1356_img1.jpg
# Processing image 28/360: post1349_img1.jpg
# Processing image 29/360: post1346_img1.jpg
# Processing image 30/360: post1339_img1.jpg
# Processing image 31/360: post1337_img1.jpg
# Processing image 32/360: post1336_img1.jpg
# Processing image 33/360: post1334_img1.jpg
# Processing image 34/360: post1333_img3.jpg
# Processing image 35/360: post1333_img4.jpg
# Processing image 36/360: post1331_img1.jpg
# Processing image 37/360: post1329_img1.jpg
# Processing image 38/360: post1326_img1.jpg
# Processing image 39/360: post1333_img1.jpg
# Processing image 40/360: post1333_img2.jpg
# Processing image 41/360: post1317_img1.jpg
# Processing image 42/360: post1316_img1.jpg
# Processing image 43/360: post1314_img1.jpg
# Processing image 44/360: post1314_img3.jpg
# Processing image 45/360: post1314_img2.jpg
# Processing image 46/360: post1312_img1.jpg
# Processing image 47/360: post1305_img1.jpg
# Processing image 48/360: post1294_img1.jpg
# Processing image 49/360: post1293_img1.jpg
# Processing image 50/360: post1290_img1.jpg
# Processing image 51/360: post1284_img1.jpg
# Processing image 52/360: post1281_img1.jpg
# Processing image 53/360: post1278_img1.jpg
# Processing image 54/360: post1277_img1.jpg
# Processing image 55/360: post1275_img1.jpg
