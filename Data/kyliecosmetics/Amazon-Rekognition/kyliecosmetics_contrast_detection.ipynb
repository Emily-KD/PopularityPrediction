# %% [markdown]
# <a href="https://colab.research.google.com/github/Emily-KD/PopularityPrediction/blob/main/Data/kyliecosmetics/Amazon-Rekognition/kyliecosmetics_contrast_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from skimage.exposure import is_low_contrast
from skimage import io
import os
import cv2
import numpy as np
import pandas as pd

# %%
print(os.path.exists("drive/Shareddrives/DS340W Project/"))
# Out:
# True

# %%
# Path to where your want to save the resulting labels
rekog_results_dir = "/content/drive/Shareddrives/DS340W Project/Dataset NEW*/kyliecosmetics/"

# Path to where your images are
rekog_images_dir = "/content/drive/Shareddrives/DS340W Project/Dataset NEW*/kyliecosmetics/kyliecosmetics_images_2024_2025/"

# %%
# Make a list of all the images in the rekog_data_dir you created
local_images = os.listdir(rekog_images_dir)

# %%
contrast_values = []
image_names = []

# %%
for imageFile in local_images:
    #image = cv2.imread(rekog_images_dir + imageFile) # Read the image
    image = io.imread(rekog_images_dir + imageFile)
    image = np.array(image)
    #contrast = is_low_contrast(image) # Contrast or not
    contrast = is_low_contrast(image, fraction_threshold=0.20, lower_percentile=20, upper_percentile=100) # Contrast or not
    if contrast: #If the contrast is true (which means LOW contrast)
        contrast_values.append('LOW')
    else:
        contrast_values.append('HIGH')

    image_names.append(imageFile)

# %%
df = pd.DataFrame()

# %%
df['image_id'] = image_names
df['Contrast'] = contrast_values

# %%
df
# Out:
#               image_id Contrast
# 0     post477_img3.jpg     HIGH
# 1     post477_img4.jpg     HIGH
# 2     post477_img2.jpg     HIGH
# 3     post476_img1.jpg      LOW
# 4     post473_img1.jpg     HIGH
# ...                ...      ...
# 2118  post349_img7.jpg     HIGH
# 2119  post349_img6.jpg      LOW
# 2120  post349_img9.jpg      LOW
# 2121  post349_img8.jpg     HIGH
# 2122  post348_img1.jpg     HIGH
#
# [2123 rows x 2 columns]

# %%
df = df.to_csv('/content/drive/Shareddrives/DS340W Project/Dataset NEW*/kyliecosmetics/kyliecosmetics_contrasts_insta.csv', index=False)
