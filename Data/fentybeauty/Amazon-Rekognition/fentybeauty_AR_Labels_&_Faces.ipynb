# %% [markdown]
# <a href="https://colab.research.google.com/github/Emily-KD/PopularityPrediction/blob/main/Data/fentybeauty/Amazon-Rekognition/fentybeauty_AR_Labels_%26_Faces.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.37.37-py3-none-any.whl.metadata (6.7 kB)
# Collecting botocore<1.38.0,>=1.37.37 (from boto3)
#   Downloading botocore-1.37.37-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.12.0,>=0.11.0 (from boto3)
#   Downloading s3transfer-0.11.5-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore<1.38.0,>=1.37.37->boto3) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<1.38.0,>=1.37.37->boto3) (2.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.38.0,>=1.37.37->boto3) (1.17.0)
# Downloading boto3-1.37.37-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 1.4 MB/s eta 0:00:00
# Downloading botocore-1.37.37-py3-none-any.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 38.0 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.11.5-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 5.2 MB/s eta 0:00:00
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.37.37 botocore-1.37.37 jmespath-1.0.1 s3transfer-0.11.5

# %%
import csv
import boto3
import pickle
import os
import json
import pandas as pd

# %%
ls
# Out:
# drive/  sample_data/

# %%
########### Paths
username = "fentybeauty"
# Path to where your want to save the resulting labels
rekog_results_dir = f"/content/drive/Shareddrives/DS340W Project/Dataset NEW*/{username}/"

# Path to where your images are
rekog_images_dir = f"/content/drive/Shareddrives/DS340W Project/Dataset NEW*/{username}/{username}_images_2024_2025/"

# %%
# Read in your personal keys
personal_access_key = "AKIA6JKEXWET5465SAMQ"
secret_access_key = "Q3HEcBy+jO7ep4tL9It/7MEoFhlBxy9R2QpRjbWv"

# Initialize the boto client to access the Rekogniton api
client=boto3.client('rekognition','us-east-1', # or choose the best region for your work,
                                               # e.g. the location of your S3 bucket if using that method to store images
                    aws_access_key_id = personal_access_key,
                    aws_secret_access_key = secret_access_key)

# %%
# Make a list of all the images in the rekog_data_dir you created
local_images = os.listdir(rekog_images_dir)
#local_images = [str(p) for p in rekog_images_dir]

# %%
from PIL import Image
import io

def resize_if_needed(image_path, max_size=5242880):
    with open(image_path, 'rb') as f:
        img_bytes = f.read()

    if len(img_bytes) < max_size:
        return img_bytes

    # Resize the image using PIL
    with Image.open(image_path) as img:
        # Reduce resolution while maintaining aspect ratio
        img.thumbnail((1024, 1024))  # tweak if needed
        buf = io.BytesIO()
        img.save(buf, format='JPEG')
        buf.seek(0)
        return buf.read()

# %%
#### Beauty-focused label extraction
holder_labels = []

for imageFile in local_images:
    image_path = rekog_images_dir + imageFile
    try:
        image_bytes = resize_if_needed(image_path)
        response = client.detect_labels(Image={'Bytes': image_bytes})
    except Exception as e:
        print(f"❌ Skipping {imageFile}: {e}")
        continue

    print('Detected labels for ' + imageFile)

    labels = []
    temp_dict = {
        "image_id": imageFile,
        "has_makeup": False,
        "has_beauty_product": False,
        "has_logo_or_branding": False,
        "is_fashion_related": False,
        "is_beauty_scene": False,
        "has_text": False,
        "close_up": False,
        "indoors": False,
        "outdoors": False
    }

    for label in response.get('Labels', []):
        if label.get('Confidence', 0) >= 70:
            labels.append(label.get('Name'))

    # Category dictionaries
    makeup_labels = ['Makeup', 'Cosmetics', 'Lipstick', 'Eyeliner', 'Blush', 'Eyeshadow']
    product_labels = ['Cosmetics', 'Bottle', 'Container', 'Toiletry', 'Skincare', 'Cream']
    brand_labels = ['Label', 'Logo', 'Trademark', 'Packaging']
    fashion_labels = ['Clothing', 'Apparel', 'Dress', 'Fashion', 'Footwear', 'Shoes', 'Bag']
    scene_labels = ['Beauty Salon', 'Mirror', 'Vanity', 'Makeup Room']
    text_labels = ['Text', 'Advertisement', 'Poster', 'Font', 'Brochure', 'Paper']

    # Binary feature assignments
    if any(lbl in labels for lbl in makeup_labels):
        temp_dict["has_makeup"] = True
    if any(lbl in labels for lbl in product_labels):
        temp_dict["has_beauty_product"] = True
    if any(lbl in labels for lbl in brand_labels):
        temp_dict["has_logo_or_branding"] = True
    if any(lbl in labels for lbl in fashion_labels):
        temp_dict["is_fashion_related"] = True
    if any(lbl in labels for lbl in scene_labels):
        temp_dict["is_beauty_scene"] = True
    if any(lbl in labels for lbl in text_labels):
        temp_dict["has_text"] = True
    if 'Portrait' in labels:
        temp_dict["close_up"] = True
    if 'Indoors' in labels:
        temp_dict["indoors"] = True
    if 'Outdoors' in labels:
        temp_dict["outdoors"] = True

    holder_labels.append(temp_dict)
    print(labels)  # Optional log
# Out:
# Detected labels for post1001_img2.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Lotion']
# Detected labels for post1001_img3.jpg
# ['Bottle', 'Cosmetics', 'Lipstick', 'Lotion', 'Perfume', 'Cabinet', 'Furniture']
# Detected labels for post1001_img4.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Lipstick']
# Detected labels for post992_img1.jpg
# ['Cosmetics', 'Lipstick', 'Toy']
# Detected labels for post990_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Food', 'Food Presentation', 'Cup']
# Detected labels for post983_img2.jpg
# ['Head', 'Person', 'Face', 'Tape', 'Body Part', 'Finger', 'Hand', 'Cosmetics', 'Bottle']
# Detected labels for post983_img1.jpg
# ['Head', 'Person', 'Face', 'Adult', 'Male', 'Man', 'Photography', 'Portrait', 'Skin']
# Detected labels for post983_img3.jpg
# ['Person', 'Washing', 'Head', 'Face', 'Adult', 'Female', 'Woman', 'Photography', 'Portrait', 'Skin']
# Detected labels for post977_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Lipstick']
# Detected labels for post956_img1.jpg
# ['Cosmetics', 'Lipstick', 'Adult', 'Female', 'Person', 'Woman', 'Body Part', 'Finger', 'Hand', 'Face', 'Head', 'Photography', 'Portrait', 'Publication']
# Detected labels for post953_img1.jpg
# ['Publication', 'Adult', 'Female', 'Person', 'Woman', 'Fashion', 'Magazine', 'Face', 'Head', 'Photography', 'Portrait', 'Ping Pong', 'Ping Pong Paddle', 'Racket', 'Sport', 'Clothing', 'Dress']
# Detected labels for post952_img2.jpg
# ['Photography', 'Blade', 'Dagger', 'Knife', 'Weapon']
# Detected labels for post952_img3.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Clothing', 'Dress', 'Photography', 'Hair', 'Formal Wear', 'Fashion']
# Detected labels for post952_img1.jpg
# ['Braid', 'Hair', 'Person']
# Detected labels for post952_img4.jpg
# ['Braid', 'Hair', 'Person', 'Adult', 'Female', 'Woman']
# Detected labels for post952_img6.jpg
# ['Clothing', 'Dress', 'Photography', 'Formal Wear', 'Fashion', 'Gown', 'Face', 'Head', 'Person', 'Portrait', 'Adult', 'Male', 'Man', 'Wedding', 'Wedding Gown', 'Dancing', 'Leisure Activities', 'Bridegroom']
# Detected labels for post952_img5.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Accessories', 'Handcuffs', 'Face', 'Head', 'Skin', 'Tattoo', 'Jewelry', 'Henna', 'Adult', 'Bride', 'Female', 'Wedding', 'Woman']
# Detected labels for post950_img1.jpg
# ['Head', 'Person', 'Face', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Skin', 'Accessories', 'Jewelry', 'Necklace']
# Detected labels for post950_img3.jpg
# ['Clothing', 'Coat', 'Blouse', 'Head', 'Person', 'Face']
# Detected labels for post950_img2.jpg
# ['Book', 'Publication', 'Novel', 'Person']
# Detected labels for post948_img1.jpg
# ['Body Part', 'Face', 'Head', 'Neck', 'Person', 'Adult', 'Female', 'Woman', 'Accessories', 'Jewelry', 'Necklace', 'Skin', 'Photography', 'Portrait']
# Detected labels for post946_img1.jpg
# ['Accessories', 'Earring', 'Jewelry', 'Body Part', 'Face', 'Head', 'Neck', 'Person', 'Adult', 'Female', 'Woman', 'Photography', 'Portrait']
# Detected labels for post946_img2.jpg
# ['Body Part', 'Face', 'Head', 'Neck', 'Person', 'Adult', 'Female', 'Woman', 'Skin', 'Accessories', 'Earring', 'Jewelry']
# Detected labels for post946_img3.jpg
# ['Head', 'Person', 'Skin', 'Face', 'Adult', 'Female', 'Woman', 'Cosmetics', 'Lipstick']
# Detected labels for post946_img4.jpg
# ['Body Part', 'Face', 'Head', 'Neck', 'Person', 'Adult', 'Female', 'Woman', 'Skin', 'Hair']
# Detected labels for post946_img5.jpg
# ['Body Part', 'Face', 'Head', 'Neck', 'Person', 'Skin']
# Detected labels for post946_img6.jpg
# ['Face', 'Head', 'Person', 'Cosmetics']
# Detected labels for post934_img3.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Text', 'Cosmetics', 'Number', 'Symbol', 'Bottle', 'Perfume']
# Detected labels for post934_img4.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Cosmetics', 'Face', 'Head', 'Lipstick', 'Bride', 'Wedding', 'Computer Hardware', 'Electronics', 'Hardware', 'Monitor', 'Screen', 'Festival', 'Hanukkah Menorah']
# Detected labels for post934_img2.jpg
# ['Cosmetics', 'Lipstick', 'Adult', 'Female', 'Person', 'Woman', 'Computer Hardware', 'Electronics', 'Hardware', 'Monitor', 'Screen', 'Face', 'Head']
# Detected labels for post934_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Cosmetics', 'Lipstick', 'Face', 'Head', 'Tape']
# Detected labels for post931_img1.jpg
# ['Person', 'Skin', 'Head', 'Face', 'Baby', 'Freckle']
# Detected labels for post931_img2.jpg
# ['Head', 'Person', 'Face', 'Skin', 'Freckle']
# Detected labels for post931_img3.jpg
# ['Child', 'Female', 'Girl', 'Person', 'Hair', 'Clothing', 'Sleeve', 'Face', 'Head']
# Detected labels for post931_img4.jpg
# ['Person', 'Skin', 'Face', 'Head']
# Detected labels for post931_img5.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Fashion', 'Adult', 'Female', 'Woman', 'Happy', 'Smile']
# Detected labels for post931_img6.jpg
# ['Cosmetics', 'Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Skin']
# Detected labels for post931_img7.jpg
# ['Head', 'Person', 'Face', 'Adult', 'Female', 'Woman', 'Skin', 'Body Part', 'Neck']
# Detected labels for post931_img8.jpg
# ['Head', 'Person', 'Face', 'Skin', 'Freckle']
# Detected labels for post931_img9.jpg
# ['Head', 'Person', 'Adult', 'Female', 'Woman', 'Face', 'Cosmetics', 'Lipstick', 'Skin', 'Photography', 'Portrait']
# Detected labels for post931_img10.jpg
# ['Hair', 'Person', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Red Hair', 'Cosmetics', 'Lipstick']
# Detected labels for post927_img1.jpg
# ['Head', 'Person', 'Face', 'Cosmetics', 'Makeup', 'Face Makeup']
# Detected labels for post927_img2.jpg
# ['Face', 'Head', 'Person', 'Cosmetics']
# Detected labels for post927_img3.jpg
# ['Brush', 'Device', 'Tool', 'Cosmetics']
# Detected labels for post912_img1.jpg
# ['Cosmetics', 'Lipstick', 'Head', 'Person', 'Face', 'Tape']
# Detected labels for post911_img1.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Publication', 'Adult', 'Female', 'Woman', 'Fashion', 'Magazine']
# Detected labels for post911_img2.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Fashion', 'Face', 'Head', 'Photography', 'Portrait', 'Art', 'Painting', 'Clothing', 'Coat']
# Detected labels for post910_img1.jpg
# ['Flower', 'Plant', 'Rose', 'Cosmetics', 'Lipstick', 'Accessories', 'Wallet', 'Body Part', 'Hand', 'Person', 'Bottle', 'Perfume', 'Finger']
# Detected labels for post910_img2.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Photographic Film']
# Detected labels for post910_img3.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post910_img4.jpg
# ['Bottle', 'Shaker']
# Detected labels for post910_img5.jpg
# ['Cosmetics', 'Lipstick', 'Text', 'Sink', 'Bottle', 'Perfume']
# Detected labels for post910_img6.jpg
# ['Beverage', 'Soda', 'Bottle', 'Cosmetics', 'Perfume', 'Flower', 'Plant', 'Rose', 'Lipstick']
# Detected labels for post901_img2.jpg
# ['Cosmetics', 'Lipstick', 'Electrical Device', 'Switch', 'Face', 'Head', 'Person', 'Makeup']
# Detected labels for post901_img1.jpg
# ['Cosmetics', 'Electrical Device', 'Switch', 'Lipstick', 'Cup', 'Disposable Cup']
# Detected labels for post901_img3.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Gun', 'Weapon', 'Cutlery', 'Spoon']
# Detected labels for post891_img1.jpg
# ['Blonde', 'Hair', 'Person', 'Adult', 'Female', 'Woman', 'Head']
# Detected labels for post891_img2.jpg
# ['Clothing', 'Coat', 'Blonde', 'Hair', 'Person', 'Jacket', 'Adult', 'Female', 'Woman', 'Overcoat', 'Lady', 'Formal Wear', 'Blazer', 'Fashion']
# Detected labels for post889_img1.jpg
# ['Bottle', 'Jar', 'Cosmetics', 'Perfume']
# Detected labels for post888_img1.jpg
# ['Flower', 'Geranium', 'Plant', 'Petal', 'Anther', 'Rose', 'Pollen']
# Detected labels for post888_img2.jpg
# ['Flower', 'Petal', 'Plant', 'Rose', 'Flower Arrangement', 'Flower Bouquet']
# Detected labels for post888_img4.jpg
# ['Flower', 'Petal', 'Plant', 'Geranium', 'Anther', 'Leaf']
# Detected labels for post888_img7.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post888_img3.jpg
# ['Green', 'Leaf', 'Plant', 'Grass', 'Silhouette', 'Amaranthaceae', 'Tree', 'Flower', 'Potted Plant']
# Detected labels for post888_img6.jpg
# ['Citrus Fruit', 'Food', 'Fruit', 'Plant', 'Produce', 'Orange', 'Grapefruit']
# Detected labels for post888_img5.jpg
# ['Flower', 'Petal', 'Plant', 'Orchid', 'Geranium', 'Anther']
# Detected labels for post887_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post886_img1.jpg
# ['Nature', 'Outdoors', 'Sky', 'Sun', 'Sunlight', 'Flare', 'Light', 'Sunrise', 'Smoke Pipe']
# Detected labels for post880_img1.jpg
# ['Head', 'Person', 'Face', 'Photography', 'Portrait', 'Body Part', 'Neck', 'Adult', 'Female', 'Woman', 'Shoulder', 'Accessories', 'Jewelry', 'Necklace', 'Finger', 'Hand', 'Skin']
# Detected labels for post879_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Head', 'Face', 'Body Part', 'Neck']
# Detected labels for post879_img2.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Skin', 'Cosmetics', 'Makeup']
# Detected labels for post879_img3.jpg
# ['Body Part', 'Face', 'Head', 'Neck', 'Person', 'Adult', 'Female', 'Woman', 'Shoulder']
# Detected labels for post879_img4.jpg
# ['Body Part', 'Face', 'Head', 'Neck', 'Person', 'Skin', 'Adult', 'Female', 'Woman']
# Detected labels for post879_img5.jpg
# ['Person', 'Skin', 'Head', 'Face', 'Adult', 'Female', 'Woman']
# Detected labels for post879_img6.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume']
# Detected labels for post873_img1.jpg
# ['Brush', 'Device', 'Tool', 'Cosmetics', 'Toothbrush', 'Lipstick']
# Detected labels for post871_img1.jpg
# ['Body Part', 'Face', 'Head', 'Neck', 'Person', 'Shoulder', 'Adult', 'Female', 'Woman']
# Detected labels for post871_img2.jpg
# ['Head', 'Person', 'Body Part', 'Face', 'Neck', 'Shoulder', 'Adult', 'Female', 'Woman', 'Photography', 'Portrait', 'Finger', 'Hand', 'Skin', 'Cosmetics', 'Lipstick']
# Detected labels for post871_img3.jpg
# ['Body Part', 'Face', 'Head', 'Neck', 'Person', 'Adult', 'Female', 'Woman', 'Hair']
# Detected labels for post871_img4.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Head', 'Face', 'Body Part', 'Neck', 'Shoulder', 'Photography', 'Portrait', 'Hair']
# Detected labels for post871_img5.jpg
# ['Wood', 'Indoors', 'Interior Design', 'Architecture', 'Building', 'Wall']
# Detected labels for post870_img2.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume']
# Detected labels for post870_img1.jpg
# ['Body Part', 'Face', 'Head', 'Neck', 'Person', 'Accessories', 'Jewelry', 'Necklace', 'Skin', 'Tattoo']
# Detected labels for post866_img1.jpg
# ['Blonde', 'Hair', 'Person', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Photography', 'Portrait', 'Skin', 'Tattoo']
# Detected labels for post866_img2.jpg
# ['Blonde', 'Hair', 'Person', 'Fashion', 'Adult', 'Female', 'Woman', 'Clothing', 'Dress', 'Formal Wear', 'Skin', 'Tattoo', 'Accessories']
# Detected labels for post864_img2.jpg
# ['Cosmetics', 'Ammunition', 'Weapon', 'Medication', 'Pill', 'Lipstick']
# Detected labels for post864_img1.jpg
# ['Clothing', 'Dress', 'Formal Wear', 'Skirt', 'Evening Dress', 'Adult', 'Female', 'Person', 'Woman', 'Shorts', 'Bride', 'Wedding', 'Groupshot', 'Fashion', 'People', 'Accessories', 'Bag', 'Handbag', 'Footwear', 'Shoe']
# Detected labels for post864_img5.jpg
# ['Dressing Room', 'Indoors', 'Room', 'Adult', 'Female', 'Person', 'Woman', 'Head', 'Face']
# Detected labels for post864_img4.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Clothing', 'Dress', 'Formal Wear', 'Cosmetics', 'Lipstick', 'Fashion', 'Gown', 'Wedding', 'Wedding Gown']
# Detected labels for post864_img3.jpg
# ['People', 'Person', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Photography', 'Portrait', 'Dressing Room', 'Indoors', 'Room', 'Urban']
# Detected labels for post864_img6.jpg
# ['Head', 'Person', 'Face', 'Cosmetics', 'Lipstick', 'Skin']
# Detected labels for post864_img7.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Urban', 'Fun', 'Party', 'Bride', 'Wedding']
# Detected labels for post864_img9.jpg
# ['Clothing', 'Dress', 'Adult', 'Female', 'Person', 'Woman', 'Lighting', 'Formal Wear', 'Fashion', 'Male', 'Man', 'Urban', 'Evening Dress', 'Accessories', 'Jewelry', 'Necklace', 'Indoors', 'Face', 'Head', 'Gown', 'Photography', 'Portrait', 'Footwear', 'Shoe']
# Detected labels for post864_img8.jpg
# ['Clothing', 'Coat', 'Jacket', 'Adult', 'Female', 'Person', 'Woman', 'Groupshot', 'Male', 'Man', 'Fashion', 'Skin', 'Tattoo', 'Skirt']
# Detected labels for post864_img12.jpg
# ['Clothing', 'Dress', 'Formal Wear', 'Evening Dress', 'Groupshot', 'Person', 'Coat', 'Fashion', 'Adult', 'Female', 'Woman', 'People', 'Bride', 'Wedding', 'Male', 'Man', 'Skirt']
# Detected labels for post864_img10.jpg
# ['Clothing', 'Dress', 'Adult', 'Female', 'Person', 'Woman', 'Fashion', 'Formal Wear', 'Evening Dress', 'Girl', 'Teen', 'Footwear', 'High Heel', 'Shoe', 'Gown', 'Face', 'Head']
# Detected labels for post864_img11.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Head', 'Face', 'Cosmetics']
# Detected labels for post864_img13.jpg
# ['Cosmetics', 'Brush', 'Device', 'Tool']
# Detected labels for post864_img14.jpg
# ['Adult', 'Male', 'Man', 'Person', 'Female', 'Woman', 'Fun', 'Party', 'Clothing', 'Footwear', 'Shoe', 'Head', 'Face']
# Detected labels for post861_img1.jpg
# ['Person', 'Photobombing', 'Adult', 'Male', 'Man', 'Fashion', 'Head', 'Face', 'Female', 'Woman', 'Bride', 'Wedding', 'Clothing', 'Dress', 'Formal Wear', 'Suit', 'Skin', 'Tattoo', 'Electronics', 'Mobile Phone', 'Phone']
# Detected labels for post861_img3.jpg
# ['Head', 'Person', 'Face', 'Photography', 'Portrait', 'Happy', 'Laughing', 'Smile', 'Adult', 'Female', 'Woman', 'Skin', 'Tattoo', 'Hugging']
# Detected labels for post861_img5.jpg
# ['Head', 'Person', 'Face', 'Happy', 'Adult', 'Male', 'Man', 'Laughing', 'Female', 'Woman', 'Hair', 'Smile']
# Detected labels for post861_img2.jpg
# ['Person', 'Photobombing', 'Adult', 'Female', 'Woman', 'Urban', 'Bride', 'Wedding', 'Skin', 'Tattoo', 'Face', 'Head']
# Detected labels for post861_img4.jpg
# ['Clothing', 'Dress', 'Formal Wear', 'Evening Dress', 'Adult', 'Female', 'Person', 'Woman', 'Fashion', 'Groupshot', 'Girl', 'Teen', 'Bride', 'Wedding', 'Gown', 'Male', 'Man', 'Accessories', 'Jewelry', 'Necklace', 'Face', 'Head', 'Footwear', 'Shoe', 'People']
# Detected labels for post861_img8.jpg
# ['Clothing', 'Dress', 'Evening Dress', 'Formal Wear', 'Face', 'Head', 'Person', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Fashion', 'Accessories', 'Jewelry', 'Necklace', 'Happy', 'Smile', 'Gown']
# Detected labels for post861_img6.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Photography', 'Portrait', 'Brown Hair', 'Hair', 'Happy', 'Smile']
# Detected labels for post861_img7.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Skin', 'Head', 'Face', 'Hair', 'Photobombing', 'Blonde', 'Tattoo', 'Fashion']
# Detected labels for post861_img11.jpg
# ['Clothing', 'Dress', 'Formal Wear', 'Evening Dress', 'Fashion', 'Groupshot', 'Person', 'Coat', 'Adult', 'Female', 'Woman', 'Lighting', 'People', 'Suit']
# Detected labels for post861_img9.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Photobombing', 'Fashion', 'Male', 'Man', 'Clothing', 'Footwear', 'Shoe', 'Face', 'Head', 'Urban', 'Skin', 'Tattoo']
# Detected labels for post861_img10.jpg
# ['Person', 'Sitting', 'Adult', 'Female', 'Woman', 'Skin', 'Tattoo', 'Clothing', 'Sleeve', 'Dress', 'Black Hair', 'Hair']
# Detected labels for post861_img15.jpg
# ['Cosmetics', 'Lipstick', 'Head', 'Person', 'Face', 'Accessories', 'Diamond', 'Gemstone', 'Jewelry', 'Skin', 'Tattoo']
# Detected labels for post861_img13.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Head', 'Face', 'Skin', 'Tattoo', 'Body Part', 'Finger', 'Hand', 'Photography', 'Selfie']
# Detected labels for post861_img14.jpg
# ['Clothing', 'Dress', 'Fashion', 'Adult', 'Female', 'Person', 'Woman', 'Formal Wear', 'Face', 'Head', 'Photography', 'Portrait', 'Evening Dress', 'Gown', 'Wedding', 'Wedding Gown']
# Detected labels for post861_img12.jpg
# ['Clothing', 'Dress', 'Formal Wear', 'Adult', 'Female', 'Person', 'Woman', 'Footwear', 'Shoe', 'Floor', 'Fashion', 'Evening Dress', 'High Heel', 'Indoors']
# Detected labels for post854_img1.jpg
# ['Cosmetics', 'Brush', 'Device', 'Tool', 'Lipstick']
# Detected labels for post854_img2.jpg
# ['Brush', 'Device', 'Tool', 'Cosmetics', 'Lipstick']
# Detected labels for post853_img1.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Cosmetics', 'Lipstick']
# Detected labels for post851_img1.jpg
# ['Head', 'Person', 'Face', 'Happy', 'Laughing', 'Adult', 'Female', 'Woman', 'Accessories', 'Glasses', 'Jewelry', 'Necklace', 'Smile', 'Male', 'Man']
# Detected labels for post851_img2.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Head', 'Face', 'Clothing', 'Dress', 'Happy', 'Smile', 'People', 'Plant', 'Tree', 'Accessories', 'Jewelry', 'Necklace', 'Laughing', 'Photography', 'Portrait', 'Wristwatch', 'Skirt', 'Car', 'Transportation', 'Vehicle']
# Detected labels for post851_img3.jpg
# ['Accessories', 'Adult', 'Male', 'Man', 'Person', 'Bracelet', 'Jewelry', 'Female', 'Woman', 'Plant', 'Tree', 'Body Part', 'Finger', 'Hand', 'Head', 'Face', 'Happy', 'Smile', 'Palm Tree', 'Photography', 'Portrait']
# Detected labels for post851_img4.jpg
# ['Cosmetics', 'Medication', 'Pill', 'Bottle', 'Shaker']
# Detected labels for post846_img1.jpg
# ['Bottle', 'Body Part', 'Finger', 'Hand', 'Person', 'Cosmetics', 'Perfume']
# Detected labels for post845_img1.jpg
# ['Dressing Room', 'Indoors', 'Room', 'Blonde', 'Hair', 'Person', 'Adult', 'Female', 'Woman']
# Detected labels for post841_img1.jpg
# ['Clothing', 'Dress', 'Adult', 'Female', 'Person', 'Woman', 'Blouse', 'Evening Dress', 'Formal Wear', 'Fashion', 'Accessories', 'Jewelry', 'Necklace']
# Detected labels for post841_img2.jpg
# ['Clothing', 'Dress', 'Long Sleeve', 'Sleeve', 'Face', 'Head', 'Person', 'Photography', 'Portrait', 'Formal Wear', 'Fashion', 'Coat', 'Lady', 'Evening Dress', 'Gown', 'Adult', 'Female', 'Woman', 'Happy', 'Smile', 'Cape']
# Detected labels for post841_img3.jpg
# ['Fashion', 'Clothing', 'Dress', 'Adult', 'Bride', 'Female', 'Person', 'Wedding', 'Woman', 'Student', 'Dancing', 'Leisure Activities', 'Performer', 'Solo Performance', 'Formal Wear', 'Sleeve']
# Detected labels for post829_img1.jpg
# ['Clothing', 'Dress', 'Evening Dress', 'Formal Wear', 'Adult', 'Female', 'Person', 'Woman', 'Fashion', 'Gown', 'Indoors', 'Dressing Room', 'Room']
# Detected labels for post829_img3.jpg
# ['Clothing', 'Dress', 'Evening Dress', 'Formal Wear', 'Fashion', 'Adult', 'Female', 'Person', 'Woman', 'Footwear', 'Shoe', 'High Heel', 'Blonde', 'Hair', 'Cosmetics', 'Lipstick']
# Detected labels for post829_img2.jpg
# ['Clothing', 'Dress', 'Fashion', 'Adult', 'Female', 'Person', 'Woman', 'Formal Wear', 'Evening Dress', 'Bride', 'Wedding', 'Gown', 'Wedding Gown', 'Skin', 'Tattoo', 'Face', 'Head', 'Blonde', 'Hair']
# Detected labels for post824_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Head', 'Person', 'Electrical Device', 'Switch', 'Face']
# Detected labels for post824_img2.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post823_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Accessories', 'Jewelry', 'Necklace', 'Face', 'Head', 'Body Part', 'Finger', 'Hand', 'Hair']
# Detected labels for post823_img2.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Adult', 'Female', 'Woman', 'Cosmetics', 'Lipstick', 'Head', 'Face', 'Accessories']
# Detected labels for post823_img3.jpg
# ['Accessories', 'Adult', 'Female', 'Person', 'Woman', 'Jewelry', 'Necklace', 'Bra', 'Clothing', 'Lingerie', 'Underwear', 'Face', 'Head']
# Detected labels for post823_img4.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Adult', 'Female', 'Woman', 'Dancing', 'Leisure Activities', 'Face', 'Head', 'Clothing', 'Dress', 'Dance Pose', 'Formal Wear']
# Detected labels for post818_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post818_img2.jpg
# ['Cosmetics', 'Lipstick', 'Person']
# Detected labels for post818_img3.jpg
# ['Cosmetics', 'Lipstick', 'Advertisement', 'Bottle']
# Detected labels for post818_img4.jpg
# ['Wood', 'Floor', 'Flooring', 'Text']
# Detected labels for post818_img5.jpg
# ['Cosmetics', 'Lipstick', 'Brush', 'Device', 'Tool', 'Head', 'Person', 'Face']
# Detected labels for post817_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Head', 'Face', 'Black Hair', 'Hair', 'Clothing', 'Coat', 'Jacket']
# Detected labels for post817_img2.jpg
# ['Clothing', 'Coat', 'Jacket', 'Face', 'Head', 'Person', 'Adult', 'Female', 'Woman', 'Cosmetics', 'Lipstick', 'Skin']
# Detected labels for post817_img3.jpg
# ['Clothing', 'Coat', 'Jacket', 'Accessories', 'Earring', 'Jewelry', 'Adult', 'Female', 'Person', 'Woman', 'Vest', 'Blouse', 'Face', 'Head']
# Detected labels for post817_img4.jpg
# ['Braid', 'Hair', 'Person', 'Adult', 'Female', 'Woman', 'Face', 'Head']
# Detected labels for post817_img5.jpg
# ['Body Part', 'Face', 'Head', 'Neck', 'Person', 'Adult', 'Female', 'Woman', 'Cosmetics', 'Lipstick', 'Photography', 'Portrait']
# Detected labels for post817_img6.jpg
# ['Accessories', 'Adult', 'Female', 'Person', 'Woman', 'Head', 'Face', 'Jewelry', 'Necklace', 'Body Part', 'Neck']
# Detected labels for post814_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Cosmetics', 'Lipstick', 'Clothing', 'Dress', 'Accessories', 'Jewelry', 'Necklace', 'Evening Dress', 'Formal Wear']
# Detected labels for post814_img2.jpg
# ['Clothing', 'Dress', 'Evening Dress', 'Formal Wear', 'Adult', 'Female', 'Person', 'Woman', 'Fashion', 'Face', 'Head', 'Cosmetics', 'Lipstick', 'Velvet', 'Lady']
# Detected labels for post814_img3.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Happy', 'Smile', 'Adult', 'Female', 'Woman', 'Body Part', 'Finger', 'Hand']
# Detected labels for post814_img4.jpg
# ['Braid', 'Hair', 'Person', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Cosmetics', 'Lipstick']
# Detected labels for post814_img5.jpg
# ['Blonde', 'Hair', 'Person', 'Body Part', 'Face', 'Head', 'Neck', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Cosmetics', 'Lipstick']
# Detected labels for post814_img6.jpg
# ['Body Part', 'Face', 'Head', 'Neck', 'Person', 'Accessories', 'Jewelry', 'Necklace', 'Adult', 'Female', 'Woman', 'Skin', 'Cosmetics', 'Lipstick']
# Detected labels for post814_img7.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Cosmetics', 'Lipstick']
# Detected labels for post814_img8.jpg
# ['Blouse', 'Clothing', 'Adult', 'Female', 'Person', 'Woman', 'Dress', 'Silk', 'Fashion', 'Cosmetics', 'Lipstick', 'Face', 'Head']
# Detected labels for post811_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Clothing', 'Glove', 'Coat', 'Blonde', 'Hair', 'Toy']
# Detected labels for post811_img2.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Clothing', 'Coat', 'Face', 'Head', 'Skin', 'Tattoo', 'Toy']
# Detected labels for post811_img4.jpg
# ['Clothing', 'Glove', 'Adult', 'Female', 'Person', 'Woman', 'Urban', 'Photobombing', 'Male', 'Man', 'Face', 'Head', 'Accessories', 'Glasses', 'Festival']
# Detected labels for post811_img3.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Clothing', 'Coat', 'Bride', 'Wedding', 'Photobombing', 'Blonde', 'Hair', 'Dress', 'Indoors']
# Detected labels for post811_img5.jpg
# ['Clothing', 'Coat', 'Jacket', 'Adult', 'Female', 'Person', 'Woman', 'Urban', 'Face', 'Head', 'Photography', 'Portrait', 'Photobombing', 'Pants', 'Blouse', 'Scarf', 'Costume', 'Appliance', 'Device', 'Electrical Device', 'Washer', 'Accessories', 'Glasses', 'Indoors', 'Bag', 'Handbag']
# Detected labels for post811_img8.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Clothing', 'Glove', 'Head', 'Face', 'Performer', 'Solo Performance', 'Accessories', 'Glasses', 'Photography', 'Portrait', 'Jewelry', 'Necklace', 'Festival']
# Detected labels for post811_img6.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Clothing', 'Coat', 'Glove', 'Head', 'Face', 'Jacket', 'Male', 'Man', 'Photobombing', 'Skin', 'Tattoo']
# Detected labels for post811_img7.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Clothing', 'Coat', 'Jacket', 'Glove', 'Urban', 'Photobombing']
# Detected labels for post808_img1.jpg
# ['Back', 'Body Part', 'Person', 'Skin', 'Tattoo', 'Clothing', 'Swimwear', 'Adult', 'Female', 'Woman', 'Bikini', 'Finger', 'Hand', 'Lingerie', 'Underwear']
# Detected labels for post807_img1.jpg
# ['Clothing', 'Swimwear', 'Bikini', 'Adult', 'Female', 'Person', 'Woman', 'Body Part', 'Finger', 'Hand']
# Detected labels for post806_img1.jpg
# ['Clothing', 'Swimwear', 'Bikini', 'Body Part', 'Finger', 'Hand', 'Person', 'Blade', 'Razor', 'Weapon']
# Detected labels for post805_img1.jpg
# ['Brown Hair', 'Hair', 'Person', 'Curly Hair', 'Smoke Pipe', 'Accessories', 'Jewelry', 'Necklace', 'Face', 'Head']
# Detected labels for post803_img1.jpg
# ['Clothing', 'Pants', 'Jeans', 'Coat', 'Jacket', 'Adult', 'Female', 'Person', 'Woman', 'Face', 'Happy', 'Head', 'Smile', 'Accessories', 'Jewelry', 'Necklace', 'Glasses', 'Blonde', 'Hair', 'Photography', 'Portrait', 'Belt', 'Costume']
# Detected labels for post803_img3.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Blonde', 'Hair', 'Performer', 'Solo Performance']
# Detected labels for post803_img2.jpg
# ['Blonde', 'Hair', 'Person', 'Adult', 'Female', 'Woman', 'Urban', 'Accessories', 'Sunglasses', 'Face', 'Head']
# Detected labels for post803_img4.jpg
# ['Head', 'Person', 'Face', 'Happy', 'Laughing', 'Clothing', 'Coat', 'Performer', 'Solo Performance', 'Urban']
# Detected labels for post794_img1.jpg
# ['Cosmetics', 'Lipstick', 'Adult', 'Female', 'Person', 'Woman', 'Bottle', 'Perfume', 'Face', 'Head']
# Detected labels for post794_img2.jpg
# ['Shop', 'Shopping Mall', 'Person', 'Adult', 'Female', 'Woman', 'People', 'Face', 'Head', 'Indoors']
# Detected labels for post794_img3.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume', 'Face', 'Head', 'Person', 'Adult', 'Female', 'Woman']
# Detected labels for post794_img4.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Cosmetics', 'Festival', 'Hanukkah Menorah']
# Detected labels for post794_img5.jpg
# ['Shop', 'Bottle', 'Shaker', 'Indoors', 'Cosmetics']
# Detected labels for post794_img6.jpg
# ['Cosmetics', 'Makeup']
# Detected labels for post794_img7.jpg
# ['Shop', 'Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Indoors', 'People', 'Market']
# Detected labels for post788_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Head', 'Face', 'Skin', 'Photography', 'Portrait', 'Body Part', 'Neck']
# Detected labels for post788_img2.jpg
# ['Person', 'Skin', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Cosmetics', 'Lipstick']
# Detected labels for post788_img3.jpg
# ['Face', 'Head', 'Person', 'Adult', 'Female', 'Woman', 'Skin', 'Photography', 'Portrait', 'Cosmetics', 'Lipstick']
# Detected labels for post783_img1.jpg
# ['Body Part', 'Mouth', 'Person', 'Cosmetics', 'Lipstick', 'Teeth', 'Baby']
# Detected labels for post783_img2.jpg
# ['Body Part', 'Mouth', 'Person']
# Detected labels for post783_img3.jpg
# ['Body Part', 'Mouth', 'Person', 'Teeth', 'Baby', 'Tongue']
# Detected labels for post780_img1.jpg
# ['Face', 'Happy', 'Head', 'Person', 'Smile', 'Photography', 'Portrait', 'People', 'Adult', 'Female', 'Woman', 'Photobombing', 'Accessories', 'Jewelry', 'Ring', 'Blouse', 'Clothing', 'Groupshot', 'Selfie', 'Glove', 'Dress']
# Detected labels for post780_img2.jpg
# ['Cosmetics', 'Makeup', 'Can', 'Tin']
# Detected labels for post780_img3.jpg
# ['Head', 'Person', 'Face', 'Photography', 'Portrait', 'Body Part', 'Finger', 'Hand', 'Baby', 'Cosmetics', 'Lipstick']
# Detected labels for post780_img4.jpg
# ['Head', 'Person', 'Face', 'Adult', 'Female', 'Woman', 'Cosmetics', 'Lipstick', 'Photography', 'Portrait', 'Bottle', 'Perfume']
# Detected labels for post780_img5.jpg
# ['Head', 'Person', 'Face', 'Adult', 'Female', 'Woman', 'Photography', 'Portrait', 'Body Part', 'Finger', 'Hand', 'Cosmetics']
# Detected labels for post780_img6.jpg
# ['Head', 'Person', 'Face', 'Skin', 'Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post780_img7.jpg
# ['Cosmetics', 'Lipstick', 'Bottle']
# Detected labels for post770_img4.jpg
# ['Cosmetics', 'Accessories', 'Wallet', 'Nail Polish']
# Detected labels for post770_img5.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Nail', 'Skin']
# Detected labels for post770_img1.jpg
# ['Cosmetics', 'Lipstick', 'Nail Polish']
# Detected labels for post770_img3.jpg
# ['Electronics', 'Mobile Phone', 'Phone', 'Person', 'Skin', 'Tattoo']
# Detected labels for post770_img2.jpg
# ['Cosmetics']
# Detected labels for post769_img1.jpg
# ['City', 'Body Part', 'Finger', 'Hand', 'Person', 'Architecture', 'Building', 'Outdoors', 'Shelter', 'Road', 'Street', 'Urban', 'Adult', 'Male', 'Man', 'Car', 'Transportation', 'Vehicle', 'Neighborhood', 'Arm', 'Cityscape', 'Condo', 'Housing']
# Detected labels for post768_img1.jpg
# ['Body Part', 'Face', 'Head', 'Neck', 'Person', 'Adult', 'Female', 'Woman', 'Cosmetics', 'Lipstick', 'Accessories', 'Jewelry', 'Necklace', 'Skin']
# Detected labels for post758_img1.jpg
# ['Advertisement', 'Poster']
# Detected labels for post758_img2.jpg
# ['Advertisement', 'Poster']
# Detected labels for post758_img3.jpg
# ['Advertisement', 'Poster']
# Detected labels for post758_img4.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Advertisement', 'Publication', 'Poster', 'Fashion', 'Photo Booth']
# Detected labels for post758_img5.jpg
# ['Clothing', 'Costume', 'Person', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Hair', 'Accessories', 'Jewelry', 'Necklace']
# Detected labels for post758_img6.jpg
# ['Purple', 'Adult', 'Female', 'Person', 'Woman', 'Accessories', 'Face', 'Head', 'Clothing', 'Dress']
# Detected labels for post758_img7.jpg
# ['Clothing', 'Footwear', 'Shoe', 'High Heel', 'Person', 'Blouse', 'Advertisement']
# Detected labels for post756_img2.jpg
# ['Publication', 'Advertisement', 'Book', 'Adult', 'Female', 'Person', 'Woman', 'Poster', 'Face', 'Head', 'Comics', 'Art', 'Cosmetics', 'Lipstick', 'Accessories', 'Jewelry', 'Necklace']
# Detected labels for post756_img1.jpg
# ['Advertisement', 'Poster', 'Adult', 'Female', 'Person', 'Woman', 'Publication', 'Face', 'Head', 'Photography', 'Portrait', 'Magazine']
# Detected labels for post756_img3.jpg
# ['Advertisement', 'Poster', 'Publication', 'Purple', 'Adult', 'Female', 'Person', 'Woman', 'Book', 'Face', 'Head']
# Detected labels for post753_img1.jpg
# ['Cosmetics', 'Face', 'Head', 'Person', 'Lipstick']
# Detected labels for post753_img2.jpg
# ['Bread', 'Food', 'Tin', 'Dynamite', 'Weapon']
# Detected labels for post753_img3.jpg
# ['Cosmetics', 'Adult', 'Female', 'Person', 'Woman', 'Lipstick', 'Makeup']
# Detected labels for post753_img4.jpg
# ['Fun', 'Accessories', 'Glasses', 'Bag', 'Handbag', 'Leisure Activities', 'Picnic', 'Picnic Basket', 'Belt', 'Clothing', 'Footwear', 'Sandal']
# Detected labels for post753_img5.jpg
# ['Cosmetics', 'Face', 'Head', 'Person', 'Accessories', 'Jewelry', 'Locket', 'Pendant']
# Detected labels for post746_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Plate', 'Perfume', 'Tape']
# Detected labels for post746_img2.jpg
# ['Head', 'Person', 'Face', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Black Hair', 'Hair']
# Detected labels for post742_img1.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Baby', 'Jar', 'Dessert', 'Food', 'Yogurt', 'Cream', 'Ice Cream', 'Cosmetics']
# Detected labels for post742_img2.jpg
# ['Black Hair', 'Hair', 'Person', 'Adult', 'Female', 'Woman']
# Detected labels for post731_img1.jpg
# ['Face', 'Head', 'Person', 'Adult', 'Female', 'Woman', 'Skin', 'Hair']
# Detected labels for post731_img4.jpg
# ['Person', 'Animal', 'Canine', 'Mammal', 'Pet', 'Hair']
# Detected labels for post731_img3.jpg
# ['Clothing', 'Coat', 'Jacket', 'Fashion', 'Long Sleeve', 'Sleeve', 'Face', 'Head', 'Person', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Formal Wear', 'Dress', 'Bottle']
# Detected labels for post731_img2.jpg
# ['Face', 'Head', 'Person', 'Adult', 'Female', 'Woman', 'Accessories', 'Jewelry', 'Necklace', 'Clothing', 'Coat', 'Jacket', 'Blonde', 'Hair']
# Detected labels for post731_img5.jpg
# ['Photography', 'Face', 'Head', 'Person', 'Portrait', 'Lighting', 'Dressing Room', 'Indoors', 'Room', 'Body Part', 'Finger', 'Hand', 'Adult', 'Bride', 'Female', 'Wedding', 'Woman', 'Neck']
# Detected labels for post731_img6.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Hair', 'Accessories', 'Jewelry', 'Ring', 'Necklace', 'Bag', 'Handbag']
# Detected labels for post731_img9.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Body Part', 'Finger', 'Hand', 'Accessories', 'Bag', 'Handbag', 'Fashion', 'Adult', 'Bride', 'Female', 'Wedding', 'Woman', 'Publication', 'Book', 'Jewelry', 'Ring', 'People']
# Detected labels for post731_img7.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Face', 'Head', 'Photography', 'Portrait', 'Adult', 'Bride', 'Female', 'Wedding', 'Woman', 'Hair']
# Detected labels for post731_img8.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Face', 'Head', 'Photography', 'Portrait', 'Skin', 'Tattoo']
# Detected labels for post725_img1.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Skin', 'Tattoo', 'Cosmetics', 'Lipstick', 'Bottle', 'Perfume', 'Face', 'Head']
# Detected labels for post725_img2.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Indoors', 'Shop', 'Cosmetics']
# Detected labels for post720_img1.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Face', 'Happy', 'Head', 'Smile', 'Bottle', 'Cosmetics', 'Perfume', 'Photography', 'Portrait', 'Clothing', 'Dress', 'Formal Wear', 'Laughing']
# Detected labels for post720_img2.jpg
# ['Clothing', 'Dress', 'Evening Dress', 'Formal Wear', 'Flower', 'Flower Arrangement', 'Flower Bouquet', 'Plant', 'Adult', 'Female', 'Person', 'Woman', 'Fashion', 'Accessories', 'Jewelry', 'Necklace', 'Footwear', 'High Heel', 'Shoe', 'Face', 'Happy', 'Head', 'Smile']
# Detected labels for post720_img3.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Body Part', 'Finger', 'Hand', 'Person']
# Detected labels for post720_img4.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Flower', 'Flower Arrangement', 'Flower Bouquet', 'Plant', 'Clothing', 'Dress', 'Evening Dress', 'Formal Wear', 'Face', 'Happy', 'Head', 'Smile', 'Adult', 'Female', 'Woman', 'Rose', 'Bottle', 'Cosmetics', 'Perfume', 'Photography', 'Portrait']
# Detected labels for post720_img5.jpg
# ['Flower', 'Flower Arrangement', 'Flower Bouquet', 'Plant', 'Potted Plant', 'Jar', 'Face', 'Happy', 'Head', 'Person', 'Smile', 'Adult', 'Male', 'Man', 'Pottery', 'Standing', 'Clothing', 'Coat', 'Vase', 'Accessories', 'Wallet', 'Jewelry', 'Necklace']
# Detected labels for post720_img6.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Fashion', 'People', 'Flower', 'Flower Arrangement', 'Flower Bouquet', 'Plant', 'Bottle', 'Cosmetics', 'Perfume', 'Clothing', 'Dress', 'Evening Dress', 'Formal Wear', 'Long Sleeve', 'Sleeve']
# Detected labels for post720_img7.jpg
# ['Wood', 'Altar', 'Architecture', 'Building', 'Church', 'Prayer', 'Indoors', 'Interior Design', 'Cup', 'Plywood', 'Flower', 'Flower Arrangement', 'Plant', 'Hardwood', 'Candle', 'Lighting', 'Furniture', 'Table']
# Detected labels for post720_img8.jpg
# ['Clothing', 'Glove', 'Baseball', 'Baseball Glove', 'Sport', 'Head', 'Person', 'Face', 'Photography', 'Portrait', 'Bottle', 'Cosmetics', 'Perfume', 'Accessories', 'Bag', 'Handbag', 'Dress', 'Flower', 'Flower Arrangement', 'Flower Bouquet', 'Plant', 'Smoke']
# Detected labels for post720_img9.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Face', 'Head', 'Person', 'Photography', 'Portrait', 'Hair', 'Braid']
# Detected labels for post720_img10.jpg
# ['Clothing', 'Pants', 'Jeans', 'Flower', 'Flower Arrangement', 'Flower Bouquet', 'Plant', 'Female', 'Girl', 'Person', 'Teen', 'Face', 'Head', 'Accessories', 'Bag', 'Handbag', 'Footwear', 'Shoe']
# Detected labels for post719_img1.jpg
# ['Beverage', 'Coffee', 'Coffee Cup', 'Furniture', 'Table', 'Plate', 'Electronics', 'Mobile Phone', 'Phone', 'Accessories', 'Wallet']
# Detected labels for post710_img1.jpg
# ['Adult', 'Bride', 'Female', 'Person', 'Wedding', 'Woman', 'Face', 'Head', 'Accessories', 'Jewelry', 'Necklace']
# Detected labels for post710_img2.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post704_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume']
# Detected labels for post704_img2.jpg
# ['Cosmetics', 'Adult', 'Female', 'Person', 'Woman', 'Makeup', 'Accessories', 'Jewelry', 'Ring']
# Detected labels for post704_img11.jpg
# ['Cosmetics', 'Makeup', 'Brush', 'Device', 'Tool', 'Lipstick', 'Adult', 'Male', 'Man', 'Person']
# Detected labels for post704_img3.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Male', 'Man', 'Cosmetics']
# Detected labels for post704_img12.jpg
# ['Cosmetics', 'Face', 'Head', 'Person', 'Bottle', 'Perfume', 'Skin', 'Tattoo']
# Detected labels for post704_img4.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Bottle', 'Cosmetics', 'Perfume', 'Face', 'Head']
# Detected labels for post704_img5.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Face', 'Head', 'Skin']
# Detected labels for post704_img13.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Brush', 'Device', 'Tool']
# Detected labels for post704_img6.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post704_img14.jpg
# ['Hairdresser', 'Person', 'Adult', 'Male', 'Man', 'Haircut', 'Female', 'Woman', 'Child', 'Girl', 'Baby', 'Head']
# Detected labels for post704_img8.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Cosmetics', 'Head', 'Face', 'Makeup', 'Lipstick']
# Detected labels for post704_img7.jpg
# ['Head', 'Person', 'Face', 'Adult', 'Female', 'Woman', 'Body Part', 'Neck', 'Skin']
# Detected labels for post704_img15.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Baby', 'Hairdresser', 'Face', 'Head', 'Haircut']
# Detected labels for post704_img9.jpg
# ['Body Part', 'Face', 'Head', 'Neck', 'Person', 'Photography', 'Portrait', 'Accessories', 'Jewelry', 'Necklace', 'Shoulder', 'Clothing', 'Coat']
# Detected labels for post704_img10.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume', 'Baby', 'Person']
# Detected labels for post699_img1.jpg
# ['Baby', 'Person', 'Face', 'Head', 'Text']
# Detected labels for post699_img2.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Clothing', 'Hat', 'Advertisement', 'Cosmetics', 'Lipstick', 'Poster']
# Detected labels for post699_img4.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post699_img5.jpg
# ['Person', 'Skin', 'Adult', 'Female', 'Woman', 'Cosmetics', 'Lipstick', 'Face', 'Head']
# Detected labels for post699_img3.jpg
# ['Car', 'Transportation', 'Vehicle', 'Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post699_img8.jpg
# ['City', 'Water', 'Urban', 'Architecture', 'Fountain', 'Plant', 'Tree', 'Outdoors', 'Vegetation', 'Nature', 'Garden', 'Grass', 'Building', 'Office Building']
# Detected labels for post699_img9.jpg
# ['Advertisement', 'Poster', 'Cosmetics', 'Business Card', 'Paper', 'Text']
# Detected labels for post699_img7.jpg
# ['Person', 'Skin', 'Adult', 'Female', 'Woman', 'Cosmetics', 'Lipstick', 'Face', 'Head']
# Detected labels for post699_img6.jpg
# ['Person', 'Skin', 'Body Part', 'Face', 'Head', 'Neck']
# Detected labels for post699_img10.jpg
# ['Grass', 'Plant', 'Backyard', 'Nature', 'Outdoors', 'Yard', 'Flower', 'Petal', 'Vegetation', 'Lawn', 'Garden', 'Architecture', 'Building', 'Shelter', 'Potted Plant', 'Tree', 'People', 'Person', 'Candle']
# Detected labels for post699_img14.jpg
# ['Architecture', 'Building', 'Outdoors', 'Shelter', 'Plant', 'Tree', 'Hotel', 'Grass', 'Planetarium', 'Vegetation', 'Nature', 'Countryside', 'Hut', 'Rural']
# Detected labels for post699_img11.jpg
# ['Art', 'Painting', 'Box', 'Package', 'Plant', 'Tree', 'Flower', 'Outdoors']
# Detected labels for post699_img13.jpg
# ['Citrus Fruit', 'Food', 'Fruit', 'Orange', 'Plant', 'Produce', 'Grapefruit', 'Grass', 'Baby', 'Person', 'Sphere', 'Balloon', 'Outdoors', 'Tree']
# Detected labels for post699_img12.jpg
# ['Art', 'Painting', 'Purple', 'Architecture', 'Building', 'House', 'Housing', 'Staircase', 'Outdoors', 'Flower', 'Plant', 'Nature']
# Detected labels for post699_img15.jpg
# ['Fashion', 'Altar', 'Architecture', 'Building', 'Church', 'Prayer', 'Lighting', 'Candle', 'Appliance', 'Ceiling Fan', 'Device', 'Electrical Device']
# Detected labels for post690_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post687_img1.jpg
# ['Head', 'Person', 'Face', 'Adult', 'Female', 'Woman', 'Accessories', 'Jewelry', 'Business Card', 'Paper', 'Text', 'Cosmetics', 'Makeup']
# Detected labels for post687_img2.jpg
# ['Accessories', 'Jewelry', 'Necklace', 'Person', 'Alcohol', 'Beverage', 'Head', 'Face', 'Drinking', 'Drinking Alcohol']
# Detected labels for post686_img1.jpg
# ['Number', 'Symbol', 'Text']
# Detected labels for post685_img1.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Head', 'Face', 'Photography', 'Portrait', 'Baby', 'Mouth']
# Detected labels for post685_img2.jpg
# ['Cosmetics', 'Lipstick', 'Accessories', 'Sunglasses', 'Body Part', 'Mouth', 'Person']
# Detected labels for post685_img3.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Photography', 'Portrait', 'Hair']
# Detected labels for post685_img6.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Head', 'Face', 'Adult', 'Female', 'Woman', 'Bottle', 'Cosmetics', 'Perfume', 'Photography', 'Skin']
# Detected labels for post685_img5.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Cosmetics', 'Lipstick', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Photography', 'Portrait']
# Detected labels for post685_img4.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Face', 'Head', 'Photography', 'Portrait', 'Cosmetics', 'Lipstick', 'Adult', 'Bride', 'Female', 'Wedding', 'Woman', 'Mouth', 'Accessories', 'Diamond', 'Gemstone', 'Jewelry']
# Detected labels for post685_img7.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Clothing', 'Hood', 'Adult', 'Female', 'Woman', 'Fashion', 'Hoodie', 'Knitwear', 'Sweater', 'Sweatshirt', 'Skin', 'Happy', 'Smile']
# Detected labels for post685_img8.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Hair', 'Photography', 'Portrait', 'Skin', 'Tattoo', 'Cosmetics', 'Lipstick']
# Detected labels for post685_img9.jpg
# ['Purple', 'Face', 'Head', 'Person', 'Photography', 'Portrait', 'Accessories', 'Sunglasses', 'Body Part', 'Finger', 'Hand', 'Adult', 'Female', 'Woman', 'Clothing', 'Dress', 'Formal Wear', 'Glasses', 'Fashion', 'Happy', 'Smile']
# Detected labels for post685_img10.jpg
# ['Accessories', 'Glasses', 'Sunglasses', 'Face', 'Head', 'Person', 'Photography', 'Portrait', 'Body Part', 'Finger', 'Hand', 'Baby', 'Happy', 'Smile', 'Skin', 'Clothing', 'Hood']
# Detected labels for post684_img1.jpg
# ['Cosmetics', 'Lipstick', 'Accessories', 'Sunglasses', 'Face', 'Head', 'Person']
# Detected labels for post684_img2.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post683_img1.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Purple', 'Accessories', 'Jewelry', 'Cosmetics', 'Lipstick']
# Detected labels for post683_img2.jpg
# ['Person', 'Skin', 'Adult', 'Female', 'Woman', 'Head', 'Face', 'Body Part', 'Mouth', 'Cosmetics', 'Lipstick']
# Detected labels for post683_img3.jpg
# ['Cosmetics', 'Lipstick', 'Nail Polish']
# Detected labels for post683_img4.jpg
# ['Person', 'Skin', 'Arm', 'Body Part', 'Text']
# Detected labels for post682_img1.jpg
# ['Purple', 'Accessories', 'Sunglasses', 'Glasses', 'Body Part', 'Finger', 'Hand', 'Person', 'Face', 'Head', 'Photography', 'Portrait', 'Baby', 'Mouth']
# Detected labels for post682_img2.jpg
# ['Car', 'Transportation', 'Vehicle', 'Cosmetics']
# Detected labels for post681_img1.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Body Part', 'Mouth', 'Adult', 'Female', 'Woman', 'Cosmetics', 'Lipstick']
# Detected labels for post681_img2.jpg
# ['Chocolate', 'Dessert', 'Food', 'Cup', 'Sweets', 'Car', 'Transportation', 'Vehicle', 'Cosmetics']
# Detected labels for post680_img1.jpg
# ['Cosmetics', 'Lipstick', 'Accessories', 'Sunglasses', 'Face', 'Head', 'Person', 'Adult', 'Female', 'Woman', 'Body Part', 'Finger', 'Hand']
# Detected labels for post680_img2.jpg
# ['Car', 'Transportation', 'Vehicle', 'Cosmetics', 'Maroon', 'Bottle']
# Detected labels for post676_img2.jpg
# ['Head', 'Person', 'Face', 'Bottle', 'Cosmetics', 'Perfume', 'Skin']
# Detected labels for post676_img1.jpg
# ['Cosmetics', 'Lipstick', 'Makeup']
# Detected labels for post676_img3.jpg
# ['Person', 'Skin', 'Arm', 'Body Part', 'Text']
# Detected labels for post670_img1.jpg
# ['Cosmetics', 'Lipstick', 'Adult', 'Female', 'Person', 'Woman', 'Head', 'Face', 'Bottle', 'Perfume']
# Detected labels for post670_img2.jpg
# ['Cosmetics', 'Lipstick', 'Head', 'Person', 'Face', 'Adult', 'Female', 'Woman', 'Skin', 'Photography', 'Portrait']
# Detected labels for post670_img3.jpg
# ['Face', 'Head', 'Person', 'Adult', 'Female', 'Woman', 'Body Part', 'Mouth', 'Teeth', 'Medication', 'Pill', 'Credit Card', 'Text']
# Detected labels for post670_img4.jpg
# ['Head', 'Person', 'Face', 'Cosmetics', 'Lipstick', 'Photography', 'Portrait', 'Bottle', 'Perfume']
# Detected labels for post670_img5.jpg
# ['Cosmetics', 'Lipstick', 'Face', 'Head', 'Person']
# Detected labels for post664_img2.jpg
# []
# Detected labels for post664_img1.jpg
# []
# Detected labels for post664_img3.jpg
# ['Maroon', 'Indoors', 'Interior Design']
# Detected labels for post664_img6.jpg
# ['Indoors', 'Interior Design']
# Detected labels for post664_img5.jpg
# ['Indoors', 'Interior Design']
# Detected labels for post664_img4.jpg
# ['Indoors', 'Interior Design']
# Detected labels for post664_img8.jpg
# ['Indoors', 'Interior Design', 'Pen', 'Maroon']
# Detected labels for post664_img7.jpg
# ['Indoors', 'Interior Design']
# Detected labels for post664_img9.jpg
# ['Indoors', 'Interior Design', 'Pen']
# Detected labels for post664_img10.jpg
# []
# Detected labels for post664_img11.jpg
# ['Text', 'Arm', 'Body Part', 'Person']
# Detected labels for post663_img1.jpg
# ['Person', 'Skin', 'Adult', 'Female', 'Woman', 'Cosmetics', 'Lipstick', 'Body Part', 'Mouth', 'Head', 'Face']
# Detected labels for post663_img2.jpg
# ['Person', 'Skin', 'Head', 'Face', 'Body Part', 'Mouth']
# Detected labels for post663_img3.jpg
# ['Person', 'Skin', 'Adult', 'Female', 'Woman', 'Face', 'Head']
# Detected labels for post663_img4.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Skin', 'Body Part', 'Mouth', 'Cosmetics', 'Lipstick', 'Head', 'Face']
# Detected labels for post663_img5.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Skin', 'Body Part', 'Mouth', 'Cosmetics', 'Lipstick', 'Face', 'Head']
# Detected labels for post660_img1.jpg
# ['Cosmetics', 'Lipstick', 'Pen']
# Detected labels for post660_img2.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post660_img3.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post660_img4.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post658_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume']
# Detected labels for post658_img2.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume']
# Detected labels for post658_img3.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume']
# Detected labels for post656_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post656_img2.jpg
# ['Person', 'Skin', 'Tattoo', 'Body Part', 'Finger', 'Hand', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Cosmetics', 'Lipstick']
# Detected labels for post650_img1.jpg
# ['Cosmetics', 'Lipstick', 'Body Part', 'Mouth', 'Person', 'Can', 'Tin']
# Detected labels for post650_img2.jpg
# ['Cosmetics', 'Lipstick', 'Body Part', 'Mouth', 'Person']
# Detected labels for post650_img3.jpg
# ['Body Part', 'Mouth', 'Person', 'Cosmetics', 'Lipstick']
# Detected labels for post650_img4.jpg
# ['Cosmetics', 'Lipstick', 'Body Part', 'Mouth', 'Person']
# Detected labels for post639_img2.jpg
# ['Cosmetics', 'Lipstick', 'Head', 'Person', 'Face']
# Detected labels for post639_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume']
# Detected labels for post639_img3.jpg
# ['Cosmetics', 'Lipstick', 'Face', 'Head', 'Person', 'Tape']
# Detected labels for post637_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Clothing', 'Hoodie', 'Knitwear', 'Sweater', 'Sweatshirt', 'Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post634_img1.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Happy', 'Smile', 'Baby']
# Detected labels for post634_img2.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Photography', 'Portrait', 'Hair']
# Detected labels for post634_img3.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Photography', 'Portrait', 'Hair', 'Skin', 'Tattoo', 'Red Hair']
# Detected labels for post632_img1.jpg
# ['Cosmetics', 'Lipstick', 'Baton', 'Stick', 'Makeup']
# Detected labels for post632_img2.jpg
# ['Person', 'Skin', 'Body Part', 'Face', 'Head', 'Neck', 'Adult', 'Female', 'Woman', 'Cosmetics', 'Lipstick']
# Detected labels for post632_img3.jpg
# ['Cosmetics', 'Lipstick', 'Makeup', 'Smoke Pipe']
# Detected labels for post624_img1.jpg
# ['Fun', 'Leisure Activities', 'Picnic', 'Picnic Basket', 'Bottle', 'Shaker']
# ...
# ['Indoors', 'Interior Design', 'Bar Stool', 'Furniture', 'Lamp', 'Kitchen', 'Floor', 'Cup']
# Detected labels for post13_img7.jpg
# ['Clothing', 'Dress', 'Evening Dress', 'Formal Wear', 'Adult', 'Female', 'Person', 'Woman', 'Face', 'Happy', 'Head', 'Smile', 'Fashion', 'Photography', 'Portrait', 'Advertisement', 'Skirt', 'Accessories', 'Bag', 'Handbag', 'Publication']
# Detected labels for post13_img9.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Cup', 'Accessories', 'Jewelry', 'Necklace', 'Performer', 'Solo Performance', 'Black Hair', 'Hair', 'Happy', 'Smile']
# Detected labels for post13_img10.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Accessories', 'Jewelry', 'Necklace', 'Ring', 'Clothing', 'Footwear', 'Shoe', 'Head', 'Face', 'Dress', 'Dressing Room', 'Indoors', 'Room', 'Happy', 'Electronics', 'Mobile Phone', 'Phone']
# Detected labels for post13_img11.jpg
# ['Shop', 'Gas Pump', 'Machine', 'Pump', 'Appliance', 'Device', 'Electrical Device', 'Washer']
# Detected labels for post13_img12.jpg
# ['Blonde', 'Hair', 'Person', 'Adult', 'Female', 'Woman', 'Accessories', 'Jewelry', 'Necklace', 'Curly Hair', 'Crib', 'Furniture', 'Infant Bed', 'Clothing', 'Coat', 'Wristwatch', 'Face', 'Head']
# Detected labels for post13_img13.jpg
# ['Bottle', 'Cosmetics']
# Detected labels for post13_img17.jpg
# ['Shop', 'Adult', 'Female', 'Person', 'Woman', 'Indoors', 'Beauty Salon']
# Detected labels for post13_img14.jpg
# ['Clothing', 'Footwear', 'Shoe', 'Person', 'Sitting', 'Head', 'Face', 'Happy', 'Adult', 'Male', 'Man', 'High Heel', 'Sandal', 'Accessories', 'Jewelry', 'Ring', 'Female', 'Woman', 'Sneaker']
# Detected labels for post13_img15.jpg
# ['Bottle', 'Lotion']
# Detected labels for post13_img18.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Clothing', 'Shorts', 'Fur', 'Head', 'Face', 'Fashion', 'Cake', 'Dessert', 'Food', 'Wedding', 'Wedding Cake']
# Detected labels for post13_img19.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Formal Wear', 'Clothing', 'Dress', 'Fashion', 'Black Hair', 'Hair', 'Face', 'Happy', 'Head', 'Smile', 'Photography', 'Portrait', 'Text']
# Detected labels for post13_img16.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Sitting', 'Head', 'Face', 'Happy', 'Smile', 'Bottle', 'Shaker']
# Detected labels for post12_img1.jpg
# ['Electronics', 'Phone', 'Car', 'Transportation', 'Vehicle', 'Tape', 'Cosmetics', 'Lipstick', 'Dial Telephone']
# Detected labels for post12_img2.jpg
# ['Cosmetics', 'Lipstick', 'Cutlery', 'Spoon', 'Brush', 'Device', 'Tool']
# Detected labels for post12_img3.jpg
# ['Electronics', 'Phone', 'Car', 'Transportation', 'Vehicle']
# Detected labels for post12_img4.jpg
# ['Cosmetics', 'Face', 'Head', 'Person']
# Detected labels for post12_img5.jpg
# ['Accessories', 'Bag', 'Handbag', 'Smoke Pipe', 'Glasses', 'Brush', 'Device', 'Tool']
# Detected labels for post12_img6.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post12_img7.jpg
# ['Accessories', 'Bag', 'Handbag', 'Purse', 'Furniture', 'Cosmetics', 'Lipstick']
# Detected labels for post12_img8.jpg
# ['Accessories', 'Bag', 'Handbag', 'Purse', 'Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post12_img9.jpg
# ['Accessories', 'Bag', 'Handbag', 'Cosmetics', 'Lipstick', 'Purse', 'Bottle', 'Perfume']
# Detected labels for post12_img10.jpg
# ['Accessories', 'Bag', 'Handbag', 'Purse']
# Detected labels for post1182_img1.jpg
# ['Bus', 'Transportation', 'Vehicle', 'Person', 'Machine', 'Wheel', 'Tour Bus', 'Nature', 'Outdoors', 'Sky', 'Smoke']
# Detected labels for post1181_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume', 'Smoke Pipe', 'Face', 'Head', 'Person']
# Detected labels for post1180_img1.jpg
# ['Food', 'Fruit', 'Plant', 'Produce', 'Transportation', 'Truck', 'Vehicle']
# Detected labels for post1179_img1.jpg
# ['Cosmetics', 'Tape', 'Nail Polish']
# Detected labels for post1179_img2.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post1178_img1.jpg
# ['Food', 'Fruit', 'Plant', 'Produce']
# Detected labels for post1177_img1.jpg
# ['Food', 'Ketchup']
# Detected labels for post1176_img1.jpg
# ['Alloy Wheel', 'Car', 'Car Wheel', 'Machine', 'Spoke', 'Tire', 'Transportation', 'Vehicle', 'Wheel', 'Limo', 'Bumper']
# Detected labels for post1175_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume', 'Nail Polish']
# Detected labels for post1174_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Adult', 'Female', 'Person', 'Woman', 'Skin', 'Face', 'Head', 'Makeup']
# Detected labels for post1173_img1.jpg
# ['Bus', 'Transportation', 'Vehicle', 'Tour Bus', 'Flower', 'Plant']
# Detected labels for post1168_img1.jpg
# ['Head', 'Person', 'Face', 'Photography', 'Portrait', 'Body Part', 'Neck', 'Skin']
# Detected labels for post1168_img2.jpg
# ['Head', 'Person', 'Face', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Black Hair', 'Hair', 'Cosmetics', 'Lipstick']
# Detected labels for post1168_img3.jpg
# ['Head', 'Person', 'Face', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Skin', 'Freckle', 'Cosmetics', 'Lipstick']
# Detected labels for post1168_img4.jpg
# ['Head', 'Person', 'Face', 'Accessories', 'Earring', 'Jewelry', 'Adult', 'Female', 'Woman', 'Photography', 'Portrait', 'Cosmetics', 'Lipstick']
# Detected labels for post1161_img2.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Cosmetics', 'Makeup', 'Skin', 'Head', 'Face', 'Lipstick']
# Detected labels for post1161_img1.jpg
# ['Person', 'Skin', 'Adult', 'Female', 'Woman', 'Face', 'Head']
# Detected labels for post1158_img1.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Face', 'Head', 'Photography', 'Portrait', 'Skin', 'Adult', 'Female', 'Woman', 'Cosmetics', 'Lipstick', 'Tattoo', 'Accessories', 'Jewelry', 'Necklace', 'Neck']
# Detected labels for post1155_img6.jpg
# ['Text', 'Calendar', 'Business Card', 'Paper']
# Detected labels for post1155_img1.jpg
# ['Cosmetics', 'Lipstick', 'Advertisement', 'Poster', 'Bottle']
# Detected labels for post1155_img7.jpg
# ['Text', 'Calendar']
# Detected labels for post1155_img5.jpg
# ['Head', 'Person', 'Face', 'Happy', 'Laughing', 'Adult', 'Female', 'Woman']
# Detected labels for post1155_img3.jpg
# ['Advertisement', 'Poster', 'Text', 'Business Card', 'Paper']
# Detected labels for post1155_img2.jpg
# ['Head', 'Person', 'Face', 'Female', 'Girl', 'Teen', 'Advertisement']
# Detected labels for post1155_img4.jpg
# ['Head', 'Person', 'Face', 'Advertisement', 'Poster', 'Baby', 'Publication', 'Text']
# Detected labels for post1151_img1.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Adult', 'Male', 'Man', 'Advertisement', 'Poster', 'People', 'Accessories', 'Formal Wear', 'Tie', 'Clothing', 'Suit', 'Text', 'Crowd']
# Detected labels for post1133_img1.jpg
# ['Cosmetics', 'Lipstick', 'Brush', 'Device', 'Tool']
# Detected labels for post1131_img1.jpg
# ['Accessories', 'Pendant', 'Jewelry', 'Necklace', 'Clothing', 'Hat']
# Detected labels for post1131_img2.jpg
# ['Accessories', 'Bag', 'Handbag', 'Clothing', 'Coat', 'Fashion', 'Glove', 'Purse', 'Hat', 'Jewelry', 'Necklace', 'Lady', 'Person']
# Detected labels for post1126_img1.jpg
# ['Cosmetics', 'Brush', 'Device', 'Tool', 'Toothbrush']
# Detected labels for post1123_img1.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Cosmetics', 'Lipstick', 'Adult', 'Female', 'Woman', 'Face', 'Head']
# Detected labels for post1111_img1.jpg
# ['Cream', 'Dessert', 'Food', 'Ice Cream']
# Detected labels for post1111_img2.jpg
# ['Person', 'Skin', 'Adult', 'Female', 'Woman', 'Head', 'Face']
# Detected labels for post1111_img3.jpg
# ['Person', 'Skin', 'Head', 'Face', 'Adult', 'Female', 'Woman']
# Detected labels for post1111_img4.jpg
# ['Head', 'Person', 'Face', 'Adult', 'Female', 'Woman', 'Skin', 'Medication', 'Pill', 'Photography', 'Portrait']
# Detected labels for post1110_img1.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Cosmetics', 'Lipstick', 'Face', 'Head', 'Adult', 'Female', 'Woman', 'Mouth']
# Detected labels for post1099_img1.jpg
# ['Dessert', 'Food', 'Yogurt', 'Tape', 'Cream']
# Detected labels for post1098_img1.jpg
# ['Cosmetics', 'Lipstick', 'Adult', 'Female', 'Person', 'Woman', 'Can', 'Tin', 'Face', 'Head']
# Detected labels for post1089_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1068_img1.jpg
# ['Cosmetics', 'Lipstick', 'Tape', 'Dynamite', 'Weapon']
# Detected labels for post1065_img1.jpg
# ['Food', 'Sweets', 'Body Part', 'Mouth', 'Person', 'Baby', 'Candy']
# Detected labels for post1065_img2.jpg
# ['Body Part', 'Mouth', 'Person', 'Baby', 'Logo']
# Detected labels for post1065_img3.jpg
# ['Food', 'Sweets', 'Body Part', 'Mouth', 'Person', 'Cosmetics', 'Lipstick']
# Detected labels for post1055_img1.jpg
# ['Person', 'Can', 'Tin']
# Detected labels for post1050_img3.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Hair', 'Head', 'Face']
# Detected labels for post1050_img1.jpg
# ['Hair', 'Person', 'Adult', 'Female', 'Woman', 'Black Hair']
# Detected labels for post1050_img2.jpg
# ['Hair', 'Person', 'Accessories', 'Jewelry', 'Necklace', 'Wig', 'Black Hair']
# Detected labels for post1046_img1.jpg
# ['Person', 'Skin', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Cosmetics']
# Detected labels for post1046_img2.jpg
# ['Head', 'Person', 'Face', 'Happy', 'Hair', 'Accessories', 'Diamond', 'Gemstone', 'Jewelry']
# Detected labels for post1046_img3.jpg
# ['Hairdresser', 'Person', 'Haircut', 'Adult', 'Male', 'Man', 'Cosmetics', 'Lipstick']
# Detected labels for post1046_img4.jpg
# ['Clothing', 'Costume', 'Person', 'Bridal Veil', 'Dress', 'Fashion', 'Formal Wear', 'Gown', 'Wedding', 'Wedding Gown', 'Lady', 'Face', 'Head', 'Photography', 'Portrait', 'Coat']
# Detected labels for post1046_img6.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Cosmetics', 'Face', 'Head', 'Lipstick', 'Makeup']
# Detected labels for post1046_img5.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Head', 'Face', 'Skin', 'Tattoo', 'Cosmetics']
# Detected labels for post1046_img8.jpg
# ['Body Part', 'Face', 'Head', 'Neck', 'Person', 'Adult', 'Female', 'Woman', 'Photography', 'Portrait', 'Black Hair', 'Hair']
# Detected labels for post1046_img7.jpg
# ['Bathing', 'Head', 'Person', 'Face', 'Sitting', 'Bathtub', 'Tub', 'Bottle', 'Cosmetics', 'Perfume', 'Skin', 'Tattoo']
# Detected labels for post1046_img9.jpg
# ['Cosmetics', 'Lipstick', 'Adult', 'Female', 'Person', 'Woman', 'Photography', 'Bottle', 'Perfume', 'Medication', 'Pill', 'Makeup']
# Detected labels for post1046_img10.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman']
# Detected labels for post1039_img1.jpg
# ['Cosmetics', 'Lipstick', 'Tape']
# Detected labels for post1036_img1.jpg
# ['Home Decor', 'Texture', 'Road']
# Detected labels for post1036_img2.jpg
# ['Blade', 'Razor', 'Weapon']
# Detected labels for post1036_img3.jpg
# ['Pen']
# Detected labels for post1030_img1.jpg
# ['Architecture', 'Building', 'Dining Room', 'Dining Table', 'Furniture', 'Indoors', 'Room', 'Table', 'Restaurant', 'Adult', 'Male', 'Man', 'Person', 'Bride', 'Female', 'Wedding', 'Woman', 'Face', 'Head', 'Accessories', 'Glasses', 'Cup', 'Saucer', 'Photography', 'Portrait', 'Beverage', 'Coffee', 'Coffee Cup', 'Bag', 'Handbag']
# Detected labels for post1029_img1.jpg
# ['Black Hair', 'Hair', 'Person', 'Head', 'Face', 'Adult', 'Female', 'Woman', 'Photography', 'Portrait']
# Detected labels for post1029_img2.jpg
# ['Photography', 'Head', 'Person', 'Face', 'Bottle', 'Cosmetics', 'Perfume', 'Portrait', 'Black Hair', 'Hair', 'Makeup']
# Detected labels for post1028_img1.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Accessories', 'Sunglasses', 'Face', 'Head', 'Photography', 'Portrait', 'Adult', 'Male', 'Man', 'Clothing', 'Formal Wear', 'Suit', 'Smoke', 'Happy', 'Smile']
# Detected labels for post1028_img2.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Face', 'Head', 'Photography', 'Portrait', 'Clothing', 'Coat', 'Adult', 'Male', 'Man', 'Formal Wear', 'Suit', 'Jacket', 'Bride', 'Female', 'Wedding', 'Woman', 'Accessories', 'Glasses']
# Detected labels for post1028_img3.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Face', 'Head', 'Photography', 'Portrait', 'Accessories', 'Sunglasses', 'Clothing', 'Glove', 'Electrical Device', 'Microphone', 'Adult', 'Male', 'Man', 'Performer', 'Solo Performance', 'Shirt', 'Formal Wear', 'Tie']
# Detected labels for post1028_img4.jpg
# ['Accessories', 'Sunglasses', 'Body Part', 'Finger', 'Hand', 'Person', 'Clothing', 'Glove', 'Face', 'Head', 'Photography', 'Portrait', 'Shirt', 'Adult', 'Male', 'Man', 'Formal Wear', 'Tie']
# Detected labels for post1026_img2.jpg
# ['Face', 'Head', 'Person', 'Clothing', 'Glove', 'Smoke', 'Body Part', 'Finger', 'Hand', 'Adult', 'Male', 'Man', 'Accessories', 'Sunglasses', 'Photography', 'Portrait', 'Smoking']
# Detected labels for post1026_img1.jpg
# ['Computer Hardware', 'Electronics', 'Hardware', 'Monitor', 'Screen', 'Body Part', 'Finger', 'Hand', 'Person', 'TV', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Photography', 'Portrait', 'Bride', 'Wedding', 'Accessories', 'Jewelry']
# Detected labels for post1026_img5.jpg
# ['Computer Hardware', 'Electronics', 'Hardware', 'Monitor', 'Screen', 'Face', 'Head', 'Person', 'Photography', 'Portrait', 'Body Part', 'Finger', 'Hand', 'TV', 'Adult', 'Female', 'Woman', 'Skin', 'Tattoo']
# Detected labels for post1026_img4.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Accessories', 'Sunglasses', 'Face', 'Head', 'Photography', 'Portrait', 'Clothing', 'Shirt', 'Glove', 'Adult', 'Male', 'Man', 'Formal Wear', 'Tie', 'Happy', 'Smile']
# Detected labels for post1026_img3.jpg
# ['Head', 'Person', 'Face', 'Adult', 'Female', 'Woman', 'Photography', 'Portrait', 'Body Part', 'Finger', 'Hand']
# Detected labels for post1026_img6.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Accessories', 'Sunglasses', 'Face', 'Head', 'Photography', 'Portrait', 'Adult', 'Male', 'Man', 'Smoke Pipe', 'Jewelry', 'Clothing', 'Formal Wear', 'Suit', 'Ring']
# Detected labels for post1025_img1.jpg
# ['Plant', 'Potted Plant', 'Face', 'Head', 'Person', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Clothing', 'Formal Wear', 'Suit', 'Body Part', 'Finger', 'Hand', 'Tree', 'Coat', 'Lady', 'Flower']
# Detected labels for post1025_img2.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Plant', 'Potted Plant', 'Clothing', 'Coat', 'Formal Wear', 'Suit', 'Lady', 'Tree', 'Jacket', 'Hair']
# Detected labels for post1024_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Cosmetics', 'Brush', 'Device', 'Tool', 'Makeup', 'Skin', 'Tattoo']
# Detected labels for post1023_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Architecture', 'Building', 'Wall', 'Art']
# Detected labels for post1020_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post1020_img2.jpg
# ['Head', 'Person', 'Face', 'Photography', 'Portrait', 'Body Part', 'Neck', 'Adult', 'Female', 'Woman', 'Skin']
# Detected labels for post1020_img3.jpg
# ['Head', 'Person', 'Face', 'Adult', 'Female', 'Woman', 'Body Part', 'Neck', 'Skin', 'Cosmetics', 'Lipstick']
# Detected labels for post1020_img4.jpg
# ['Head', 'Person', 'Face', 'Adult', 'Female', 'Woman', 'Skin', 'Body Part', 'Neck']
# Detected labels for post1020_img5.jpg
# ['Head', 'Person', 'Face', 'Body Part', 'Neck', 'Skin', 'Adult', 'Female', 'Woman']
# Detected labels for post1020_img6.jpg
# ['Body Part', 'Face', 'Head', 'Neck', 'Person', 'Adult', 'Female', 'Woman', 'Photography', 'Portrait', 'Skin']
# Detected labels for post1011_img1.jpg
# ['Body Part', 'Face', 'Head', 'Neck', 'Person', 'Photography', 'Portrait', 'Skin', 'Adult', 'Female', 'Woman']
# Detected labels for post1011_img2.jpg
# ['Body Part', 'Face', 'Head', 'Neck', 'Person', 'Skin', 'Adult', 'Female', 'Woman']
# Detected labels for post1011_img3.jpg
# ['Person', 'Skin', 'Body Part', 'Face', 'Head', 'Neck', 'Adult', 'Female', 'Woman']
# Detected labels for post1011_img4.jpg
# ['Arm', 'Body Part', 'Person', 'Baby', 'Skin']
# Detected labels for post1010_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post1008_img1.jpg
# ['Cosmetics', 'Lipstick', 'Chocolate', 'Dessert', 'Food']
# Detected labels for post1004_img1.jpg
# ['Person', 'Skin', 'Adult', 'Male', 'Man', 'Cosmetics', 'Lipstick']
# Detected labels for post1004_img2.jpg
# ['Person', 'Cosmetics', 'Lipstick', 'Body Part', 'Hand', 'Skin']
# Detected labels for post1001_img5.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume']
# Detected labels for post1001_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Lotion']

# %%
# Write out the results to a csv
with open(rekog_results_dir + f'labels_final_{username}.csv', 'w', newline = '') as csvfile:
    fieldnames = ['image_id', 'has_makeup', 'has_beauty_product', 'has_logo_or_branding',
 'is_fashion_related', 'is_beauty_scene', 'has_text', 'close_up', 'indoors', 'outdoors']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for entry in holder_labels:
        writer.writerow(entry)

# %%
face_labels = []

for imageFile in local_images:
    image_path = rekog_images_dir + imageFile
    try:
        image_bytes = resize_if_needed(image_path)
    except Exception as e:
        print(f"❌ Skipping {imageFile}: {e}")
        continue

    # Detect facial features
    face_response = client.detect_faces(Image={'Bytes': image_bytes}, Attributes=['ALL'])
    celeb_response = client.recognize_celebrities(Image={'Bytes': image_bytes})

    print('Detected faces and celebrities for ' + imageFile)

    temp_dict = {
        "image_id": imageFile,
        "face_count": 0,
        "has_smile": False,
        "has_female": False,
        "has_male": False,
        "dominant_emotion": None,
        "emotions": [],
        "has_happy_emotion": False,
        "has_confident_emotion": False,
        "has_celebrity": False,
        "celebrity_names": [],
        "has_unrecognized_face": False
    }

    # === CELEBRITY CHECK ===
    matched = celeb_response.get("CelebrityFaces", [])
    unmatched = celeb_response.get("UnrecognizedFaces", [])

    if matched:
        temp_dict["has_celebrity"] = True
        temp_dict["celebrity_names"] = [c["Name"] for c in matched]
    if unmatched:
        temp_dict["has_unrecognized_face"] = True

    # === FACIAL ATTRIBUTES ===
    faces = face_response.get('FaceDetails', [])
    temp_dict["face_count"] = len(faces)

    all_emotions = set()
    happy_detected = False
    confident_detected = False

    for face in faces:
        if face.get('Smile', {}).get('Value'):
            temp_dict["has_smile"] = True

        gender = face.get('Gender', {}).get('Value')
        if gender == 'Female':
            temp_dict["has_female"] = True
        elif gender == 'Male':
            temp_dict["has_male"] = True

        for emotion in face.get('Emotions', []):
            if emotion.get('Confidence', 0) >= 70:
                emotion_type = emotion.get('Type')
                all_emotions.add(emotion_type)

                if emotion_type == 'HAPPY':
                    happy_detected = True
                if emotion_type == 'CONFIDENT':
                    confident_detected = True

    temp_dict["emotions"] = list(all_emotions)
    temp_dict["has_happy_emotion"] = happy_detected
    temp_dict["has_confident_emotion"] = confident_detected
    if all_emotions:
        temp_dict["dominant_emotion"] = list(all_emotions)[0]

    face_labels.append(temp_dict)
# Out:
# Detected faces and celebrities for post1001_img2.jpg
# Detected faces and celebrities for post1001_img3.jpg
# Detected faces and celebrities for post1001_img4.jpg
# Detected faces and celebrities for post992_img1.jpg
# Detected faces and celebrities for post990_img1.jpg
# Detected faces and celebrities for post983_img2.jpg
# Detected faces and celebrities for post983_img1.jpg
# Detected faces and celebrities for post983_img3.jpg
# Detected faces and celebrities for post977_img1.jpg
# Detected faces and celebrities for post956_img1.jpg
# Detected faces and celebrities for post953_img1.jpg
# Detected faces and celebrities for post952_img2.jpg
# Detected faces and celebrities for post952_img3.jpg
# Detected faces and celebrities for post952_img1.jpg
# Detected faces and celebrities for post952_img4.jpg
# Detected faces and celebrities for post952_img6.jpg
# Detected faces and celebrities for post952_img5.jpg
# Detected faces and celebrities for post950_img1.jpg
# Detected faces and celebrities for post950_img3.jpg
# Detected faces and celebrities for post950_img2.jpg
# Detected faces and celebrities for post948_img1.jpg
# Detected faces and celebrities for post946_img1.jpg
# Detected faces and celebrities for post946_img2.jpg
# Detected faces and celebrities for post946_img3.jpg
# Detected faces and celebrities for post946_img4.jpg
# Detected faces and celebrities for post946_img5.jpg
# Detected faces and celebrities for post946_img6.jpg
# Detected faces and celebrities for post934_img3.jpg
# Detected faces and celebrities for post934_img4.jpg
# Detected faces and celebrities for post934_img2.jpg
# Detected faces and celebrities for post934_img1.jpg
# Detected faces and celebrities for post931_img1.jpg
# Detected faces and celebrities for post931_img2.jpg
# Detected faces and celebrities for post931_img3.jpg
# Detected faces and celebrities for post931_img4.jpg
# Detected faces and celebrities for post931_img5.jpg
# Detected faces and celebrities for post931_img6.jpg
# Detected faces and celebrities for post931_img7.jpg
# Detected faces and celebrities for post931_img8.jpg
# Detected faces and celebrities for post931_img9.jpg
# Detected faces and celebrities for post931_img10.jpg
# Detected faces and celebrities for post927_img1.jpg
# Detected faces and celebrities for post927_img2.jpg
# Detected faces and celebrities for post927_img3.jpg
# Detected faces and celebrities for post912_img1.jpg
# Detected faces and celebrities for post911_img1.jpg
# Detected faces and celebrities for post911_img2.jpg
# Detected faces and celebrities for post910_img1.jpg
# Detected faces and celebrities for post910_img2.jpg
# Detected faces and celebrities for post1098_img1.jpg
# Detected faces and celebrities for post1089_img1.jpg
# Detected faces and celebrities for post1068_img1.jpg
# Detected faces and celebrities for post1065_img1.jpg
# Detected faces and celebrities for post1065_img2.jpg
# Detected faces and celebrities for post1065_img3.jpg
# Detected faces and celebrities for post1055_img1.jpg
# Detected faces and celebrities for post1050_img3.jpg
# Detected faces and celebrities for post1050_img1.jpg
# Detected faces and celebrities for post1050_img2.jpg
# Detected faces and celebrities for post1046_img1.jpg
# Detected faces and celebrities for post1046_img2.jpg
# Detected faces and celebrities for post1046_img3.jpg
# Detected faces and celebrities for post1046_img4.jpg
# Detected faces and celebrities for post1046_img6.jpg
# Detected faces and celebrities for post1046_img5.jpg
# Detected faces and celebrities for post1046_img8.jpg
# Detected faces and celebrities for post1046_img7.jpg
# Detected faces and celebrities for post1046_img9.jpg
# Detected faces and celebrities for post1046_img10.jpg
# Detected faces and celebrities for post1039_img1.jpg
# Detected faces and celebrities for post1036_img1.jpg
# Detected faces and celebrities for post1036_img2.jpg
# Detected faces and celebrities for post1036_img3.jpg
# Detected faces and celebrities for post1030_img1.jpg
# Detected faces and celebrities for post1029_img1.jpg
# Detected faces and celebrities for post1029_img2.jpg
# Detected faces and celebrities for post1028_img1.jpg
# Detected faces and celebrities for post1028_img2.jpg
# Detected faces and celebrities for post1028_img3.jpg
# Detected faces and celebrities for post1028_img4.jpg
# Detected faces and celebrities for post1026_img2.jpg
# Detected faces and celebrities for post1026_img1.jpg
# Detected faces and celebrities for post1026_img5.jpg
# Detected faces and celebrities for post1026_img4.jpg
# Detected faces and celebrities for post1026_img3.jpg
# Detected faces and celebrities for post1026_img6.jpg
# Detected faces and celebrities for post1025_img1.jpg
# Detected faces and celebrities for post1025_img2.jpg
# Detected faces and celebrities for post1024_img1.jpg
# Detected faces and celebrities for post1023_img1.jpg
# Detected faces and celebrities for post1020_img1.jpg
# Detected faces and celebrities for post1020_img2.jpg
# Detected faces and celebrities for post1020_img3.jpg
# Detected faces and celebrities for post1020_img4.jpg
# Detected faces and celebrities for post1020_img5.jpg
# Detected faces and celebrities for post1020_img6.jpg
# Detected faces and celebrities for post1011_img1.jpg
# Detected faces and celebrities for post1011_img2.jpg
# Detected faces and celebrities for post1011_img3.jpg
# Detected faces and celebrities for post1011_img4.jpg
# Detected faces and celebrities for post1010_img1.jpg
# Detected faces and celebrities for post1008_img1.jpg
# Detected faces and celebrities for post1004_img1.jpg
# Detected faces and celebrities for post1004_img2.jpg
# Detected faces and celebrities for post1001_img5.jpg
# Detected faces and celebrities for post1001_img1.jpg

# %%
with open(rekog_results_dir + f'faces_final_{username}.csv', 'w', newline = '') as csvfile:
    fieldnames = [
        'image_id',
        'face_count',
        'has_smile',
        'has_female',
        'has_male',
        'dominant_emotion',
        'emotions',
        'has_happy_emotion',
        'has_confident_emotion',
        'has_celebrity',
        'celebrity_names',
        'has_unrecognized_face'
    ]

    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for entry in face_labels:
        writer.writerow(entry)
