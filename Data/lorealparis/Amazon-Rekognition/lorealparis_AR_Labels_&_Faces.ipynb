# %% [markdown]
# <a href="https://colab.research.google.com/github/Emily-KD/PopularityPrediction/blob/main/Data/lorealparis/Amazon-Rekognition/lorealparis_AR_Labels_%26_Faces.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.37.37-py3-none-any.whl.metadata (6.7 kB)
# Collecting botocore<1.38.0,>=1.37.37 (from boto3)
#   Downloading botocore-1.37.37-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.12.0,>=0.11.0 (from boto3)
#   Downloading s3transfer-0.11.5-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.11/dist-packages (from botocore<1.38.0,>=1.37.37->boto3) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.11/dist-packages (from botocore<1.38.0,>=1.37.37->boto3) (2.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.38.0,>=1.37.37->boto3) (1.17.0)
# Downloading boto3-1.37.37-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 6.2 MB/s eta 0:00:00
# Downloading botocore-1.37.37-py3-none-any.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 103.7 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.11.5-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 7.9 MB/s eta 0:00:00
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.37.37 botocore-1.37.37 jmespath-1.0.1 s3transfer-0.11.5

# %%
import csv
import boto3
import pickle
import os
import json
import pandas as pd

# %%
ls
# Out:
# drive/  sample_data/

# %%
########### Paths
username = "lorealparis"
# Path to where your want to save the resulting labels
rekog_results_dir = f"/content/drive/Shareddrives/DS340W Project/Dataset NEW*/{username}/"

# Path to where your images are
rekog_images_dir = f"/content/drive/Shareddrives/DS340W Project/Dataset NEW*/{username}/{username}_images_2024_2025/"

# %%
# Read in your personal keys
personal_access_key = "AKIA6JKEXWET5465SAMQ"
secret_access_key = "Q3HEcBy+jO7ep4tL9It/7MEoFhlBxy9R2QpRjbWv"

# Initialize the boto client to access the Rekogniton api
client=boto3.client('rekognition','us-east-1', # or choose the best region for your work,
                                               # e.g. the location of your S3 bucket if using that method to store images
                    aws_access_key_id = personal_access_key,
                    aws_secret_access_key = secret_access_key)

# %%
# Make a list of all the images in the rekog_data_dir you created
local_images = os.listdir(rekog_images_dir)
#local_images = [str(p) for p in rekog_images_dir]

# %%
from PIL import Image
import io

def resize_if_needed(image_path, max_size=5242880):
    with open(image_path, 'rb') as f:
        img_bytes = f.read()

    if len(img_bytes) < max_size:
        return img_bytes

    # Resize the image using PIL
    with Image.open(image_path) as img:
        # Reduce resolution while maintaining aspect ratio
        img.thumbnail((1024, 1024))  # tweak if needed
        buf = io.BytesIO()
        img.save(buf, format='JPEG')
        buf.seek(0)
        return buf.read()

# %%
#### Beauty-focused label extraction
holder_labels = []

for imageFile in local_images:
    image_path = rekog_images_dir + imageFile
    try:
        image_bytes = resize_if_needed(image_path)
        response = client.detect_labels(Image={'Bytes': image_bytes})
    except Exception as e:
        print(f"❌ Skipping {imageFile}: {e}")
        continue

    print('Detected labels for ' + imageFile)

    labels = []
    temp_dict = {
        "image_id": imageFile,
        "has_makeup": False,
        "has_beauty_product": False,
        "has_logo_or_branding": False,
        "is_fashion_related": False,
        "is_beauty_scene": False,
        "has_text": False,
        "close_up": False,
        "indoors": False,
        "outdoors": False
    }

    for label in response.get('Labels', []):
        if label.get('Confidence', 0) >= 70:
            labels.append(label.get('Name'))

    # Category dictionaries
    makeup_labels = ['Makeup', 'Cosmetics', 'Lipstick', 'Eyeliner', 'Blush', 'Eyeshadow']
    product_labels = ['Cosmetics', 'Bottle', 'Container', 'Toiletry', 'Skincare', 'Cream']
    brand_labels = ['Label', 'Logo', 'Trademark', 'Packaging']
    fashion_labels = ['Clothing', 'Apparel', 'Dress', 'Fashion', 'Footwear', 'Shoes', 'Bag']
    scene_labels = ['Beauty Salon', 'Mirror', 'Vanity', 'Makeup Room']
    text_labels = ['Text', 'Advertisement', 'Poster', 'Font', 'Brochure', 'Paper']

    # Binary feature assignments
    if any(lbl in labels for lbl in makeup_labels):
        temp_dict["has_makeup"] = True
    if any(lbl in labels for lbl in product_labels):
        temp_dict["has_beauty_product"] = True
    if any(lbl in labels for lbl in brand_labels):
        temp_dict["has_logo_or_branding"] = True
    if any(lbl in labels for lbl in fashion_labels):
        temp_dict["is_fashion_related"] = True
    if any(lbl in labels for lbl in scene_labels):
        temp_dict["is_beauty_scene"] = True
    if any(lbl in labels for lbl in text_labels):
        temp_dict["has_text"] = True
    if 'Portrait' in labels:
        temp_dict["close_up"] = True
    if 'Indoors' in labels:
        temp_dict["indoors"] = True
    if 'Outdoors' in labels:
        temp_dict["outdoors"] = True

    holder_labels.append(temp_dict)
    print(labels)  # Optional log
# Out:
# Detected labels for post1121_img3.jpg
# ['Hair', 'Person', 'Adult', 'Female', 'Woman', 'Wig']
# Detected labels for post1121_img6.jpg
# ['Purple', 'Bottle', 'Cosmetics', 'Perfume', 'Lipstick', 'Lotion']
# Detected labels for post1121_img5.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Hairdresser', 'Haircut', 'Face', 'Head']
# Detected labels for post1121_img2.jpg
# ['White', 'Lamp']
# Detected labels for post1121_img4.jpg
# ['Brush', 'Device', 'Tool']
# Detected labels for post1120_img6.jpg
# ['Purple', 'Lighting', 'Urban', 'Adult', 'Female', 'Person', 'Woman', 'Male', 'Man', 'Club', 'Face', 'Head', 'Night Life']
# Detected labels for post1120_img5.jpg
# ['Purple', 'Adult', 'Female', 'Person', 'Woman', 'Face', 'Happy', 'Head', 'Smile', 'Accessories', 'Jewelry', 'Necklace', 'Clothing', 'Dress', 'Urban', 'Formal Wear', 'Photography', 'Portrait', 'Flower', 'Plant', 'Bag', 'Handbag']
# Detected labels for post1120_img4.jpg
# ['Purple', 'Face', 'Head', 'Person', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Clothing', 'Coat', 'Blonde', 'Hair', 'Accessories', 'Bag', 'Handbag']
# Detected labels for post1120_img2.jpg
# ['Purple', 'Adult', 'Female', 'Person', 'Woman', 'Urban', 'Clothing', 'Coat', 'Face', 'Head', 'Accessories', 'Jewelry', 'Necklace']
# Detected labels for post1120_img1.jpg
# ['Face', 'Happy', 'Head', 'Person', 'Smile', 'Adult', 'Female', 'Woman', 'Male', 'Man', 'Urban', 'Photobombing', 'Cup', 'Disposable Cup', 'Accessories', 'Jewelry', 'Ring', 'Electronics', 'Mobile Phone', 'Phone']
# Detected labels for post1120_img3.jpg
# ['Purple', 'Accessories', 'Sunglasses', 'Electronics', 'Phone', 'Mobile Phone', 'Adult', 'Female', 'Person', 'Woman', 'Male', 'Man', 'Clothing', 'Glove', 'Face', 'Head', 'Hat', 'Formal Wear', 'Suit', 'Cup', 'Texting', 'Jewelry', 'Necklace']
# Detected labels for post1113_img1.jpg
# ['Advertisement', 'Poster']
# Detected labels for post1112_img3.jpg
# ['Fashion', 'Adult', 'Female', 'Person', 'Woman', 'Formal Wear', 'Clothing', 'Dress', 'Face', 'Head', 'Evening Dress']
# Detected labels for post1112_img1.jpg
# ['Cosmetics', 'Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Mascara']
# Detected labels for post1112_img2.jpg
# ['Accessories', 'Earring', 'Jewelry', 'Adult', 'Female', 'Person', 'Woman', 'Head', 'Face', 'Photography', 'Portrait', 'Cosmetics', 'Lipstick']
# Detected labels for post1110_img2.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Head', 'Face', 'Photography', 'Portrait', 'Clothing', 'Coat', 'Blonde', 'Hair', 'Cosmetics', 'Lipstick', 'Lady']
# Detected labels for post1110_img3.jpg
# ['Formal Wear', 'Clothing', 'Long Sleeve', 'Sleeve', 'Adult', 'Female', 'Person', 'Woman', 'Dress', 'Suit', 'Fashion', 'Costume', 'Face', 'Head', 'Coat']
# Detected labels for post1110_img1.jpg
# ['Baby', 'Person', 'Head', 'Face', 'Skin']
# Detected labels for post1105_img1.jpg
# ['Body Part', 'Mouth', 'Person', 'Piercing', 'Face', 'Head', 'Accessories', 'Earring', 'Jewelry', 'Adult', 'Female', 'Woman', 'Cosmetics', 'Lipstick']
# Detected labels for post1105_img3.jpg
# ['Blouse', 'Clothing', 'Adult', 'Female', 'Person', 'Woman', 'Dress', 'Formal Wear', 'Evening Dress', 'Face', 'Head', 'Accessories']
# Detected labels for post1105_img2.jpg
# ['Photography', 'Head', 'Person', 'Adult', 'Female', 'Woman', 'Face', 'Portrait', 'Accessories', 'Earring', 'Jewelry', 'Cosmetics', 'Lipstick', 'Body Part', 'Neck']
# Detected labels for post1100_img1.jpg
# ['Cosmetics', 'Dynamite', 'Weapon', 'Bottle']
# Detected labels for post1097_img1.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Head', 'Face', 'Cosmetics', 'Lipstick', 'Photography', 'Portrait']
# Detected labels for post1095_img1.jpg
# ['Cosmetics', 'Can', 'Spray Can', 'Tin', 'Bottle', 'Shaker', 'Deodorant']
# Detected labels for post1094_img1.jpg
# ['Bottle', 'Cosmetics', 'Shaker', 'Lipstick']
# Detected labels for post1093_img1.jpg
# ['Cosmetics', 'Adult', 'Female', 'Person', 'Woman', 'Bottle', 'Perfume', 'Makeup', 'Face', 'Head']
# Detected labels for post1090_img1.jpg
# ['Bottle', 'Cosmetics', 'Sunscreen', 'Shaker']
# Detected labels for post1088_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1087_img1.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Bottle', 'Cosmetics', 'Perfume', 'Photography', 'Face', 'Head', 'Portrait', 'Adult', 'Male', 'Man']
# Detected labels for post1086_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1084_img2.jpg
# ['Texture']
# Detected labels for post1084_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Shampoo']
# Detected labels for post1081_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Bottle', 'Cosmetics', 'Perfume', 'Hair', 'Face', 'Head']
# Detected labels for post1079_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Hair', 'Face', 'Head', 'Curly Hair']
# Detected labels for post1077_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Lotion']
# Detected labels for post1076_img2.jpg
# ['Logo', 'Maroon', 'Electrical Device', 'Switch']
# Detected labels for post1076_img1.jpg
# ['Cosmetics', 'Lipstick', 'Head', 'Person', 'Face', 'Device', 'Screwdriver', 'Tool']
# Detected labels for post1073_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post1071_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Head', 'Face', 'Cosmetics', 'Makeup']
# Detected labels for post1070_img1.jpg
# ['Cosmetics', 'Lipstick', 'Smoke Pipe']
# Detected labels for post1069_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Head', 'Face', 'Black Hair', 'Hair', 'Cosmetics', 'Lipstick', 'Lady', 'Photography', 'Portrait']
# Detected labels for post1068_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post1067_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Cosmetics', 'Lipstick', 'Black Hair', 'Hair', 'Head', 'Clothing', 'Formal Wear', 'Suit', 'Face', 'Judge']
# Detected labels for post1066_img1.jpg
# ['Cosmetics', 'Lipstick', 'Machine', 'Wheel']
# Detected labels for post1064_img1.jpg
# ['Head', 'Person', 'Face', 'Happy', 'Smile', 'Adult', 'Female', 'Woman', 'Bottle', 'Lotion', 'Cosmetics', 'Photography', 'Portrait', 'Skin']
# Detected labels for post1062_img1.jpg
# ['Accessories', 'Sunglasses', 'Bottle', 'Cosmetics', 'Sunscreen', 'Lotion']
# Detected labels for post1060_img3.jpg
# ['Bottle', 'Lotion', 'Purple', 'Cosmetics']
# Detected labels for post1060_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Perfume', 'Shampoo', 'Purple']
# Detected labels for post1060_img2.jpg
# ['Bottle', 'Can', 'Tin', 'Lotion', 'Cosmetics', 'Purple']
# Detected labels for post1060_img4.jpg
# ['Bottle', 'Shampoo', 'Lotion', 'Cosmetics', 'Perfume']
# Detected labels for post1055_img1.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Adult', 'Female', 'Woman', 'Head', 'Face', 'Cosmetics', 'Blade', 'Razor', 'Weapon', 'Accessories', 'Earring', 'Jewelry']
# Detected labels for post1053_img1.jpg
# ['Cosmetics', 'Mascara', 'Blade', 'Razor', 'Weapon', 'Lipstick']
# Detected labels for post1052_img1.jpg
# ['Cosmetics', 'Mascara', 'Cricket', 'Cricket Bat', 'Sport', 'Gun', 'Weapon']
# Detected labels for post1050_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Clothing', 'Dress', 'Black Hair', 'Hair', 'Formal Wear', 'Face', 'Head', 'Photography', 'Portrait', 'Evening Dress']
# Detected labels for post1048_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1046_img1.jpg
# ['Face', 'Happy', 'Head', 'Person', 'Smile', 'Adult', 'Female', 'Woman', 'Photography', 'Portrait', 'Dimples', 'Laughing']
# Detected labels for post1045_img1.jpg
# ['Advertisement', 'Adult', 'Female', 'Person', 'Woman', 'Poster', 'Face', 'Head', 'Text', 'Business Card', 'Paper']
# Detected labels for post1043_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Head', 'Face', 'Happy', 'Smile', 'Chandelier', 'Lamp']
# Detected labels for post1041_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Bottle', 'Lotion', 'Advertisement', 'Face', 'Head', 'Cosmetics', 'Tape']
# Detected labels for post1032_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Perfume']
# Detected labels for post1026_img1.jpg
# ['Cosmetics', 'Lipstick', 'Sink']
# Detected labels for post1024_img1.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Bottle', 'Cosmetics', 'Perfume', 'Face', 'Head', 'Photography', 'Portrait', 'Nail']
# Detected labels for post1021_img4.jpg
# ['Logo', 'Text', 'Outdoors', 'Nature']
# Detected labels for post1021_img1.jpg
# ['Head', 'Person', 'Face', 'Adult', 'Female', 'Woman', 'Photography', 'Portrait']
# Detected labels for post1021_img3.jpg
# ['Lighting', 'Advertisement', 'Text', 'Photography', 'Outdoors', 'City', 'Publication']
# Detected labels for post1021_img2.jpg
# ['Text', 'Outdoors', 'City', 'Nature', 'Night']
# Detected labels for post1014_img1.jpg
# ['Cosmetics', 'Mascara', 'Car', 'Transportation', 'Vehicle']
# Detected labels for post1012_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Food', 'Honey']
# Detected labels for post1010_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1008_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1007_img1.jpg
# ['Advertisement', 'Poster', 'Text', 'Symbol', 'Number']
# Detected labels for post1007_img3.jpg
# ['Advertisement', 'Poster', 'Text']
# Detected labels for post1007_img2.jpg
# ['Logo', 'Text', 'Advertisement']
# Detected labels for post1005_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post1003_img1.jpg
# ['Clothing', 'Dress', 'Fashion', 'Formal Wear', 'Evening Dress', 'Advertisement', 'Adult', 'Female', 'Person', 'Woman', 'Poster', 'Gown']
# Detected labels for post1001_img1.jpg
# ['Clothing', 'Footwear', 'High Heel', 'Shoe']
# Detected labels for post999_img2.jpg
# ['Text', 'Logo']
# Detected labels for post999_img3.jpg
# ['Advertisement', 'Poster', 'Text']
# Detected labels for post999_img1.jpg
# ['Logo', 'Text', 'Advertisement']
# Detected labels for post995_img1.jpg
# ['Advertisement', 'Poster', 'Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Blonde', 'Hair']
# Detected labels for post994_img1.jpg
# ['Blonde', 'Hair', 'Person', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Accessories', 'Jewelry', 'Ring', 'Necklace']
# Detected labels for post993_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Cosmetics', 'Bottle', 'Face', 'Head']
# Detected labels for post992_img1.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Advertisement', 'Poster', 'Clothing', 'T-Shirt', 'Adult', 'Male', 'Man', 'Publication', 'Body Part', 'Finger', 'Hand']
# Detected labels for post991_img1.jpg
# ['Advertisement', 'Book', 'Publication', 'Adult', 'Female', 'Person', 'Woman', 'Gold', 'Poster', 'Treasure', 'Bride', 'Wedding', 'Face', 'Head']
# Detected labels for post990_img1.jpg
# ['Clothing', 'Coat', 'Jacket', 'Adult', 'Female', 'Person', 'Woman', 'Accessories', 'Jewelry', 'Necklace', 'Dress', 'Formal Wear', 'Hair', 'Face', 'Head', 'Fashion', 'Blonde']
# Detected labels for post986_img1.jpg
# ['Cosmetics', 'Smoke Pipe']
# Detected labels for post984_img1.jpg
# ['Cosmetics', 'Bottle', 'Perfume']
# Detected labels for post982_img3.jpg
# ['Cosmetics', 'Bottle', 'Perfume']
# Detected labels for post982_img2.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Perfume']
# Detected labels for post982_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Lotion']
# Detected labels for post979_img4.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post979_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post979_img3.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post979_img2.jpg
# ['Cosmetics', 'Lipstick', 'Smoke Pipe']
# Detected labels for post977_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Bottle', 'Cosmetics', 'Perfume', 'Photography', 'Portrait']
# Detected labels for post975_img1.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Clothing', 'Dress', 'Happy', 'Smile', 'Evening Dress', 'Formal Wear', 'Fashion', 'Hair']
# Detected labels for post971_img1.jpg
# []
# Detected labels for post970_img1.jpg
# ['Head', 'Person', 'Face', 'Photography', 'Portrait', 'Accessories', 'Earring', 'Jewelry', 'Adult', 'Female', 'Woman', 'Body Part', 'Neck', 'Clothing', 'Dress', 'Formal Wear', 'Evening Dress', 'Ring']
# Detected labels for post966_img1.jpg
# ['Cosmetics', 'Mascara']
# Detected labels for post964_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Head', 'Person', 'Face']
# Detected labels for post962_img1.jpg
# ['Bottle', 'Cosmetics', 'Shaker']
# Detected labels for post960_img1.jpg
# ['Bottle', 'Cosmetics', 'Lotion']
# Detected labels for post958_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Sunscreen', 'Lipstick', 'Shaker']
# Detected labels for post955_img1.jpg
# ['Face', 'Head', 'Person', 'Adult', 'Female', 'Woman', 'Cosmetics', 'Lipstick']
# Detected labels for post954_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics']
# Detected labels for post953_img1.jpg
# ['Clothing', 'Coat', 'Lab Coat', 'Adult', 'Female', 'Person', 'Woman', 'Male', 'Man', 'Face', 'Head']
# Detected labels for post952_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Architecture', 'Building', 'Hospital', 'Text']
# Detected labels for post951_img1.jpg
# ['Clothing', 'Coat', 'Adult', 'Female', 'Person', 'Woman', 'Lab Coat', 'Head', 'Face']
# Detected labels for post950_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post949_img1.jpg
# ['Cosmetics', 'Bottle', 'Perfume', 'Face', 'Head', 'Person', 'Photography', 'Portrait']
# Detected labels for post948_img1.jpg
# ['Smoke Pipe', 'Chandelier', 'Lamp', 'Cosmetics', 'Bottle']
# Detected labels for post947_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Purple']
# Detected labels for post945_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post944_img1.jpg
# ['Head', 'Person', 'Face', 'Adult', 'Female', 'Woman', 'Body Part', 'Finger', 'Hand', 'Cosmetics', 'Makeup', 'Lipstick']
# Detected labels for post943_img1.jpg
# ['Cosmetics', 'Bottle', 'Perfume', 'Lipstick']
# Detected labels for post941_img1.jpg
# ['Brush', 'Device', 'Tool']
# Detected labels for post938_img1.jpg
# ['Clothing', 'Dress', 'Evening Dress', 'Formal Wear', 'Blonde', 'Hair', 'Person', 'Adult', 'Female', 'Woman', 'Accessories', 'Jewelry', 'Ring', 'Face', 'Head', 'Photography', 'Portrait']
# Detected labels for post937_img1.jpg
# ['Blonde', 'Hair', 'Person', 'Clothing', 'Dress', 'Fashion', 'Formal Wear', 'Evening Dress', 'Adult', 'Female', 'Woman', 'Bride', 'Wedding', 'Face', 'Head', 'Male', 'Man', 'Bottle', 'Cosmetics', 'Perfume', 'Suit']
# Detected labels for post935_img1.jpg
# ['Head', 'Person', 'Face', 'Cosmetics', 'Bottle', 'Perfume', 'Deodorant']
# Detected labels for post935_img2.jpg
# ['Person', 'Skin', 'Face', 'Head']
# Detected labels for post934_img1.jpg
# ['Bottle', 'Advertisement', 'Cosmetics', 'Sunscreen', 'Business Card', 'Paper', 'Text']
# Detected labels for post933_img1.jpg
# ['Bottle', 'Cosmetics', 'Sunscreen', 'Tape', 'Advertisement', 'Can', 'Tin', 'Business Card', 'Paper', 'Text']
# Detected labels for post932_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Body Part', 'Finger', 'Hand', 'Bottle', 'Cosmetics', 'Perfume', 'Blonde', 'Hair', 'Accessories', 'Jewelry', 'Necklace', 'Face', 'Head', 'Photography', 'Portrait']
# Detected labels for post931_img1.jpg
# ['Bottle', 'Cosmetics', 'Lotion']
# Detected labels for post930_img1.jpg
# ['Blonde', 'Hair', 'Person', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Accessories', 'Bracelet', 'Jewelry']
# Detected labels for post929_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Lotion']
# Detected labels for post927_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Lotion', 'Tape']
# Detected labels for post922_img1.jpg
# ['City', 'Urban', 'Architecture', 'Building', 'High Rise', 'Hotel', 'Apartment Building', 'Condo', 'Housing', 'Person', 'Face', 'Head']
# Detected labels for post922_img3.jpg
# ['City', 'Urban', 'Architecture', 'Building', 'High Rise', 'Hotel', 'Apartment Building', 'Condo', 'Housing', 'Person', 'Palm Tree', 'Plant', 'Tree', 'Face', 'Head']
# Detected labels for post922_img2.jpg
# ['Person', 'Worker', 'Clothing', 'Footwear', 'Shoe', 'Helmet', 'Adult', 'Male', 'Man', 'Glove', 'Accessories', 'Bag', 'Handbag', 'Window']
# Detected labels for post922_img4.jpg
# ['City', 'Urban', 'Architecture', 'Building', 'High Rise', 'Condo', 'Housing', 'Adult', 'Female', 'Person', 'Woman', 'Apartment Building', 'Face', 'Head', 'Window']
# Detected labels for post921_img2.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Sunscreen', 'Dynamite', 'Weapon']
# Detected labels for post921_img1.jpg
# ['Furniture', 'Table', 'Coffee Table', 'Wood', 'Hardwood', 'Tabletop', 'Stained Wood', 'Adult', 'Female', 'Person', 'Woman', 'Text', 'Couch']
# Detected labels for post921_img4.jpg
# ['Nature', 'Outdoors', 'Countryside', 'Rural', 'Cosmetics']
# Detected labels for post921_img3.jpg
# ['Palm Tree', 'Plant', 'Tree', 'Summer', 'Outdoors']
# Detected labels for post919_img2.jpg
# ['Water', 'Waterfront', 'Cosmetics', 'Lipstick', 'Publication', 'Advertisement', 'Book', 'Business Card', 'Paper', 'Text']
# Detected labels for post919_img1.jpg
# ['Animal', 'Bird', 'Landmark']
# Detected labels for post919_img4.jpg
# ['Cosmetics', 'Bottle', 'Can', 'Tin']
# Detected labels for post919_img3.jpg
# ['Architecture', 'Balcony', 'Building', 'Gate', 'Horizon', 'Nature', 'Outdoors', 'Sky']
# Detected labels for post919_img5.jpg
# ['Nature', 'Outdoors', 'Sky', 'Horizon', 'Boat', 'Sailboat', 'Transportation', 'Vehicle', 'Sea', 'Water']
# Detected labels for post918_img1.jpg
# ['Brunch', 'Food', 'Beverage', 'Coffee', 'Coffee Cup', 'Cosmetics', 'Lipstick', 'Food Presentation', 'Blade', 'Razor', 'Weapon']
# Detected labels for post918_img3.jpg
# ['Handle', 'Advertisement', 'Poster']
# Detected labels for post918_img4.jpg
# ['Summer', 'Water', 'Waterfront', 'Pier', 'Port', 'Boat', 'Sailboat', 'Transportation', 'Vehicle', 'Architecture', 'Building', 'Outdoors', 'Shelter', 'Nature', 'Plant', 'Tree', 'Palm Tree', 'Sea']
# Detected labels for post918_img5.jpg
# ['Architecture', 'Balcony', 'Building', 'Text', 'Adult', 'Male', 'Man', 'Person']
# Detected labels for post918_img2.jpg
# ['Indoors', 'Interior Design', 'Floor']
# Detected labels for post905_img1.jpg
# ['Clothing', 'Hat', 'Adult', 'Female', 'Person', 'Woman', 'Glove', 'Sun Hat', 'Coat', 'Formal Wear', 'Suit', 'Face', 'Head', 'Photography', 'Portrait']
# Detected labels for post904_img1.jpg
# ['Hair', 'Person', 'Head', 'Face', 'Adult', 'Bride', 'Female', 'Wedding', 'Woman', 'Accessories', 'Diamond', 'Gemstone', 'Jewelry', 'Black Hair']
# Detected labels for post904_img2.jpg
# ['Fashion', 'Lady', 'Person', 'Camera', 'Electronics', 'Adult', 'Bride', 'Female', 'Wedding', 'Woman', 'Formal Wear', 'Photoshoot', 'Male', 'Man']
# Detected labels for post899_img2.jpg
# ['Blonde', 'Hair', 'Person', 'Accessories', 'Jewelry', 'Necklace', 'Pixie Cut']
# Detected labels for post899_img1.jpg
# ['Lady', 'Person', 'Adult', 'Female', 'Woman', 'Male', 'Man', 'Fashion', 'Face', 'Head', 'Electronics']
# Detected labels for post897_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Hair', 'Face', 'Head', 'Blue Hair']
# Detected labels for post895_img1.jpg
# ['Clothing', 'Dress', 'Evening Dress', 'Formal Wear', 'Body Part', 'Finger', 'Hand', 'Person', 'Head', 'Face', 'Adult', 'Female', 'Woman', 'Accessories', 'Jewelry', 'Necklace', 'Ring', 'Fashion']
# Detected labels for post892_img2.jpg
# ['Clothing', 'Sleeve', 'Beachwear', 'Blouse', 'Adult', 'Female', 'Person', 'Woman']
# Detected labels for post892_img1.jpg
# ['Body Part', 'Face', 'Head', 'Neck', 'Person', 'Shoulder', 'Adult', 'Female', 'Woman', 'Indoors']
# Detected labels for post892_img3.jpg
# ['Clothing', 'Sleeve', 'Beachwear', 'Swimwear', 'Blouse', 'Adult', 'Female', 'Person', 'Woman']
# Detected labels for post890_img1.jpg
# ['Clothing', 'Dress', 'Formal Wear', 'Fashion', 'Gown', 'Evening Dress', 'Adult', 'Bride', 'Female', 'Person', 'Wedding', 'Woman', 'Performer', 'Solo Performance', 'Wedding Gown', 'Face', 'Head']
# Detected labels for post890_img2.jpg
# ['Face', 'Happy', 'Head', 'Person', 'Smile', 'Dimples', 'Adult', 'Bride', 'Female', 'Wedding', 'Woman']
# Detected labels for post884_img1.jpg
# ['Accessories', 'Formal Wear', 'Tie', 'Adult', 'Male', 'Man', 'Person', 'Jewelry', 'Ring', 'Face', 'Head', 'Clothing', 'Suit', 'Black Hair', 'Hair', 'Dimples', 'Bracelet', 'Body Part', 'Finger', 'Hand']
# Detected labels for post881_img1.jpg
# ['Clothing', 'Dress', 'Fashion', 'Formal Wear', 'Adult', 'Female', 'Person', 'Woman', 'Evening Dress', 'Black Hair', 'Hair', 'Gown', 'Head', 'Face']
# Detected labels for post881_img4.jpg
# ['Adult', 'Male', 'Man', 'Person', 'Clothing', 'Formal Wear', 'Suit', 'Fashion', 'Paparazzi', 'Blazer', 'Coat', 'Jacket', 'Face', 'Head']
# Detected labels for post881_img2.jpg
# ['Head', 'Person', 'Face', 'Happy', 'Smile', 'Dimples', 'Adult', 'Bride', 'Female', 'Wedding', 'Woman', 'Body Part', 'Neck', 'Accessories', 'Jewelry', 'Necklace', 'Hair']
# Detected labels for post881_img3.jpg
# ['Clothing', 'Dress', 'Fashion', 'Formal Wear', 'Evening Dress', 'Adult', 'Female', 'Person', 'Woman', 'Head', 'Face']
# Detected labels for post874_img1.jpg
# ['Pen', 'Cosmetics', 'Lipstick']
# Detected labels for post874_img3.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post874_img2.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Lotion']
# Detected labels for post873_img1.jpg
# ['Black Hair', 'Hair', 'Person', 'Head', 'Adult', 'Female', 'Woman', 'Face', 'Happy', 'Smile', 'Photography', 'Portrait', 'Clothing', 'Coat']
# Detected labels for post873_img2.jpg
# ['Fashion', 'Adult', 'Female', 'Person', 'Woman', 'Male', 'Man', 'Clothing', 'Coat', 'Formal Wear', 'Suit', 'Face', 'Head', 'Footwear', 'Shoe', 'Accessories', 'Glasses', 'Electronics', 'Bag', 'Handbag', 'Camera', 'Jewelry', 'Necklace', 'Tie', 'Photographer']
# Detected labels for post871_img2.jpg
# ['Fashion', 'Clothing', 'Dress', 'Adult', 'Bride', 'Female', 'Person', 'Wedding', 'Woman', 'Formal Wear', 'Premiere', 'Red Carpet', 'Standing', 'Car', 'Transportation', 'Vehicle']
# Detected labels for post871_img3.jpg
# ['Fashion', 'Adult', 'Female', 'Person', 'Woman', 'Premiere', 'Red Carpet', 'Clothing', 'Dress']
# Detected labels for post871_img1.jpg
# ['Fashion', 'Premiere', 'Red Carpet', 'Adult', 'Bride', 'Female', 'Person', 'Wedding', 'Woman', 'Clothing', 'Dress', 'Formal Wear']
# Detected labels for post870_img1.jpg
# ['Black Hair', 'Hair', 'Person', 'Face', 'Happy', 'Head', 'Smile', 'Adult', 'Bride', 'Female', 'Wedding', 'Woman', 'Body Part', 'Finger', 'Hand', 'Clothing', 'Dress', 'Formal Wear', 'Neck', 'Accessories', 'Jewelry', 'Necklace']
# Detected labels for post870_img2.jpg
# ['Fashion', 'Clothing', 'Dress', 'Formal Wear', 'Adult', 'Female', 'Person', 'Woman', 'Bride', 'Wedding', 'Male', 'Man', 'Accessories', 'Jewelry', 'Necklace', 'Ring', 'Glasses', 'Footwear', 'Shoe', 'Camera', 'Electronics', 'Premiere', 'Bag', 'Handbag', 'Face', 'Head', 'Gown']
# Detected labels for post868_img3.jpg
# ['Clothing', 'Dress', 'Evening Dress', 'Formal Wear', 'Adult', 'Female', 'Person', 'Woman', 'Body Part', 'Finger', 'Hand', 'Face', 'Happy', 'Head', 'Smile', 'Photography', 'Portrait', 'Fashion', 'Accessories', 'Jewelry', 'Necklace']
# Detected labels for post868_img2.jpg
# ['Clothing', 'Dress', 'Evening Dress', 'Formal Wear', 'Handrail', 'Adult', 'Bride', 'Female', 'Person', 'Wedding', 'Woman', 'Fashion', 'Body Part', 'Finger', 'Hand', 'Lingerie', 'Underwear', 'Face', 'Head']
# Detected labels for post868_img1.jpg
# ['Clothing', 'Dress', 'Evening Dress', 'Formal Wear', 'Fashion', 'Gown', 'Adult', 'Bride', 'Female', 'Person', 'Wedding', 'Woman', 'Accessories', 'Jewelry', 'Necklace', 'Flower', 'Flower Arrangement', 'Flower Bouquet', 'Plant', 'Face', 'Head']
# Detected labels for post868_img4.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Clothing', 'Dress', 'Formal Wear', 'Evening Dress', 'Long Sleeve', 'Sleeve', 'Head', 'Face', 'Happy', 'Smile', 'Black Hair', 'Hair', 'Lady']
# Detected labels for post867_img2.jpg
# ['Adult', 'Bride', 'Female', 'Person', 'Wedding', 'Woman', 'Hair', 'Face', 'Head', 'Bun (Hairstyle)']
# Detected labels for post867_img1.jpg
# ['Fashion', 'Wristwatch', 'Adult', 'Bride', 'Female', 'Person', 'Wedding', 'Woman', 'Male', 'Man', 'Camera', 'Electronics', 'Clothing', 'Footwear', 'Shoe', 'Premiere', 'Face', 'Head', 'Accessories', 'Bag', 'Handbag', 'Red Carpet', 'Photographer']
# Detected labels for post859_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Accessories', 'Jewelry', 'Ring', 'Necklace', 'Head', 'Face']
# Detected labels for post858_img1.jpg
# ['Clothing', 'Dress', 'Face', 'Happy', 'Head', 'Person', 'Smile', 'Formal Wear', 'Evening Dress', 'Adult', 'Female', 'Woman', 'Beachwear', 'Fashion']
# Detected labels for post857_img1.jpg
# ['Clothing', 'Dress', 'Formal Wear', 'Fashion', 'Gown', 'Wedding', 'Wedding Gown', 'Evening Dress', 'Long Sleeve', 'Sleeve', 'Adult', 'Bride', 'Female', 'Person', 'Woman', 'Blouse', 'Blonde', 'Hair', 'Knitwear', 'Sweater', 'Face', 'Head']
# Detected labels for post856_img1.jpg
# ['Fashion', 'Adult', 'Female', 'Person', 'Woman', 'Black Hair', 'Hair', 'Head', 'Premiere', 'Face', 'Clothing', 'Footwear', 'High Heel', 'Shoe', 'Standing']
# Detected labels for post855_img1.jpg
# ['Clothing', 'Dress', 'Adult', 'Female', 'Person', 'Woman', 'Evening Dress', 'Formal Wear', 'Face', 'Head', 'Happy', 'Smile', 'Footwear', 'Shoe', 'Coat', 'Beachwear']
# Detected labels for post854_img1.jpg
# ['Fashion', 'Adult', 'Female', 'Person', 'Woman', 'Formal Wear', 'Blonde', 'Hair', 'Premiere', 'Clothing', 'Coat']
# Detected labels for post853_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Lady', 'Clothing', 'Long Sleeve', 'Sleeve', 'Face', 'Head', 'Photography', 'Portrait', 'Dress', 'Formal Wear', 'Happy', 'Smile']
# Detected labels for post852_img2.jpg
# ['Fashion', 'Clothing', 'Dress', 'Formal Wear', 'Adult', 'Female', 'Person', 'Woman', 'Evening Dress', 'Glove', 'Gown', 'Face', 'Head', 'Black Hair', 'Hair']
# Detected labels for post852_img1.jpg
# ['Fashion', 'Adult', 'Female', 'Person', 'Woman', 'Formal Wear', 'Clothing', 'Dress', 'Premiere', 'Face', 'Head', 'Accessories', 'Jewelry', 'Ring']
# Detected labels for post850_img1.jpg
# ['Fashion', 'Adult', 'Male', 'Man', 'Person', 'Female', 'Woman', 'Clothing', 'Footwear', 'Shoe', 'Electronics', 'Formal Wear', 'Suit', 'Camera', 'Accessories', 'Glasses', 'Face', 'Head']
# Detected labels for post849_img2.jpg
# ['Fashion', 'Adult', 'Female', 'Person', 'Woman', 'Bride', 'Wedding', 'Male', 'Man', 'Clothing', 'Formal Wear', 'Suit', 'Face', 'Head', 'Electronics', 'Footwear', 'Shoe', 'Camera']
# Detected labels for post849_img1.jpg
# ['Blonde', 'Hair', 'Person', 'Fashion', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Clothing', 'Formal Wear', 'Suit']
# Detected labels for post848_img1.jpg
# ['Black Hair', 'Hair', 'Person', 'Head', 'Face', 'Accessories', 'Jewelry', 'Necklace', 'Adult', 'Bride', 'Female', 'Wedding', 'Woman', 'Clothing', 'Dress']
# Detected labels for post840_img1.jpg
# ['Fashion', 'Adult', 'Bride', 'Female', 'Person', 'Wedding', 'Woman', 'Head', 'Face', 'Male', 'Man', 'Clothing', 'Formal Wear', 'Suit']
# Detected labels for post840_img2.jpg
# ['Face', 'Happy', 'Head', 'Person', 'Smile', 'Adult', 'Female', 'Woman', 'Photography', 'Portrait', 'Accessories', 'Jewelry', 'Necklace']
# Detected labels for post838_img1.jpg
# ['Cosmetics', 'Brush', 'Device', 'Tool', 'Toothbrush', 'Mascara', 'Pen', 'Bottle', 'Perfume']
# Detected labels for post838_img3.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post838_img2.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Shaker']
# Detected labels for post837_img1.jpg
# ['Body Part', 'Face', 'Head', 'Neck', 'Person', 'Adult', 'Female', 'Woman', 'Hair', 'Accessories', 'Earring', 'Jewelry', 'Bun (Hairstyle)']
# Detected labels for post836_img1.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Fashion', 'Adult', 'Female', 'Woman', 'Happy', 'Smile', 'Body Part', 'Finger', 'Hand']
# Detected labels for post836_img2.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Photography', 'Portrait']
# Detected labels for post836_img3.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Photography', 'Photographer', 'Adult', 'Female', 'Woman', 'Camera', 'Electronics', 'Face', 'Head', 'Male', 'Man', 'Wristwatch', 'Portrait']
# Detected labels for post836_img4.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Male', 'Man']
# Detected labels for post834_img3.jpg
# ['Face', 'Happy', 'Head', 'Person', 'Smile', 'Adult', 'Male', 'Man', 'Handrail']
# Detected labels for post834_img1.jpg
# ['Lady', 'Person', 'Adult', 'Female', 'Woman', 'Accessories', 'Jewelry', 'Necklace', 'Face', 'Head', 'Ring']
# Detected labels for post834_img2.jpg
# ['Architecture', 'Balcony', 'Building', 'Clothing', 'Dress', 'Handrail', 'Adult', 'Female', 'Person', 'Woman', 'Formal Wear']
# Detected labels for post834_img4.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Clothing', 'Dress', 'Formal Wear', 'Architecture', 'Balcony', 'Building', 'Lady', 'Handrail', 'Face', 'Head']
# Detected labels for post825_img1.jpg
# ['Fashion', 'Clothing', 'Dress', 'Adult', 'Female', 'Person', 'Woman', 'Formal Wear', 'Bride', 'Wedding', 'Accessories', 'Jewelry', 'Necklace', 'Footwear', 'High Heel', 'Shoe', 'Gown', 'Face', 'Head', 'Premiere']
# Detected labels for post822_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Lotion']
# Detected labels for post820_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Flower', 'Plant', 'Petal']
# Detected labels for post818_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Tape', 'Lotion']
# Detected labels for post817_img1.jpg
# ['Head', 'Person', 'Face', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Cosmetics', 'Lipstick']
# Detected labels for post815_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Head', 'Face', 'Skin', 'Cosmetics', 'Lipstick', 'Makeup']
# Detected labels for post814_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Tape', 'Can', 'Tin']
# Detected labels for post811_img1.jpg
# ['Face', 'Happy', 'Head', 'Person', 'Smile', 'Adult', 'Female', 'Woman', 'Advertisement', 'Poster', 'Photography', 'Portrait', 'Text']
# Detected labels for post810_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Body Part', 'Finger', 'Hand', 'Person']
# Detected labels for post807_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Face', 'Happy', 'Head', 'Smile', 'Hair', 'Brown Hair']
# Detected labels for post806_img1.jpg
# ['Bottle', 'Lotion', 'Advertisement', 'Adult', 'Bride', 'Female', 'Person', 'Wedding', 'Woman', 'Face', 'Head', 'Business Card', 'Paper', 'Text']
# Detected labels for post805_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Hair', 'Face', 'Head', 'Black Hair']
# Detected labels for post804_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Perfume']
# Detected labels for post802_img1.jpg
# ['Cosmetics', 'Bottle', 'Perfume']
# Detected labels for post798_img2.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post798_img3.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Perfume']
# Detected labels for post798_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Lotion']
# Detected labels for post795_img1.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Clothing', 'Dress', 'Fashion', 'Hair', 'Gun', 'Weapon', 'Formal Wear', 'Hairdresser']
# Detected labels for post790_img1.jpg
# ['Bottle', 'Cricket', 'Cricket Bat', 'Sport', 'Cosmetics']
# Detected labels for post790_img2.jpg
# ['Chart', 'Diagram', 'Plan', 'Plot', 'Text']
# Detected labels for post789_img2.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Hair', 'Art', 'Collage', 'Ponytail', 'Black Hair']
# Detected labels for post789_img1.jpg
# ['Advertisement', 'Poster', 'Paper', 'Text', 'Business Card']
# Detected labels for post784_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Publication', 'Face', 'Head', 'Photography', 'Portrait', 'Book', 'Accessories', 'Earring', 'Jewelry', 'Advertisement', 'Business Card', 'Paper', 'Text', 'Clothing', 'Coat', 'Cosmetics', 'Lipstick']
# Detected labels for post783_img1.jpg
# ['Advertisement', 'Poster', 'Publication', 'Book', 'Face', 'Head', 'Person', 'Adult', 'Female', 'Woman', 'Box', 'Text']
# Detected labels for post783_img5.jpg
# ['Light', 'Art', 'Porcelain', 'Pottery']
# Detected labels for post783_img6.jpg
# ['Person', 'Skin', 'Contact Lens', 'Face', 'Head']
# Detected labels for post783_img4.jpg
# ['Pen', 'Brush', 'Device', 'Tool']
# Detected labels for post783_img3.jpg
# ['Bottle', 'Shaker']
# Detected labels for post783_img2.jpg
# ['Bottle', 'Lotion', 'Electrical Device', 'Microphone']
# Detected labels for post779_img1.jpg
# ['Adult', 'Bride', 'Female', 'Person', 'Wedding', 'Woman', 'Face', 'Head', 'Bottle']
# Detected labels for post776_img1.jpg
# ['Bottle', 'Face', 'Head', 'Person', 'Photography', 'Portrait', 'Adult', 'Male', 'Man', 'Can', 'Tin', 'Lotion', 'Cosmetics']
# Detected labels for post774_img1.jpg
# ['Can', 'Tin', 'Head', 'Person', 'Face', 'Bottle']
# Detected labels for post773_img1.jpg
# ['Bottle', 'Shampoo', 'Cosmetics', 'Perfume']
# Detected labels for post771_img1.jpg
# ['Face', 'Head', 'Person', 'Tape', 'Cosmetics', 'Makeup', 'Bottle', 'Perfume']
# Detected labels for post765_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Lipstick', 'Lotion']
# Detected labels for post762_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Lipstick', 'Balloon']
# Detected labels for post760_img1.jpg
# ['Blonde', 'Hair', 'Person', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Accessories', 'Jewelry', 'Ring', 'Necklace']
# Detected labels for post759_img1.jpg
# ['Advertisement', 'Poster', 'Adult', 'Female', 'Person', 'Woman', 'Blonde', 'Hair', 'Publication', 'Face', 'Head']
# Detected labels for post758_img2.jpg
# ['Clothing', 'Glove', 'Hairdresser', 'Person', 'Adult', 'Female', 'Woman', 'Male', 'Man', 'Face', 'Head', 'Body Part', 'Finger', 'Hand', 'Haircut']
# Detected labels for post758_img1.jpg
# ['Blonde', 'Hair', 'Person', 'Adult', 'Female', 'Woman', 'Male', 'Man', 'Face', 'Head', 'Accessories', 'Jewelry', 'Necklace', 'Hairdresser', 'Photography', 'Portrait']
# Detected labels for post757_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Bottle', 'Cosmetics', 'Perfume', 'Shaker', 'Face', 'Head', 'Business Card', 'Paper', 'Text']
# Detected labels for post756_img1.jpg
# ['Blonde', 'Hair', 'Person', 'Adult', 'Female', 'Woman', 'Face', 'Head']
# Detected labels for post755_img1.jpg
# ['Advertisement', 'Poster', 'Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Publication']
# Detected labels for post750_img1.jpg
# ['Cosmetics', 'Mascara', 'White Board', 'Machine', 'Wheel']
# Detected labels for post749_img1.jpg
# ['Cosmetics', 'Lipstick', 'Makeup']
# Detected labels for post748_img1.jpg
# ['Head', 'Person', 'Face', 'Adult', 'Male', 'Man', 'Photography', 'Portrait', 'Cosmetics', 'Clothing', 'Coat', 'Makeup', 'Brush', 'Device', 'Tool']
# Detected labels for post747_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post745_img1.jpg
# ['Bottle', 'Cosmetics', 'Sunscreen', 'Can', 'Tin', 'Perfume']
# Detected labels for post743_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Sunscreen', 'Shaker', 'Dynamite', 'Weapon']
# Detected labels for post739_img1.jpg
# ['Cosmetics', 'Lipstick', 'Car', 'Transportation', 'Vehicle']
# Detected labels for post738_img1.jpg
# ['Cosmetics', 'Lipstick', 'Head', 'Person', 'Face', 'Makeup']
# Detected labels for post737_img1.jpg
# ['Cosmetics', 'Lipstick', 'Dynamite', 'Weapon']
# Detected labels for post736_img1.jpg
# ['Head', 'Person', 'Face', 'Adult', 'Female', 'Woman', 'Photography', 'Portrait', 'Happy', 'Smile', 'Body Part', 'Neck', 'Skin']
# Detected labels for post735_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Cricket', 'Cricket Bat', 'Sport']
# Detected labels for post734_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Lipstick']
# Detected labels for post733_img1.jpg
# ['Cosmetics', 'Lipstick', 'Smoke Pipe', 'Bottle']
# Detected labels for post732_img1.jpg
# ['Cosmetics', 'Lipstick', 'Dynamite', 'Weapon']
# Detected labels for post731_img1.jpg
# ['Blonde', 'Hair', 'Person', 'Adult', 'Female', 'Woman', 'Face', 'Head']
# Detected labels for post730_img1.jpg
# ['Cosmetics', 'Lipstick', 'Body Part', 'Mouth', 'Person']
# Detected labels for post730_img2.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post728_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle']
# Detected labels for post724_img1.jpg
# ['Advertisement', 'Poster', 'Text']
# Detected labels for post722_img3.jpg
# ['Clothing', 'Footwear', 'High Heel', 'Shoe']
# Detected labels for post722_img5.jpg
# ['Advertisement', 'Poster', 'Text']
# Detected labels for post722_img2.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post722_img4.jpg
# ['Logo', 'Text', 'Advertisement']
# Detected labels for post722_img1.jpg
# ['Clothing', 'Dress', 'Fashion', 'Formal Wear', 'Evening Dress', 'Advertisement', 'Adult', 'Female', 'Person', 'Woman', 'Gown', 'Poster']
# Detected labels for post721_img1.jpg
# ['Head', 'Person', 'Face', 'Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post720_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Perfume']
# Detected labels for post718_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Perfume']
# Detected labels for post716_img1.jpg
# ['Cosmetics', 'Bottle', 'Perfume']
# Detected labels for post712_img1.jpg
# ['Adult', 'Male', 'Man', 'Person', 'Clothing', 'Shorts', 'Fitness', 'Gym', 'Sport', 'Working Out', 'Footwear', 'Shoe', 'Battling Ropes', 'Face', 'Head']
# Detected labels for post711_img1.jpg
# ['Appliance', 'Blow Dryer', 'Device', 'Electrical Device', 'Bottle']
# Detected labels for post710_img1.jpg
# ['Adult', 'Male', 'Man', 'Person', 'Skin', 'Arm', 'Body Part', 'Face', 'Head']
# Detected labels for post709_img1.jpg
# ['Tape', 'Smoke']
# Detected labels for post708_img1.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Adult', 'Male', 'Man', 'Advertisement', 'Face', 'Head']
# Detected labels for post707_img1.jpg
# ['Bottle', 'Cosmetics', 'Sunscreen', 'Advertisement', 'Perfume']
# Detected labels for post702_img1.jpg
# ['Cosmetics', 'Mascara']
# Detected labels for post697_img1.jpg
# ['Cosmetics', 'Lipstick', 'Head', 'Person', 'Face', 'Makeup']
# Detected labels for post696_img1.jpg
# ['Cosmetics', 'Mascara']
# Detected labels for post694_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Head', 'Face', 'Machine', 'Screw']
# Detected labels for post692_img1.jpg
# ['Cosmetics', 'Bottle', 'Perfume', 'Face', 'Head', 'Person', 'Lipstick', 'Makeup']
# Detected labels for post687_img1.jpg
# ['Car', 'Transportation', 'Vehicle', 'Cosmetics']
# Detected labels for post685_img1.jpg
# ['Brown Hair', 'Hair', 'Person', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Photography', 'Portrait']
# Detected labels for post684_img1.jpg
# ['Bottle', 'Lotion', 'Beverage', 'Milk', 'Cosmetics']
# Detected labels for post682_img1.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Advertisement']
# Detected labels for post680_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Advertisement', 'Bottle', 'Face', 'Head']
# Detected labels for post679_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Perfume']
# Detected labels for post677_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Deodorant']
# Detected labels for post675_img1.jpg
# ['Cosmetics', 'Mascara', 'Bottle', 'Shaker']
# Detected labels for post673_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post671_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle']
# Detected labels for post670_img1.jpg
# ['Cosmetics', 'Bottle', 'Lotion', 'Perfume', 'Head', 'Person', 'Face']
# Detected labels for post669_img1.jpg
# ['Bottle', 'Cosmetics', 'Sunscreen', 'Lotion', 'Perfume', 'Tape']
# Detected labels for post668_img1.jpg
# ['Head', 'Person', 'Face', 'Adult', 'Female', 'Woman', 'Skin', 'Body Part', 'Neck', 'Photography', 'Portrait']
# Detected labels for post667_img1.jpg
# ['Bottle', 'Cosmetics', 'Sunscreen', 'Lotion', 'Perfume']
# Detected labels for post665_img1.jpg
# ['Bottle', 'Cosmetics', 'Lipstick']
# Detected labels for post664_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Body Part', 'Finger', 'Hand', 'Head', 'Face', 'Bottle', 'Cosmetics', 'Perfume', 'Photography']
# Detected labels for post663_img1.jpg
# ['Bottle', 'Car', 'Transportation', 'Vehicle', 'Dynamite', 'Weapon', 'Cosmetics']
# Detected labels for post659_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Dynamite', 'Weapon', 'Perfume', 'Shaker']
# Detected labels for post658_img2.jpg
# ['Advertisement', 'QR Code', 'Adult', 'Female', 'Person', 'Woman', 'Billboard']
# Detected labels for post658_img1.jpg
# ['Adult', 'Male', 'Man', 'Person', 'QR Code']
# Detected labels for post657_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Hair', 'Brown Hair', 'Face', 'Head', 'Photography', 'Portrait']
# Detected labels for post656_img1.jpg
# ['Cosmetics', 'Blade', 'Razor', 'Weapon']
# Detected labels for post652_img1.jpg
# ['Head', 'Person', 'Face', 'Photography', 'Portrait', 'Body Part', 'Finger', 'Hand', 'Cosmetics', 'Bottle', 'Perfume']
# Detected labels for post651_img1.jpg
# ['Bottle', 'Cosmetics', 'Can', 'Tin']
# Detected labels for post650_img1.jpg
# ['Cosmetics', 'Head', 'Person', 'Face', 'Bottle', 'Perfume']
# Detected labels for post649_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Perfume', 'Sunscreen']
# Detected labels for post647_img1.jpg
# ['Bottle', 'Cosmetics', 'Lipstick', 'Perfume', 'Lotion']
# Detected labels for post646_img1.jpg
# ['Cosmetics', 'Lipstick', 'Pen']
# Detected labels for post644_img1.jpg
# ['Cosmetics', 'Lipstick', 'Pen']
# Detected labels for post642_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Lipstick', 'Perfume']
# Detected labels for post640_img1.jpg
# ['Cosmetics', 'Adult', 'Female', 'Person', 'Woman', 'Bottle', 'Perfume', 'Makeup']
# Detected labels for post639_img1.jpg
# ['Can', 'Spray Can', 'Tin', 'Cosmetics', 'Dynamite', 'Weapon', 'Deodorant']
# Detected labels for post637_img1.jpg
# ['Can', 'Tin']
# Detected labels for post636_img1.jpg
# ['Adult', 'Male', 'Man', 'Person', 'Ball', 'Football', 'Soccer', 'Soccer Ball', 'Sport', 'Clothing', 'Footwear', 'Shoe', 'Shorts', 'Sphere']
# Detected labels for post635_img1.jpg
# ['Cosmetics', 'Bottle', 'Advertisement', 'Computer Hardware', 'Electronics', 'Hardware', 'Sunscreen', 'Mailbox']
# Detected labels for post634_img1.jpg
# ['Adult', 'Male', 'Man', 'Person', 'Ball', 'Rugby', 'Rugby Ball', 'Sport', 'Face', 'Head']
# Detected labels for post633_img1.jpg
# ['Bottle', 'Advertisement', 'Cosmetics', 'Sunscreen', 'Food', 'Ketchup']
# Detected labels for post632_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Sunscreen', 'Advertisement']
# Detected labels for post630_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Perfume']
# Detected labels for post628_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Perfume']
# Detected labels for post626_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post625_img1.jpg
# ['Advertisement', 'Poster', 'Text']
# Detected labels for post622_img1.jpg
# ['Advertisement', 'Poster', 'Text', 'Book', 'Publication']
# Detected labels for post621_img1.jpg
# ['Logo', 'Text', 'Advertisement']
# Detected labels for post619_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post616_img1.jpg
# ['Clothing', 'Long Sleeve', 'Sleeve', 'Adult', 'Female', 'Person', 'Woman', 'Face', 'Happy', 'Head', 'Smile', 'Dress', 'Fashion', 'Formal Wear', 'Photography', 'Portrait']
# Detected labels for post613_img1.jpg
# ['Cosmetics', 'Deodorant', 'Can', 'Tin']
# Detected labels for post611_img1.jpg
# ['Bottle', 'Cosmetics', 'Shaker', 'Water Bottle']
# Detected labels for post610_img1.jpg
# ['Head', 'Person', 'Face', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Happy', 'Smile', 'Cosmetics', 'Lipstick', 'Body Part', 'Neck', 'Black Hair', 'Hair']
# Detected labels for post610_img2.jpg
# ['Head', 'Person', 'Face', 'Adult', 'Female', 'Woman', 'Surprised', 'Angry', 'Cosmetics', 'Lipstick']
# Detected labels for post609_img1.jpg
# ['Bottle', 'Cosmetics', 'Can', 'Tin', 'Dynamite', 'Weapon']
# Detected labels for post608_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Cosmetics', 'Head', 'Face', 'Bottle', 'Perfume', 'Makeup']
# Detected labels for post606_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Clothing', 'Coat', 'Bottle', 'Cosmetics', 'Perfume', 'Head', 'Face', 'Accessories', 'Jewelry', 'Necklace']
# Detected labels for post604_img1.jpg
# ['Toothpaste', 'Cosmetics']
# Detected labels for post602_img1.jpg
# ['Bottle', 'Cosmetics', 'Shaker']
# Detected labels for post601_img1.jpg
# ['Head', 'Person', 'Face', 'Happy', 'Smile', 'Dimples', 'Adult', 'Female', 'Woman', 'Cosmetics', 'Lipstick']
# Detected labels for post600_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Lotion']
# Detected labels for post598_img1.jpg
# ['Bottle', 'Cosmetics', 'Lotion']
# Detected labels for post597_img1.jpg
# ['Face', 'Happy', 'Head', 'Person', 'Smile', 'Adult', 'Female', 'Woman', 'Clothing', 'Coat', 'Black Hair', 'Hair']
# Detected labels for post596_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Cosmetics', 'Lipstick', 'Head', 'Face', 'Skin']
# Detected labels for post594_img1.jpg
# ['Cosmetics', 'Lipstick', 'Red']
# Detected labels for post592_img1.jpg
# ['Bottle', 'Lotion', 'Foam', 'Cosmetics']
# Detected labels for post590_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Perfume']
# Detected labels for post588_img1.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Bottle', 'Lotion', 'Cosmetics', 'Cup', 'Disposable Cup', 'Nail']
# Detected labels for post587_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics']
# Detected labels for post586_img2.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Cosmetics', 'Lipstick']
# Detected labels for post586_img1.jpg
# ['Cosmetics', 'Lipstick', 'Head', 'Person', 'Face', 'Makeup']
# Detected labels for post585_img1.jpg
# ['Cosmetics', 'Lipstick', 'Dynamite', 'Weapon', 'Can', 'Tin']
# Detected labels for post583_img1.jpg
# ['Cooking', 'Cooking Batter', 'Food']
# Detected labels for post581_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post580_img1.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Head', 'Face', 'Cosmetics', 'Lipstick', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman']
# Detected labels for post579_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics']
# Detected labels for post578_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post575_img1.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Adult', 'Female', 'Woman', 'Bottle', 'Cosmetics', 'Perfume', 'Face', 'Head', 'Photography', 'Portrait', 'Black Hair', 'Hair']
# Detected labels for post573_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post572_img1.jpg
# ['Cosmetics', 'Adult', 'Female', 'Person', 'Woman', 'Makeup', 'Face', 'Head']
# Detected labels for post572_img2.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post572_img3.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Smoke Pipe']
# Detected labels for post571_img1.jpg
# ['Smoke Pipe', 'Chandelier', 'Lamp', 'Cosmetics', 'Bottle']
# Detected labels for post568_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Face', 'Head', 'Person']
# Detected labels for post567_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post565_img1.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Clothing', 'Glove', 'Skin', 'Adult', 'Female', 'Woman', 'Happy', 'Smile', 'Body Part', 'Finger', 'Hand']
# Detected labels for post561_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Head', 'Face', 'Photography', 'Portrait', 'Bottle', 'Cosmetics', 'Perfume', 'Body Part', 'Finger', 'Hand']
# Detected labels for post560_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Head', 'Face', 'Cosmetics', 'Photography', 'Portrait']
# Detected labels for post557_img1.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Body Part', 'Finger', 'Hand', 'Bottle', 'Cosmetics', 'Perfume', 'Happy', 'Smile', 'Student']
# Detected labels for post556_img1.jpg
# ['Face', 'Head', 'Person', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Body Part', 'Neck', 'Black Hair', 'Hair']
# Detected labels for post556_img2.jpg
# ['Black Hair', 'Hair', 'Person', 'Face', 'Head', 'Photography', 'Portrait', 'Bottle', 'Shaker', 'Body Part', 'Finger', 'Hand', 'Cosmetics']
# Detected labels for post556_img3.jpg
# ['Head', 'Person', 'Face', 'Photography', 'Portrait', 'Body Part', 'Neck', 'Adult', 'Female', 'Woman', 'Hair']
# Detected labels for post554_img1.jpg
# ['Electrical Device', 'Fuse']
# Detected labels for post552_img1.jpg
# ['Cosmetics', 'Tin', 'Tape']
# Detected labels for post551_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume']
# Detected labels for post550_img1.jpg
# ['Cosmetics', 'Lipstick', 'Makeup']
# Detected labels for post549_img1.jpg
# ['Cosmetics', 'Lipstick', 'Car', 'Transportation', 'Vehicle', 'Electronics', 'Speaker']
# Detected labels for post548_img1.jpg
# ['Brick', 'Cosmetics', 'Lipstick', 'Weapon']
# Detected labels for post547_img2.jpg
# ['Body Part', 'Mouth', 'Person', 'Baby', 'Face', 'Head']
# Detected labels for post547_img1.jpg
# ['Body Part', 'Mouth', 'Person', 'Cosmetics', 'Lipstick']
# Detected labels for post544_img1.jpg
# ['Head', 'Person', 'Face', 'Cosmetics', 'Lipstick', 'Photography']
# Detected labels for post543_img1.jpg
# ...
# Detected labels for post1271_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle']
# Detected labels for post1270_img1.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Bottle', 'Cosmetics', 'Perfume', 'Head', 'Face', 'Photography']
# Detected labels for post1267_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Sunscreen', 'Body Part', 'Finger', 'Hand', 'Person']
# Detected labels for post1264_img1.jpg
# ['Bottle', 'Cosmetics', 'Sunscreen']
# Detected labels for post1262_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1261_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Lipstick']
# Detected labels for post1260_img1.jpg
# ['Cosmetics', 'Bottle', 'Perfume', 'Medication', 'Pill', 'Nail Polish']
# Detected labels for post1259_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1257_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1256_img1.jpg
# ['Accessories', 'Bag', 'Handbag', 'Can', 'Tin', 'Cup', 'Cosmetics']
# Detected labels for post1254_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Electronics', 'Phone', 'Mobile Phone', 'Head', 'Face', 'Happy', 'Smile', 'Indoors', 'Restaurant', 'Bottle', 'Cosmetics', 'Perfume', 'Cup']
# Detected labels for post1253_img1.jpg
# ['Food', 'Food Presentation', 'Tape', 'Can', 'Tin', 'Plate']
# Detected labels for post1251_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Head', 'Face', 'Cosmetics', 'Can', 'Tin']
# Detected labels for post1249_img1.jpg
# ['Accessories', 'Earring', 'Jewelry', 'Face', 'Head', 'Person', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Body Part', 'Neck']
# Detected labels for post1238_img1.jpg
# ['Cosmetics', 'Car', 'Transportation', 'Vehicle', 'Mascara']
# Detected labels for post1237_img1.jpg
# ['Head', 'Person', 'Face', 'Accessories', 'Earring', 'Jewelry', 'Adult', 'Female', 'Woman', 'Skin', 'Photography', 'Portrait', 'Happy', 'Smile']
# Detected labels for post1234_img1.jpg
# ['Bottle', 'Face', 'Head', 'Person', 'Cosmetics', 'Perfume', 'Photography', 'Portrait']
# Detected labels for post1233_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Perfume', 'Shampoo']
# Detected labels for post1232_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1230_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1229_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Head', 'Face', 'Skin', 'Cosmetics']
# Detected labels for post1228_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1227_img1.jpg
# ['Cosmetics', 'Bottle', 'Perfume', 'Nail Polish', 'Face', 'Head', 'Person']
# Detected labels for post1226_img1.jpg
# ['Bottle', 'Cup']
# Detected labels for post1224_img1.jpg
# ['Head', 'Person', 'Face', 'Blonde', 'Hair', 'Photography', 'Portrait', 'Adult', 'Female', 'Woman', 'Accessories', 'Bracelet', 'Jewelry']
# Detected labels for post1222_img1.jpg
# ['Blonde', 'Hair', 'Person', 'Adult', 'Female', 'Woman', 'Accessories', 'Jewelry', 'Necklace', 'Face', 'Head']
# Detected labels for post1221_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Lipstick', 'Perfume']
# Detected labels for post1220_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1218_img1.jpg
# ['Bottle']
# Detected labels for post1217_img1.jpg
# ['Person', 'Skin', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Cosmetics', 'Lipstick']
# Detected labels for post1215_img1.jpg
# ['Person', 'Skin', 'Adult', 'Female', 'Woman', 'Head', 'Face']
# Detected labels for post1210_img2.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1210_img3.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Perfume']
# Detected labels for post1210_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1205_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Lipstick', 'Furniture']
# Detected labels for post1203_img1.jpg
# ['Cosmetics', 'Bottle', 'Perfume', 'Lipstick']
# Detected labels for post1201_img1.jpg
# ['Cosmetics', 'Bottle', 'Perfume', 'Lipstick']
# Detected labels for post1197_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Perfume']
# Detected labels for post1196_img1.jpg
# ['Head', 'Person', 'Face', 'Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1193_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Lotion']
# Detected labels for post1191_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Head', 'Face', 'Cosmetics', 'Lipstick', 'Body Part', 'Hand', 'Game']
# Detected labels for post1188_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1187_img1.jpg
# ['Chopsticks', 'Food']
# Detected labels for post1184_img1.jpg
# ['Face', 'Happy', 'Head', 'Person', 'Smile', 'Adult', 'Female', 'Woman', 'Photography', 'Portrait', 'Body Part', 'Finger', 'Hand', 'Hardwood', 'Wood', 'Sitting', 'Advertisement', 'Publication', 'Floor', 'Flooring']
# Detected labels for post1184_img2.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Photography', 'Portrait', 'Happy', 'Smile', 'Clothing', 'Shirt', 'Body Part', 'Neck']
# Detected labels for post1184_img3.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Photography', 'Portrait', 'Happy', 'Smile', 'Clothing', 'Shirt', 'Long Sleeve', 'Sleeve', 'Body Part', 'Neck', 'Blouse', 'Accessories']
# Detected labels for post1182_img1.jpg
# ['Advertisement', 'Poster', 'Adult', 'Female', 'Person', 'Woman', 'Child', 'Girl', 'Face', 'Head']
# Detected labels for post1181_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Hair', 'Face', 'Head']
# Detected labels for post1179_img1.jpg
# ['Cosmetics', 'Can', 'Tin', 'Tape', 'Bottle', 'Lotion']
# Detected labels for post1178_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Perfume']
# Detected labels for post1173_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Bottle', 'Cosmetics', 'Perfume', 'Face', 'Head', 'Clothing', 'Coat', 'Formal Wear', 'Suit']
# Detected labels for post1172_img1.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post1171_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Cosmetics', 'Makeup', 'Brush', 'Device', 'Tool', 'Toothbrush', 'Face', 'Head']
# Detected labels for post1168_img1.jpg
# ['Person', 'Skin', 'Head', 'Face', 'Cosmetics', 'Lipstick', 'Adult', 'Female', 'Woman']
# Detected labels for post1167_img1.jpg
# ['Cosmetics', 'Lipstick', 'Can', 'Tin', 'Bottle', 'Perfume']
# Detected labels for post1165_img1.jpg
# ['Cosmetics', 'Lipstick', 'Red']
# Detected labels for post1159_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Lotion', 'Face', 'Head', 'Person']
# Detected labels for post1158_img1.jpg
# ['Bottle', 'Lotion', 'Cosmetics', 'Perfume']
# Detected labels for post1157_img1.jpg
# ['Clothing', 'Dress', 'Evening Dress', 'Formal Wear', 'Face', 'Head', 'Person', 'Photography', 'Portrait', 'Body Part', 'Finger', 'Hand', 'Adult', 'Female', 'Woman', 'Accessories', 'Earring', 'Jewelry', 'Fashion']
# Detected labels for post1155_img1.jpg
# ['Cosmetics', 'Mascara', 'Car', 'Transportation', 'Vehicle']
# Detected labels for post1154_img1.jpg
# ['Cosmetics', 'Mascara']
# Detected labels for post1152_img1.jpg
# ['Accessories', 'Earring', 'Jewelry', 'Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Photography', 'Portrait', 'Formal Wear', 'Clothing', 'Dress', 'Evening Dress', 'Body Part', 'Neck', 'Finger', 'Hand']
# Detected labels for post1151_img1.jpg
# ['Floor', 'Flooring', 'Adult', 'Male', 'Man', 'Person', 'Lighting', 'Photography', 'Back', 'Body Part', 'Standing', 'Clothing', 'Footwear', 'Shoe', 'Furniture']
# Detected labels for post1150_img1.jpg
# ['Smoke Pipe', 'Cosmetics', 'Medication', 'Pill']
# Detected labels for post1149_img1.jpg
# ['Clothing', 'Coat', 'Jacket', 'Blazer', 'Long Sleeve', 'Sleeve', 'Adult', 'Male', 'Man', 'Person', 'Face', 'Head', 'Pants', 'Formal Wear', 'Suit', 'Overcoat', 'Accessories']
# Detected labels for post1148_img1.jpg
# ['Lighting', 'Lamp', 'Light']
# Detected labels for post1147_img1.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Adult', 'Male', 'Man', 'Clothing', 'Shirt', 'Formal Wear', 'Suit', 'Coat', 'Face', 'Head']
# Detected labels for post1146_img1.jpg
# ['Food', 'Honey', 'Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1144_img1.jpg
# ['Blonde', 'Hair', 'Person', 'Face', 'Head', 'Adult', 'Female', 'Woman', 'Text']
# Detected labels for post1141_img1.jpg
# ['Clothing', 'Coat', 'Face', 'Head', 'Person', 'Adult', 'Female', 'Woman', 'Smoke Pipe', 'Black Hair', 'Hair', 'Happy', 'Smile', 'Photography', 'Portrait', 'Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1141_img3.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Cosmetics', 'Makeup']
# Detected labels for post1141_img4.jpg
# ['Clothing', 'Coat', 'Cosmetics', 'Lipstick', 'Bottle', 'Perfume', 'Smoke Pipe']
# Detected labels for post1141_img2.jpg
# ['Cosmetics', 'Adult', 'Female', 'Person', 'Woman', 'Clothing', 'Coat', 'Face', 'Head', 'Makeup']
# Detected labels for post1139_img1.jpg
# ['Text', 'Business Card', 'Paper', 'Credit Card']
# Detected labels for post1139_img3.jpg
# ['Advertisement', 'Poster', 'Person', 'Text', 'Cosmetics', 'Lipstick', 'Business Card', 'Paper', 'Adult', 'Male', 'Man']
# Detected labels for post1139_img2.jpg
# ['Clothing', 'Coat', 'Text', 'Face', 'Head', 'Person', 'Adult', 'Male', 'Man', 'Newspaper']
# Detected labels for post1137_img1.jpg
# ['Terminal', 'Railway', 'Train', 'Train Station', 'Transportation', 'Vehicle', 'Architecture', 'Building', 'Outdoors', 'Shelter', 'Office Building', 'City', 'Urban', 'Road', 'Street', 'Subway']
# Detected labels for post1136_img1.jpg
# ['Furniture', 'Table', 'Adult', 'Female', 'Person', 'Woman', 'Indoors', 'Interior Design', 'Electronics', 'Screen', 'Desk', 'Chair', 'Computer Hardware', 'Hardware', 'Monitor', 'Face', 'Head', 'Shop', 'Market']
# Detected labels for post1136_img4.jpg
# ['Cosmetics', 'Cylinder']
# Detected labels for post1136_img6.jpg
# ['Terminal', 'Railway', 'Train', 'Train Station', 'Transportation', 'Vehicle', 'Subway', 'Chair', 'Furniture', 'Indoors', 'Floor']
# Detected labels for post1136_img2.jpg
# ['Person']
# Detected labels for post1136_img3.jpg
# ['Purple', 'Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Photo Booth']
# Detected labels for post1136_img5.jpg
# ['Book', 'Publication', 'Person', 'Shelf', 'Shop', 'Box', 'Advertisement', 'Indoors']
# Detected labels for post1133_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume']
# Detected labels for post1133_img3.jpg
# ['Laboratory']
# Detected labels for post1133_img5.jpg
# ['Laboratory']
# Detected labels for post1133_img7.jpg
# ['Shelf', 'Cabinet', 'Furniture', 'Shop']
# Detected labels for post1133_img2.jpg
# ['Coin', 'Money']
# Detected labels for post1133_img6.jpg
# ['Food', 'Food Presentation', 'Plate', 'Cooking', 'Medication', 'Pill']
# Detected labels for post1133_img4.jpg
# ['Brush', 'Device', 'Tool', 'Smoke Pipe']
# Detected labels for post1131_img5.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Scientist', 'Clothing', 'Coat']
# Detected labels for post1131_img4.jpg
# ['Accessories', 'Bag', 'Handbag', 'Adult', 'Female', 'Person', 'Woman', 'Computer Hardware', 'Electronics', 'Hardware', 'Monitor', 'Screen', 'Mobile Phone', 'Phone', 'Clothing', 'Footwear', 'Shoe', 'Appliance', 'Device', 'Electrical Device', 'Washer', 'Chair', 'Furniture']
# Detected labels for post1131_img2.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Laboratory', 'Car', 'Transportation', 'Vehicle']
# Detected labels for post1131_img6.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Clothing', 'Coat', 'Indoors', 'Interior Design', 'Face', 'Head', 'Person']
# Detected labels for post1131_img1.jpg
# ['Clothing', 'Coat', 'Adult', 'Female', 'Person', 'Woman', 'Baby', 'Face', 'Head', 'Cup', 'Laboratory', 'Accessories', 'Jewelry', 'Necklace', 'Photography', 'Portrait', 'Ring', 'Glasses']
# Detected labels for post1131_img3.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Clothing', 'Coat', 'Laboratory', 'Face', 'Head', 'Lab', 'Accessories', 'Glasses', 'Cup']
# Detected labels for post1130_img1.jpg
# ['Cosmetics', 'Lipstick', 'Bottle', 'Food', 'Ketchup']
# Detected labels for post1130_img3.jpg
# ['Device', 'Screwdriver', 'Tool', 'Dynamite', 'Weapon', 'Test Tube']
# Detected labels for post1130_img4.jpg
# ['Cosmetics', 'Lipstick']
# Detected labels for post1130_img5.jpg
# ['Photography', 'Bottle', 'Cosmetics', 'Perfume', 'Computer', 'Electronics', 'Laptop', 'Pc', 'Adult', 'Female', 'Person', 'Woman', 'Indoors', 'Lipstick', 'Face', 'Head']
# Detected labels for post1130_img6.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Indoors', 'Beauty Salon']
# Detected labels for post1130_img2.jpg
# ['Food', 'Ketchup']
# Detected labels for post1128_img1.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Chair', 'Furniture', 'Indoors', 'Face', 'Head']
# Detected labels for post1128_img7.jpg
# ['Urban', 'Club', 'Adult', 'Female', 'Person', 'Woman', 'Night Club', 'Electronics', 'Mobile Phone', 'Phone', 'Male', 'Man', 'Face', 'Head', 'Accessories', 'Bracelet', 'Jewelry']
# Detected labels for post1128_img5.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Bottle', 'Cosmetics', 'Perfume', 'Bride', 'Wedding', 'Head']
# Detected labels for post1128_img3.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Adult', 'Female', 'Woman', 'Face', 'Head', 'Nail', 'Cosmetics', 'Accessories', 'Jewelry', 'Ring']
# Detected labels for post1128_img2.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Adult', 'Female', 'Woman', 'Cup', 'Disposable Cup', 'Face', 'Head', 'Clothing', 'Dress', 'Happy', 'Smile']
# Detected labels for post1128_img6.jpg
# ['Body Part', 'Finger', 'Hand', 'Person', 'Adult', 'Female', 'Woman', 'Electronics', 'Mobile Phone', 'Phone', 'Face', 'Head', 'Beverage', 'Milk', 'Bottle', 'Shaker', 'Nail']
# Detected labels for post1128_img4.jpg
# ['Clothing', 'Coat', 'Jacket', 'Adult', 'Male', 'Man', 'Person', 'Face', 'Head', 'Bottle']
# Detected labels for post1127_img5.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Hair', 'Hairdresser']
# Detected labels for post1127_img2.jpg
# ['Brush', 'Device', 'Tool', 'Hair', 'Person', 'Glass']
# Detected labels for post1127_img6.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Male', 'Man', 'Book', 'Publication', 'Advertisement', 'Text', 'Electronics', 'Phone']
# Detected labels for post1127_img3.jpg
# ['Cleaning', 'Person', 'Clothing', 'Glove', 'Brush', 'Device', 'Tool', 'Kitchen Utensil', 'Food', 'Food Presentation']
# Detected labels for post1127_img1.jpg
# ['Advertisement', 'Adult', 'Female', 'Person', 'Woman', 'Face', 'Head', 'Bride', 'Wedding', 'Poster']
# Detected labels for post1127_img4.jpg
# ['Hair', 'Person']
# Detected labels for post1125_img3.jpg
# ['Clothing', 'Pants', 'Coat', 'Jacket', 'Blouse', 'People', 'Person', 'Face', 'Happy', 'Head', 'Smile', 'Adult', 'Female', 'Woman', 'Jeans', 'Accessories', 'Bag', 'Handbag', 'Belt', 'Blazer', 'Jewelry', 'Necklace']
# Detected labels for post1125_img2.jpg
# ['Clothing', 'Glove', 'Adult', 'Female', 'Person', 'Woman', 'Male', 'Man', 'Accessories', 'Jewelry', 'Necklace', 'Chef', 'Wristwatch', 'Face', 'Head', 'Bag', 'Handbag']
# Detected labels for post1125_img1.jpg
# ['Clothing', 'Glove', 'Adult', 'Female', 'Person', 'Woman', 'Electronics', 'Mobile Phone', 'Phone']
# Detected labels for post1125_img4.jpg
# ['Clothing', 'Glove', 'Adult', 'Female', 'Person', 'Woman', 'Accessories', 'Glasses', 'Jewelry', 'Necklace', 'Face', 'Head', 'Coat', 'Chef']
# Detected labels for post1125_img5.jpg
# ['Clothing', 'Glove', 'Electronics', 'Mobile Phone', 'Phone', 'Adult', 'Male', 'Man', 'Person', 'Female', 'Woman', 'Face', 'Head']
# Detected labels for post1125_img6.jpg
# ['Adult', 'Female', 'Person', 'Woman', 'Electronics', 'Mobile Phone', 'Phone', 'Head', 'Face', 'Hair']
# Detected labels for post1123_img3.jpg
# ['Indoors', 'Dynamite', 'Weapon']
# Detected labels for post1123_img6.jpg
# ['White']
# Detected labels for post1123_img2.jpg
# ['Accessories', 'Electrical Device', 'Microphone', 'Weapon', 'Firearm', 'Gun', 'Rifle', 'Ammunition']
# Detected labels for post1123_img5.jpg
# ['Mace Club', 'Weapon', 'Coil', 'Spiral', 'Brush', 'Device', 'Tool']
# Detected labels for post1123_img4.jpg
# ['Stain', 'Hockey', 'Ice Hockey', 'Ice Hockey Puck', 'Rink', 'Skating', 'Sport', 'Footprint']
# Detected labels for post1123_img1.jpg
# ['Nature', 'Outdoors', 'Sea', 'Water', 'Sea Waves', 'Plant', 'Tree', 'Night']
# Detected labels for post1121_img1.jpg
# ['Bottle', 'Cosmetics', 'Perfume', 'Lotion', 'Cutlery', 'Spoon']

# %%
# Write out the results to a csv
with open(rekog_results_dir + f'labels_final_{username}.csv', 'w', newline = '') as csvfile:
    fieldnames = ['image_id', 'has_makeup', 'has_beauty_product', 'has_logo_or_branding',
 'is_fashion_related', 'is_beauty_scene', 'has_text', 'close_up', 'indoors', 'outdoors']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
    writer.writeheader()
    for entry in holder_labels:
        writer.writerow(entry)

# %%
face_labels = []

for imageFile in local_images:
    image_path = rekog_images_dir + imageFile
    try:
        image_bytes = resize_if_needed(image_path)
    except Exception as e:
        print(f"❌ Skipping {imageFile}: {e}")
        continue

    # Detect facial features
    face_response = client.detect_faces(Image={'Bytes': image_bytes}, Attributes=['ALL'])
    celeb_response = client.recognize_celebrities(Image={'Bytes': image_bytes})

    print('Detected faces and celebrities for ' + imageFile)

    temp_dict = {
        "image_id": imageFile,
        "face_count": 0,
        "has_smile": False,
        "has_female": False,
        "has_male": False,
        "dominant_emotion": None,
        "emotions": [],
        "has_happy_emotion": False,
        "has_confident_emotion": False,
        "has_celebrity": False,
        "celebrity_names": [],
        "has_unrecognized_face": False
    }

    # === CELEBRITY CHECK ===
    matched = celeb_response.get("CelebrityFaces", [])
    unmatched = celeb_response.get("UnrecognizedFaces", [])

    if matched:
        temp_dict["has_celebrity"] = True
        temp_dict["celebrity_names"] = [c["Name"] for c in matched]
    if unmatched:
        temp_dict["has_unrecognized_face"] = True

    # === FACIAL ATTRIBUTES ===
    faces = face_response.get('FaceDetails', [])
    temp_dict["face_count"] = len(faces)

    all_emotions = set()
    happy_detected = False
    confident_detected = False

    for face in faces:
        if face.get('Smile', {}).get('Value'):
            temp_dict["has_smile"] = True

        gender = face.get('Gender', {}).get('Value')
        if gender == 'Female':
            temp_dict["has_female"] = True
        elif gender == 'Male':
            temp_dict["has_male"] = True

        for emotion in face.get('Emotions', []):
            if emotion.get('Confidence', 0) >= 70:
                emotion_type = emotion.get('Type')
                all_emotions.add(emotion_type)

                if emotion_type == 'HAPPY':
                    happy_detected = True
                if emotion_type == 'CONFIDENT':
                    confident_detected = True

    temp_dict["emotions"] = list(all_emotions)
    temp_dict["has_happy_emotion"] = happy_detected
    temp_dict["has_confident_emotion"] = confident_detected
    if all_emotions:
        temp_dict["dominant_emotion"] = list(all_emotions)[0]

    face_labels.append(temp_dict)
# Out:
# Detected faces and celebrities for post1121_img3.jpg
# Detected faces and celebrities for post1121_img6.jpg
# Detected faces and celebrities for post1121_img5.jpg
# Detected faces and celebrities for post1121_img2.jpg
# Detected faces and celebrities for post1121_img4.jpg
# Detected faces and celebrities for post1120_img6.jpg
# Detected faces and celebrities for post1120_img5.jpg
# Detected faces and celebrities for post1120_img4.jpg
# Detected faces and celebrities for post1120_img2.jpg
# Detected faces and celebrities for post1120_img1.jpg
# Detected faces and celebrities for post1120_img3.jpg
# Detected faces and celebrities for post1113_img1.jpg
# Detected faces and celebrities for post1112_img3.jpg
# Detected faces and celebrities for post1112_img1.jpg
